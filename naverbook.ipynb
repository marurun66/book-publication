# %%
#.env에서 API키 가져오기
import os
from dotenv import load_dotenv
load_dotenv('.env')
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# %%
## 지금 작업중 (2/26 기준)

# %%
import requests
import time
import json
import os

# 네이버 API 환경변수 가져오기
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# ✅ 검색할 소설 키워드 목록
query_list = ["한국 소설", "일본 소설", "영미 소설"]

# 📌 API 요청 함수
def search_books(query, start=1, display=100):
    url = "https://openapi.naver.com/v1/search/book.json"
    headers = {
        "X-Naver-Client-Id": CLIENT_ID,
        "X-Naver-Client-Secret": CLIENT_SECRET
    }
    params = {
        "query": query,
        "display": display,  # 최대 100개 가져오기
        "start": start,  # 페이징 처리
        "sort": "sim"
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        return response.json()["items"]
    else:
        print(f"⚠️ API 요청 실패 ({response.status_code}): {query}, start={start}")
        return []

# 📌 전체 데이터 저장할 리스트
all_books = []
exclude_keywords = ["단편", "소설집", "단편선", "앤솔러지", "모음집", "옴니버스","자서전","시집","에세이","수필"]

# ✅ 여러 검색어로 데이터 수집
for query in query_list:
    for start in range(1, 1000, 100):  # 1000권 이상 확보 시도
        books = search_books(query, start)
        if not books:
            break  # 더 이상 결과 없음
        
        # 🔹 단편 소설 제외 (제목 또는 설명에 특정 키워드 포함 시 필터링)
        filtered_books = []
        for book in books:
            title = book["title"]
            description = book["description"]
            author = book.get("author", "알 수 없음")  # 🔹 작가 정보 가져오기
            
            # 📌 제외 키워드가 제목이나 설명에 포함되지 않은 경우만 저장
            if not any(keyword in title or keyword in description for keyword in exclude_keywords):
                filtered_books.append({
                    "title": title.split("(")[0].strip(),  # 🔹 제목에서 부가 정보 제거
                    "description": description.replace(".", ".\n"),  # 🔹 줄바꿈 추가
                    "author": author,  # 🔹 작가 정보 포함
                    "summary": ""  # 🔹 줄거리(요약)는 비워둠
                })

        all_books.extend(filtered_books)
        time.sleep(0.5)  # API 호출 제한 방지를 위해 대기

# ✅ 중복 제거 (책 제목 기준)
unique_books = {book["title"]: book for book in all_books}.values()

# 📌 JSON 파일로 저장
output_file = "filtered_novels.json"
with open(output_file, "w", encoding="utf-8") as f:
    json.dump(list(unique_books), f, ensure_ascii=False, indent=4)

print(f"✅ 총 {len(unique_books)}권의 장편 소설 데이터가 '{output_file}'에 저장되었습니다!")
# Out:
# ✅ 총 1637권의 장편 소설 데이터가 'filtered_novels.json'에 저장되었습니다!

# %%
import json
import random

# 📌 1. 전체 1681권 데이터 로드
with open("filtered_novels.json", "r", encoding="utf-8") as f:
    all_books = json.load(f)

# ✅ 2. 랜덤으로 200권 선택 (라벨링용)
random.shuffle(all_books)  # 랜덤 셔플
labeled_books = all_books[:200]  # 앞에서 200권 선택

# ✅ 3. 나머지 1481권 (모델 자동 요약용)
unlabeled_books = all_books[200:]

# 📌 4. 라벨링 데이터 저장
with open("labeling_novels.json", "w", encoding="utf-8") as f:
    json.dump(labeled_books, f, ensure_ascii=False, indent=4)

# 📌 5. 모델 요약용 데이터 저장
with open("unlabeled_books.json", "w", encoding="utf-8") as f:
    json.dump(unlabeled_books, f, ensure_ascii=False, indent=4)

print(f"✅ 랜덤 200권 라벨링 완료! ('labeling_novels.json' 저장)")
print(f"✅ 나머지 1481권 모델 요약 준비 완료! ('unlabeled_books.json' 저장)")
# Out:
# ✅ 랜덤 200권 라벨링 완료! ('labeling_novels.json' 저장)
# ✅ 나머지 1481권 모델 요약 준비 완료! ('unlabeled_books.json' 저장)

# %%
###################################################################

# %%
import json
from rank_bm25 import BM25Okapi
import re

# ✅ JSON 파일 로드 (도서 데이터)
with open("novels.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 텍스트 전처리 (소문자 변환 + 불필요한 기호 제거)
def preprocess_text(text):
    text = text.lower()  # 소문자로 변환
    text = re.sub(r"[^\w\s]", "", text)  # 특수문자 제거
    return text

# ✅ BM25에 사용할 책 줄거리 데이터 준비
book_summaries = [preprocess_text(book.get("description", "")) for book in books_data]
tokenized_books = [summary.split() for summary in book_summaries]

# ✅ BM25 모델 생성
bm25 = BM25Okapi(tokenized_books)

# ✅ 사용자 입력 (검색할 줄거리)
query = "수학 교사가 전남편을 살해한 짝사랑하던 여자를 감싸기 위해 알리바이를 조작하는 소설"
tokenized_query = preprocess_text(query).split()

# ✅ BM25로 유사도 점수 계산
scores = bm25.get_scores(tokenized_query)

# ✅ 가장 유사한 상위 5개 책 찾기
top_n = 5
top_indices = sorted(range(len(scores)), key=lambda i: scores[i], reverse=True)[:top_n]

# ✅ 검색 결과 출력
print("\n🔍 검색 결과 (Top 5):")
for idx in top_indices:
    book = books_data[idx]
    print(f"📖 제목: {book.get('title', '제목 없음')}")
    print(f"📜 줄거리: {book.get('description', '줄거리 없음')}")
    print(f"🔗 링크: {book.get('link', '링크 없음')}\n")
# Out:
# 🔍 검색 결과 (Top 5):
# 📖 제목: 흔한 일들
# 📜 줄거리: 연쇄살인사건의 비밀을 파헤치는 한국적인 크라임 스릴러!
#
# 범죄 전문 기자 출신 작가 신재형이 쓴 한국형 크라임 스릴러 『흔한 일들』. 연쇄살인사건을 배경으로 최고의 프로파일러와 현장을 조작하는 범인의 치열한 두뇌 싸움을 그리고 있다. 서울 보광동에서 발생한 일가족 살인사건. 피해자는 여덟 살 딸과 그 어머니, 유력한 용의자는 현장을 배회하던 이웃집 여자 차아령. 6개월 전 연쇄살인범을 검거한 서울청 현장감식반 최재준 형사가 사건에 투입된다. 그는 차아령을 심문하던 중 피해자의 남편이 알리바이를 속인 사실을 알아내고 재빨리 탐문에 돌입하지만, 남편은 숨진 채 발견된다. 사체의 훼손상태를 살펴보던 최재준 형사는 이 사건이 자신을 겨낭하고 있다는 것을 깨닫게 되는데….
# 🔗 링크: https://search.shopping.naver.com/book/catalog/32506472270
#
# 📖 제목: 다감 선생님은 아이들이 싫다(리커버 개정판) (공민철 연작소설)
# 📜 줄거리: 타고난 명탐정 초등학교 교사가 아이들과 함께 겪는 성장통 이야기
#
# 좀처럼 아이들에게 마음을 열지 못하던 초등학교 교사 다감은 학교 내 자살 미수 사건을 해결하면서 6학년 1반의 담임이 된다. 이후로도 살인 사건, 방화 사건, 학교 폭력 등 아이들과 관련되어 예사롭지 않은 일들을 겪게 되는데, 진실을 알기 위해 사건을 하나둘 해결해 나가며 자신의 내면에서 아이들의 존재가 조금씩 커지는 것을 느끼는데…….
# 🔗 링크: https://search.shopping.naver.com/book/catalog/39849318619
#
# 📖 제목: 이방인 : 보성어부 살인 사건
# 📜 줄거리: 2007년! 녹차로 유명한 보성에서 충격적인 사건이 발생했다.
# 70대 어부가 성 욕구를 채우기 위해 자신의 배에 탄 젊은 남녀 대학생을 살해한 사건이었다.
# 노인은 2명의 젊은 여자를 같은 방법 같은 목적으로 추가 살해했다.
# 사람들은 노인의 엽기적 행각에 울분을 터뜨렸고 분노했다.
# ‘싸이코패스’ ‘성도착자’라는 단어들이 한동안 매스컴에 오르내렸다.
# 그는 항변했다.
# 태양이 너무 눈이 부셔 살인을 했다는 이방인의 뫼르소처럼...
#
# “나한테 배를 태워 달라고 한 것이 잘못이다. 왜 그 많은 배들 중에 내 배를 태워 달라고 했고 또 돈 안 받고 공짜로 태워 준다니까 그게 좋아서 탄
# 그 사람들이 문제 있지 않느냐? 그 사람들 보다 내가 더 불행해졌다. 사망한 사람들은 이미 사망했지 않느냐? 그런 일을 저지른 난 여기서 지금 굉장히
# 사회적으로 지탄을 받고 몸도 지금 아프다.”
#
#
#
#
#
# 70대 어부의 性!
# 진정 그는 성 욕구 때문에 살인을 한 것일까?
# 소외감과 외로움 때문은 아니었을까?
# 아니면 붉은 바다 노을 때문이었을까?
# 아니면 자신(노인)에 대한 사회의 왜곡된 인식과 편견에 대한 반항의 몸짓이었을까?
# 이방인은 바로 이 보성 어부 사건이 모티브가 되었고 이러한 의문에서 비롯되었다.
# 🔗 링크: https://search.shopping.naver.com/book/catalog/33812096646
#
# 📖 제목: 다감 선생님은 아이들이 싫다 (가슴이 따뜻해지고 울컥해지는 힐링 미스터리)
# 📜 줄거리: 가슴이 따뜻해지고 울컥해지는 힐링 미스터리 연작소설
#
# 더는 힘들어하지 말아 달라는 말을 남기고 자살로 세상을 떠난 언니. 다감은 언니 다정의 마음을 눈치채지 못한 자신이 원망스러워 견딜 수 없다. 언니는 왜 자살을 한 것일까? 왜 우리 가족을 떠나 버린 걸까? 무슨 일이 있어도 언니의 마음을 알고 싶었던 다감은 언니처럼 초등학교 교사가 되기로 결심한다.
# 그리고 수년 후, 다감은 뜻하던 대로 교사가 되어 길벗 초등학교로 발령을 받는다. 하지만 교사의 일은 적성에 맞지 않고 언니에 대한 기억으로 아이들이 거북하다. 다감은 교사의 자격이 없는 자신이 언니의 마음을 알 수 있을지 불안하기만 하다.
# 그러던 어느 날, 다감은 학교 엘리베이터에 목을 매어 자살을 시도하는 시아를 구해 내게 된다. 그리고 시아를 대하는 어른들의 태도를 보며 마음속에서 알 수 없는 감정이 끓어오르는 것을 느끼는데…….
#
# 좀처럼 아이들에게 마음을 열지 못하던 초등학교 선생님 다감은 자살 미수, 살인 사건, 방화 사건, 학교 폭력 등 아이들과 관련되어 예사롭지 않은 일들을 겪게 된다. 진실을 알기 위해 사건을 하나둘 해결해 나가며 다감은 자신의 내면에서 아이들의 존재가 조금씩 커져 가는 것을 느낀다.
# 큰 슬픔으로 흩어졌던 마음의 퍼즐을 맞춰 가는 휴먼 미스터리 연작소설 『다감 선생님은 아이들이 싫다』는 한 명의 교사로 성장하는 다감과 삶의 아픔을 딛고 꿋꿋하게 일어서는 아이들을 통해 독자의 마음에 따뜻한 온기를 전해 줄 것이다.
# 🔗 링크: https://search.shopping.naver.com/book/catalog/32491439102
#
# 📖 제목: 용의자 X의 헌신 (제134회 나오키상 수상작, 갈릴레오 시리즈 3)
# 📜 줄거리: 정교한 살인수식에 도전하는 천재 물리학자의 집요한 추적이 시작된다!
#
# 히가시노 게이고 문학의 정수로 일컬어지는 추리 소설 『용의자 X의 헌신』. 일본 문학 전문 번역가 양억관이 자신의 번역을 대폭 손질해 원작이 지닌 문학적 향기와 감동을 오롯이 되살려냈다. 일본 추리소설에서 흔히 보여 지는 잔혹함이나 엽기 호러가 아닌 사랑과 헌신이라는 고전적이며 낭만적인 테마를 미로처럼 섬세하게 엮어낸 슬프고 아름다운 이야기로, 제134회 나오키상을 수상했다.
#
# 도쿄 에도가와 인근 한 연립 주택에서 중년 남자가 모녀에 의해 살해된다. 숨진 남자는 도가시. 한때 술집 호스티스였으나 지금은 도시락 가게에서 일하면서 첫 남편 사이에 낳은 딸 마사토를 키우고 있는 여자, 하나오카 야스코의 이혼한 두 번째 남편이다. 돈을 갈취하기 위해 찾아와 폭력을 휘두르는 그를 모녀가 우발적으로 목 졸라 살해하고, 우연히 사건을 눈치 채게 된 옆집 사는 고등학교 수학교사 이시가미가 그녀를 돕겠다고 나선다.
#
# 마음속으로 야스코를 깊이 사모해 왔던 이시가미는 완전범죄 만들기에 나서게 된다. 대학 시절 백 년에 한번 나올까 말까 한 천재라는 소리를 듣던 그는 빈틈없는 알리바이를 만들고, 경찰 심문에 대응하는 요령까지 모녀에게 세세히 지시하여 경찰의 수사를 혼선에 빠뜨린다. 사건 다음날, 얼굴을 알아볼 수 없는 중년 남자의 변사체가 발견되고, 경찰은 그것이 도가시의 사체임을 밝혀낸다.
#
# 야스코가 유력한 용의자로 수사선상에 떠오르고, 경찰은 그녀의 알리바이를 확인하는 데 총력을 기울이지만 별다른 소득을 얻지 못한다. 수사가 답보 상태에 빠진 상황에서 형사 구사나기는 자신이 어려움에 처할 때마다 등장해 사건 해결의 실마리를 던져주던 천재 물리학자, 일명 ‘탐정 갈릴레오’, 유가와에게 S.O.S를 친다. 유가와는 구사나기에게 야스코의 이웃인 이시가미의 이름을 듣고 그가 대학 시절 자신과 전공은 다르지만 서로의 천재성을 인정했던 동창생이라는 사실을 기억해내고, 이시가미가 사건에 개입했음을 직감하는데…….
# 🔗 링크: https://search.shopping.naver.com/book/catalog/32463541483

# %%
from sentence_transformers import SentenceTransformer, util
import json

# ✅ 사전 훈련된 Sentence Embedding 모델 로드
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# ✅ JSON 파일 로드 (도서 데이터)
with open("novels.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 책 줄거리 리스트 생성
book_summaries = [book.get("description", "") for book in books_data]

# ✅ 책 줄거리들을 벡터로 변환
book_vectors = model.encode(book_summaries, convert_to_tensor=True)

# ✅ 사용자 입력
query = "어떤 수학 천재가 살인을 저지른 여자를 도와주려는 소설"
query_vector = model.encode(query, convert_to_tensor=True)

# ✅ 코사인 유사도 계산
similarities = util.pytorch_cos_sim(query_vector, book_vectors)[0]

# ✅ 가장 유사한 상위 5개 책 찾기
top_n = 5
top_indices = similarities.argsort(descending=True)[:top_n]

# ✅ 검색 결과 출력
print("\n🔍 검색 결과 (Top 5):")
for idx in top_indices:
    book = books_data[idx]
    print(f"📖 제목: {book.get('title', '제목 없음')}")
    print(f"📜 줄거리: {book.get('description', '줄거리 없음')}")
    print(f"🔗 링크: {book.get('link', '링크 없음')}\n")
# Out:
# 🔍 검색 결과 (Top 5):
# 📖 제목: 경범죄 전문 흥신소
# 📜 줄거리: 대한민국의 경범죄 치한률 증가. 경찰이 해결 못해주는 사건을 맡아주는 경범죄 전문 흥신소 등장
# 🔗 링크: https://search.shopping.naver.com/book/catalog/44021367621
#
# 📖 제목: 사랑오운 아가미
# 📜 줄거리: 세상이 부정하더라도 모든 사랑은 빛나기에
# 빛나는 사랑을 하고 계신 분들께 이 책을 바칩니다
# 🔗 링크: https://search.shopping.naver.com/book/catalog/52782956485
#
# 📖 제목: 카페 홈즈의 마지막 사랑(큰글씨책)
# 📜 줄거리: 추리소설 작가들의 아지트인 ‘카페 홈즈’
# 그곳을 무대로 펼쳐지는 여섯 작가의 독특한 여섯 가지 이야기
# 🔗 링크: https://search.shopping.naver.com/book/catalog/32441033830
#
# 📖 제목: 사라진 피리 (고대 도시에서의 추적)
# 📜 줄거리: 고대 도시 경주에서 펼쳐지는 5일간의 모험
# 🔗 링크: https://search.shopping.naver.com/book/catalog/51896716626
#
# 📖 제목: 트윈 풀 호텔의 살인 사건
# 📜 줄거리: 포문 출판 노원 작가의 대표작 ‘어릿광대 저택의 살인 사건’에서 활약한 아일랜과 뉴윈의 두 번째 사건 해결서
# 🔗 링크: https://search.shopping.naver.com/book/catalog/45813431623

# %%
from sentence_transformers import SentenceTransformer, util
import json
import numpy as np
from rank_bm25 import BM25Okapi
import re

# ✅ 더 강력한 모델 사용 ('multi-qa-mpnet-base-dot-v1')
model = SentenceTransformer("sentence-transformers/multi-qa-mpnet-base-dot-v1")

# ✅ JSON 파일 로드 (도서 데이터)
with open("novels.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 데이터 정제 및 줄거리 리스트 생성 (너무 짧은 줄거리는 제외)
filtered_books = [book for book in books_data if len(book.get("description", "")) > 20]

# ✅ 책 줄거리 리스트 생성
book_summaries = [book.get("description", "") for book in filtered_books]

# ✅ 1️⃣ BM25 기반 검색 수행 (불필요한 특수문자 제거)
tokenized_summaries = [re.sub(r"\W+", " ", summary.lower()).split() for summary in book_summaries]
bm25 = BM25Okapi(tokenized_summaries)

# ✅ 사용자 입력 (검색어)
query = "여자주인공이 도시락집 직원인데 전남편을 살해했어. 이웃집 수학 천재가 그 여자를 짝사랑해서 그 여자를 위해 알리바이를 만들어주고 자기자신은 죄를 뒤집어쓰려고 해. 그 소설이 뭐지?"

# ✅ BM25 검색 적용 (Top 50개 선택)
query_tokens = re.sub(r"\W+", " ", query.lower()).split()
bm25_scores = bm25.get_scores(query_tokens)
top_n_bm25 = np.argsort(bm25_scores)[::-1][:50]  # ✅ BM25 기반 Top 50개 선택

# ✅ 2️⃣ 선택된 Top 50개에 대해 SentenceTransformer 유사도 비교
selected_books = [book_summaries[i] for i in top_n_bm25]
selected_vectors = model.encode(selected_books, convert_to_tensor=True)

query_vector = model.encode(query, convert_to_tensor=True)
similarities = util.pytorch_cos_sim(query_vector, selected_vectors)[0].cpu().numpy()

# ✅ SentenceTransformer 유사도 점수를 활용하여 최종 Top 5 정렬
top_n = 5
sorted_indices = np.argsort(similarities)[::-1][:top_n]

# ✅ 검색 결과 출력
print("\n🔍 검색 결과 (Top 5):")
for idx in sorted_indices:
    book = filtered_books[top_n_bm25[idx]]
    print(f"📖 제목: {book.get('title', '제목 없음')}")
    print(f"📜 줄거리: {book.get('description', '줄거리 없음')}")
    print(f"🔗 링크: {book.get('link', '링크 없음')}\n")
# Out:
# 🔍 검색 결과 (Top 5):
# 📖 제목: 옥중금낭, 첫날밤의 살인사건
# 📜 줄거리: 과거를 보러 서울에 올라온 장한응은 아이들의 장난으로 곤경에 처한 맹인 점쟁이를 구해 준다. 점쟁이는 그 사례로 점을 쳐 주는데, 세 가지 액운을 예언한다. 불에 타 죽을 운수와 물에 빠져 죽을 운수, 옥에 갇혀 죽을 운수가 그것이다. 《옥중금낭》은 장한응에게 닥쳐오는 세 가지 액운을 어떻게 극복할 것인가에 대한 긴장을 담고 있다. 중심은 신혼 첫날밤 벌어진 살인사건이다. 알리바이를 입증 못해 옥에 갇힌 장한응. 진짜 범인은 누구인가?
# 🔗 링크: https://search.shopping.naver.com/book/catalog/51398618626
#
# 📖 제목: 옥중금낭, 첫날밤의 살인사건 (큰글자책)
# 📜 줄거리: 과거를 보러 서울에 올라온 장한응은 아이들의 장난으로 곤경에 처한 맹인 점쟁이를 구해 준다. 점쟁이는 그 사례로 점을 쳐 주는데, 세 가지 액운을 예언한다. 불에 타 죽을 운수와 물에 빠져 죽을 운수, 옥에 갇혀 죽을 운수가 그것이다. 《옥중금낭》은 장한응에게 닥쳐오는 세 가지 액운을 어떻게 극복할 것인가에 대한 긴장을 담고 있다. 중심은 신혼 첫날밤 벌어진 살인사건이다. 알리바이를 입증 못해 옥에 갇힌 장한응. 진짜 범인은 누구인가?
# 🔗 링크: https://search.shopping.naver.com/book/catalog/51408008630
#
# 📖 제목: 꿈에서 온 그녀
# 📜 줄거리: “꿈에서 본 여자를 현실에서 만났다면, 꿈에서 일어난 사건도 현실에서 일어날 수 있는 게 아닌가?”꿈과 현실의 경계를 넘나드는 섬세한 서사와 심리적 긴장감이 돋보이는 문학적 서스펜스.
# 주인공 함지훈은 태어나는 순간 어머니를 잃고, 아버지의 냉대 속에서 상처와 죄책감을 안고 성장했다. 어느 날, 꿈속에서 지훈은 광기 어린 웃음을 짓는 여인을 만나고, 현실에서 그녀와 마주한 뒤 삶이 예측할 수 없는 방향으로 흔들리기 시작한다. 연이어 벌어지는 비극 속에서 지훈은 믿음과 의심, 사랑과 상실의 감정 사이를 오가며 점점 더 깊은 혼란에 빠진다. 점차 드러나는 진실은 지훈에게 삶과 운명에 대한 근본적인 질문을 던진다.
# 🔗 링크: https://search.shopping.naver.com/book/catalog/52821712267
#
# 📖 제목: 엔젤
# 📜 줄거리: 이시다 이라 미스터리 장편소설 『엔젤』. 사후의 세계에서 영혼으로 존재하는 것들에게 각자의 사연을 만들어주고, 또 그들이 생성되고 소멸되는 과정을 독특한 방식으로 독자들에게 보여준다. 준이치는 불행한 어린 시절을 보내며 어두운 성격으로 성장해 자신만을 위해 살아온 인물이다. 불현듯 깨달아버린 자신의 죽음을 미처 받아들이기도 전에 영혼으로 존재하게 된 남자. 사람의 따뜻한 정이라곤 전혀 느껴보지 못한 준이치가 잃어버린 사랑을 되찾고 범인에게 복수하려는 계획은 성공할 수 있을까?
# 🔗 링크: https://search.shopping.naver.com/book/catalog/32485027385
#
# 📖 제목: 상복의 랑데부
# 📜 줄거리: 외로운 사나이의 음습한 범죄 스릴러. 여객기 승객이 무심코 떨어뜨린 병이 참극의 시발이었다. 한순간에 사랑하는 여자를 잃은 조니는 복수의 집념을 불태우며 모든 승객의 연인을 차례로 살해한다. 긴박감 넘치는 서스펜스, 독특한 우수와 서정이 깔린 작품.
# 🔗 링크: https://search.shopping.naver.com/book/catalog/33434912657

# %%
import faiss
import numpy as np
from sentence_transformers import SentenceTransformer
import json

# 1️⃣ BAAI/bge-m3 모델 로드 (정규화 필수)
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512

# 2️⃣ novels.json 파일 로드
with open("novels.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# 3️⃣ 소설 줄거리를 벡터로 변환 (✅ 정규화 추가)
descriptions = [novel["description"] for novel in novels]
embeddings = model.encode(descriptions, normalize_embeddings=True, convert_to_numpy=True)

# 4️⃣ FAISS 코사인 유사도 검색을 위한 Index 생성
d = embeddings.shape[1]  # 1024차원
index = faiss.IndexFlatIP(d)  # ✅ Inner Product (IP) 기반 인덱스
faiss.normalize_L2(embeddings)  # ✅ 벡터 정규화 필수
index.add(embeddings)

# 5️⃣ 인덱스 저장 (재사용 가능)
faiss.write_index(index, "novel_index_cosine.faiss")

# 6️⃣ JSON 파일로 소설 데이터 저장 (검색 시 사용)
with open("novel_data.json", "w", encoding="utf-8") as f:
    json.dump(novels, f, ensure_ascii=False, indent=4)

print("✅ FAISS 코사인 유사도 인덱스 저장 완료!")
# Out:
# ✅ FAISS 코사인 유사도 인덱스 저장 완료!

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer

# 1️⃣ BAAI/bge-m3 모델 로드
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512

# 2️⃣ FAISS 인덱스 로드
index = faiss.read_index("novel_index_cosine.faiss")

# 3️⃣ 소설 데이터 로드
with open("novel_data.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# 4️⃣ 검색 함수 정의
def search_similar_novels(query, top_k=20):  # ✅ top_k=20 으로 확장
    query_embedding = model.encode([query], normalize_embeddings=True, convert_to_numpy=True)
    faiss.normalize_L2(query_embedding)  # ✅ 검색 전 벡터 정규화 필수
    
    distances, indices = index.search(query_embedding, top_k)
    
    results = []
    for i, idx in enumerate(indices[0]):
        if idx < len(novels):
            results.append({
                "rank": i+1,
                "title": novels[idx]["title"],
                "link": novels[idx]["link"],
                "description": novels[idx]["description"],
                "similarity": float(distances[0][i])
            })
    
    return results

# 5️⃣ 테스트 검색 (예제)
query = "어떤 여자가 전남편을 살해했어. 그 여자를 짝사랑해왔던 이웃집 수학교사가 그 여자를 위해 알리바이를 만들어주고 자기자신이 죄를 뒤집어쓰려고 해"
results = search_similar_novels(query)

# 6️⃣ 검색 결과 출력
for res in results[:5]:  # ✅ 상위 5개 결과만 출력
    print(f"{res['rank']}. {res['title']} ({res['similarity']:.4f})")
    print(f"🔗 {res['link']}")
    print(f"📖 {res['description'][:100]}...\n")
# Out:
# 1. 누명 (0.5345)
# 🔗 https://search.shopping.naver.com/book/catalog/33434700728
# 📖 막대한 자산을 가진 의붓어머니를 살해했다는 죄로 복역중인 쟈코는 강력히 무죄를 주장하나 결국 옥사한다. 그러나 그에게는 철벽 알리바이가 있었다! 그렇다면 진짜 범인은 누구인가? 인...
#
# 2. 그날로 다시 돌아가 널 살리고 싶어 (우대경 장편소설) (0.5236)
# 🔗 https://search.shopping.naver.com/book/catalog/39072822623
# 📖 촉법소년에게 아들을 잃은 은서. 그녀에게 건네진 낡은 일기장.
# 그 일기를 통해 시작된 타임슬립, 그리고 복수.
#
# “내가 과거로 가면 미래가 달라지기라도 하니? 우리 아들이 살아 돌...
#
# 3. 중간지점의 집 (0.5209)
# 🔗 https://search.shopping.naver.com/book/catalog/32436143223
# 📖 오두막에서 한 남자가 살해된다. 이 남자는 누구이며 왜 살해되었는가? 아름다움과 추함, 빈곤과 부유, 혼자이면서 두 사람의 피해자이기도 한 이중성 알리바이 상쾌한 추리가 질주, 질...
#
# 4. 킬에이저 (0.5202)
# 🔗 https://search.shopping.naver.com/book/catalog/49644211622
# 📖 ‘올해 가장 주목받는 한국의 여성 리더 10인’에 선정될 정도로 대한민국을 대표하는 1세대 프로파일러 강해수. 야망 때문에 남편과 이혼한 후, 아들을 명문 고등학교에 보낸다. 그러...
#
# 5. 종이학 살인사건 (0.5186)
# 🔗 https://search.shopping.naver.com/book/catalog/35326331623
# 📖 아버지의 시신에서 암호를 발견한 그날,
# 멈췄던 연쇄살인이 다시 시작됐다.
#
# 의사인 치하야는 어머니의 죽음 후 멀어진 아버지와의 관계를 회복하지 못한 채, 아버지마저 암으로 떠나보내...

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer

# 1️⃣ BAAI/bge-m3 모델 로드
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512

# 2️⃣ FAISS 인덱스 로드
index = faiss.read_index("novel_index_cosine.faiss")

# 3️⃣ 소설 데이터 로드
with open("novel_data.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# 4️⃣ 검색 함수 정의
def search_similar_novels(query, top_k=20):  # ✅ 검색 개수 증가
    # ✅ 쿼리에 "질문:" 추가
    query_embedding = model.encode(["질문: " + query], normalize_embeddings=True, convert_to_numpy=True)
    faiss.normalize_L2(query_embedding)  # ✅ 벡터 정규화 추가

    distances, indices = index.search(query_embedding, top_k)

    results = []
    for i, idx in enumerate(indices[0]):
        if idx < len(novels):
            results.append({
                "rank": i+1,
                "title": novels[idx]["title"],
                "link": novels[idx]["link"],
                "description": novels[idx]["description"],
                "similarity": float(distances[0][i])
            })

    return results

# 5️⃣ 테스트 검색
query = """
도시락 가게에서 일하는 여성이 있습니다. 그녀는 전남편을 우발적으로 살해했으며, 
그녀의 이웃인 수학 천재 남성은 그녀를 오랫동안 짝사랑해 왔습니다. 
이 남성은 그녀를 돕기 위해 완벽한 알리바이를 만들어주고, 
자신이 대신 죄를 뒤집어쓰려고 합니다. 이 이야기가 담긴 소설의 제목은 무엇인가요?
"""

results = search_similar_novels(query)

# 6️⃣ 검색 결과 출력
for res in results[:5]:  # ✅ 상위 5개 결과만 출력
    print(f"{res['rank']}. {res['title']} ({res['similarity']:.4f})")
    print(f"🔗 {res['link']}")
    print(f"📖 {res['description'][:100]}...\n")
# Out:
# 1. 시간의 조각 (0.5620)
# 🔗 https://search.shopping.naver.com/book/catalog/52522355605
# 📖 김동원│로버트
# 조금 특별한 친구 ‘로버트’. 어눌한 말투와 무표정한 얼굴, 특정 분야에 몰두해 있고 말의 맥락을 파악할 줄 모르며 상대방의 기분이나 상황을 고려하지 않고 자신의 관...
#
# 2. 용의자 X의 헌신 (갈릴레오 시리즈 3) (0.5569)
# 🔗 https://search.shopping.naver.com/book/catalog/32485526273
# 📖 정교한 살인수식에 도전하는 천재 물리학자의 집요한 추적이 시작된다!
#
# 《동급생》, 《백야행》의 작가 히가시노 게이고의 장편소설. 2006년 제134회 나오키 상 수상작이다. 일본 ...
#
# 3. 미스터리 살인 사건 7+1 (0.5567)
# 🔗 https://search.shopping.naver.com/book/catalog/42654561620
# 📖 미스터리 살인 사건에는 규칙이 있다.
# 반드시 피해자, 용의자, 수사관이 있을 것.
#
# 수학 교수인 그랜트 맥알리스터가 그 모든 규칙을 세우고 연구한 다음 완벽한 일곱 편의 이야기를 ...
#
# 4. 한밤중의 마리오네트 (0.5540)
# 🔗 https://search.shopping.naver.com/book/catalog/51896750620
# 📖 내가 살려낸 환자가 약혼자를 죽인 연쇄살인마라면?
# 토막 난 시신 옆에서 발견된 그는…
# 무고한 피해자인가, 아니면 끔찍한 살인마인가?!
#
# 하룻밤 사이에 사람을 토막 내는 엽기살인마,...
#
# 5. 용의자 X의 헌신 (제134회 나오키상 수상작, 갈릴레오 시리즈 3) (0.5519)
# 🔗 https://search.shopping.naver.com/book/catalog/32463541483
# 📖 정교한 살인수식에 도전하는 천재 물리학자의 집요한 추적이 시작된다!
#
# 히가시노 게이고 문학의 정수로 일컬어지는 추리 소설 『용의자 X의 헌신』. 일본 문학 전문 번역가 양억관이 자...

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer

# ✅ 모델 로드
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512

# ✅ 소설 데이터 로드
with open("novels.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# ✅ 소설 줄거리 벡터 변환
descriptions = [novel["description"] for novel in novels]
embeddings = model.encode(descriptions, normalize_embeddings=True, convert_to_numpy=True)

# ✅ 벡터 정규화 (코사인 유사도 기반 검색용)
faiss.normalize_L2(embeddings)

# ✅ FAISS 인덱스 생성 (Inner Product 기반)
d = embeddings.shape[1]  # 벡터 차원
index = faiss.IndexFlatIP(d)  # IP (Inner Product) 방식 사용
index.add(embeddings)  # 벡터 추가

# ✅ FAISS 인덱스 저장
faiss.write_index(index, "novel_index_cosine.faiss")

print("✅ FAISS 인덱스 생성 완료! (코사인 유사도 기반)")
# Out:
# ✅ FAISS 인덱스 생성 완료! (코사인 유사도 기반)

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer

# 1️⃣ BAAI/bge-m3 모델 로드
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512  # 입력 문장 길이 제한

# 2️⃣ FAISS 인덱스 로드
index = faiss.read_index("novel_index.faiss")

# 3️⃣ 소설 데이터 로드
with open("novel_data.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# ✅ 🔥 다양한 쿼리 변형 함수 추가
def generate_query_variants(query):
    """여러 가지 방식으로 쿼리를 변형하여 검색 정확도를 높임"""
    return [
        f"이 소설은 {query} 라는 이야기를 다룬다.",
        f"이 이야기의 핵심 키워드는 {query} 이다.",
        f"이 책은 {query} 를 중심으로 전개된다.",
        f"이 소설에서 주요 인물들은 {query} 속에서 관계를 맺는다.",
        f"줄거리는 {query} 를 기반으로 진행된다."
    ]

# ✅ 🔥 다중 쿼리 검색 수행 함수
def search_similar_novels_multi(query, top_k=10):
    """다양한 쿼리를 생성하고, 다중 검색 후 최적의 결과를 반환"""
    query_variants = generate_query_variants(query)  # 여러 개의 변형된 쿼리 생성
    all_results = {}

    for q in query_variants:
        query_embedding = model.encode([q], normalize_embeddings=True, convert_to_numpy=True)
        faiss.normalize_L2(query_embedding)

        distances, indices = index.search(query_embedding, top_k)

        for i, idx in enumerate(indices[0]):
            if idx < len(novels):
                title = novels[idx]["title"]
                similarity = float(distances[0][i])

                # 동일한 책이 여러 번 등장하면 가장 높은 점수 유지
                if title in all_results:
                    all_results[title]["similarity"] = max(all_results[title]["similarity"], similarity)
                else:
                    all_results[title] = {
                        "rank": len(all_results) + 1,
                        "title": title,
                        "link": novels[idx]["link"],
                        "description": novels[idx]["description"],
                        "similarity": similarity
                    }

    # ✅ 점수 순으로 정렬
    sorted_results = sorted(all_results.values(), key=lambda x: x["similarity"], reverse=True)
    return sorted_results[:5]

# ✅ 테스트 실행 (쿼리 입력)
query = """
일본소설이야. 도시락가게에서 일하는 여자가 있는데, 전남편을 우발적으로 살해했다.
그 여자를 짝사랑하던 이웃의 수학교사가 그 여자를 돕기 위해 완벽한 알리바이를 만들어주고,
자신이 대신 죄를 뒤집어쓰려고 한다. 이 소설의 제목은 무엇인가요?
"""

# 🔍 최종 검색 실행
results = search_similar_novels_multi(query)

# ✅ 검색 결과 출력
for res in results:
    print(f"{res['rank']}. {res['title']} ({res['similarity']:.4f})")
    print(f"🔗 {res['link']}")
    print(f"📖 {res['description'][:100]}...\n")
# Out:
# 15. 도련님 (미니북) (0.8778)
# 🔗 https://search.shopping.naver.com/book/catalog/32436072624
# 📖 일본의 셰익스피어 나쓰메 소세키를 인기 작가 반열에 올린 작품이다. 사회 부조리와 기회주의적 인간에 대한 비판을 담고 있다. 비판 의식이 가득한 소설이지만 무겁게 이야기를 끌어가는...
#
# 14. 수인번호 1004 (죽은 자는 말이 없지만, 완전범죄란 있을 수 없다!) (0.8767)
# 🔗 https://search.shopping.naver.com/book/catalog/41203603620
# 📖 죽은 자는 말이 없지만 완전범죄란 있을 수 없다. 이 말이 가능한 것은 범인과 진실을 쫓는 이들의 부단한 노력과 집념이 있기 때문일 것이다. 실화를 바탕으로 쓰인 이 미스터리 소설...
#
# 13. 나오미와 가나코 (오쿠다 히데오 장편소설) (0.8760)
# 🔗 https://search.shopping.naver.com/book/catalog/32436121677
# 📖 우리는 오늘 남편을 죽였다!
#
# 오쿠다 히데오의 장편소설 『나오미와 가나코』. 그동안의 스타일에서 벗어나 고도의 서스펜스 스타일로 새롭게 변신을 시도한 오쿠다 히데오. 저자 자신도 ...
#
# 7. 테사를 찾아서(큰글자도서) (0.8738)
# 🔗 https://search.shopping.naver.com/book/catalog/50402736623
# 📖 불행한 어린 시절을 보내며 성장했으면서도 행복한 삶에 대한 희망과 기대를 놓지 않는 테사. 그녀는 자신을 구원해 줄 새 인생을 꿈꾸며 지옥 같은 이전 삶에서 탈출을 시도한다. 끊임...
#
# 8. 테사를 찾아서 (0.8738)
# 🔗 https://search.shopping.naver.com/book/catalog/49893111618
# 📖 불행한 어린 시절을 보내며 성장했으면서도 행복한 삶에 대한 희망과 기대를 놓지 않는 테사. 그녀는 자신을 구원해 줄 새 인생을 꿈꾸며 지옥 같은 이전 삶에서 탈출을 시도한다. 끊임...

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer

# ✅ 모델 로드 (BAAI/bge-m3)
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512

# ✅ 소설 데이터 로드
with open("novels.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# ✅ 🔥 새로운 임베딩 전략: 제목 + 작가 + 줄거리 포함
def create_embedding_text(novel):
    return f"제목: {novel['title']}. 저자: {novel['author']}. 내용: {novel['description']}"

# ✅ 🔥 벡터 변환 (제목 + 저자 + 설명 포함)
descriptions = [create_embedding_text(novel) for novel in novels]
embeddings = model.encode(descriptions, normalize_embeddings=True, convert_to_numpy=True)

# ✅ 벡터 정규화 (코사인 유사도 기반 검색용)
faiss.normalize_L2(embeddings)

# ✅ FAISS 인덱스 생성 (Inner Product 기반)
d = embeddings.shape[1]  # 벡터 차원
index = faiss.IndexFlatIP(d)  # IP (Inner Product) 방식 사용
index.add(embeddings)  # 벡터 추가

# ✅ FAISS 인덱스 저장
faiss.write_index(index, "novel_index_cosine_v2.faiss")

print("✅ 새로운 FAISS 인덱스 생성 완료! (제목+저자+설명 포함)")
# Out:
# ✅ 새로운 FAISS 인덱스 생성 완료! (제목+저자+설명 포함)

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer

# ✅ 모델 로드 (BAAI/bge-m3)
model = SentenceTransformer("BAAI/bge-m3")
model.max_seq_length = 512

# ✅ FAISS 인덱스 로드 (업데이트된 버전 사용)
index = faiss.read_index("novel_index_cosine_v2.faiss")

# ✅ 소설 데이터 로드
with open("novel_data.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# ✅ 🔥 사용자 질문을 소설 설명처럼 변환
def transform_query(query):
    return f"이 소설의 제목과 주요 내용은 다음과 같습니다: {query}"

# ✅ 🔥 검색 함수 (쿼리 변형 + 벡터 변환)
def search_similar_novels(query, top_k=10):
    query_text = transform_query(query)  # ✅ 쿼리 변형 적용
    query_embedding = model.encode([query_text], normalize_embeddings=True, convert_to_numpy=True)
    faiss.normalize_L2(query_embedding)  # ✅ 벡터 정규화 적용

    distances, indices = index.search(query_embedding, top_k)

    results = []
    for i, idx in enumerate(indices[0]):
        if idx < len(novels):
            results.append({
                "rank": i+1,
                "title": novels[idx]["title"],
                "author": novels[idx]["author"],
                "link": novels[idx]["link"],
                "description": novels[idx]["description"],
                "similarity": float(distances[0][i])
            })

    return results

# ✅ 테스트 실행 (쿼리 입력)
query = """
도시락가게에서 일하는 여자가 있는데, 전남편을 우발적으로 살해했다.
이웃의 수학교사가 그 여자를 짝사랑하며, 그 여자를 돕기 위해 완벽한 알리바이를 만들어주고,
자신이 대신 죄를 뒤집어쓰려고 한다. 이 소설의 제목은 무엇인가요?
"""

# 🔍 최종 검색 실행
results = search_similar_novels(query)

# ✅ 검색 결과 출력
for res in results:
    print(f"{res['rank']}. {res['title']} ({res['similarity']:.4f})")
    print(f"👨‍💻 {res['author']}")
    print(f"🔗 {res['link']}")
    print(f"📖 {res['description'][:100]}...\n")
# Out:
# 1. 달콤한 살인 계획 (김서진 장편소설) (0.5658)
# 👨‍💻 김서진
# 🔗 https://search.shopping.naver.com/book/catalog/48242544621
# 📖 모든 것이 결핍된 여자가 세상을 향해 겨누는 뜨거운 칼끝
# 세계문학상 우수상 수상 작가 김서진, 10년 만의 신작
#
# 나 자신으로부터 도망치고 싶은 적이 있는가? 벗어날 수 없는 과거...
#
# 2. 도시락 (제30회 소설미학 신인소설상 장편소설부문 당선작) (0.5616)
# 👨‍💻 김선덕
# 🔗 https://search.shopping.naver.com/book/catalog/51342226802
# 📖 시대에 필요한 정신을 담아내고자 노력한 소설이다. 주인공이 재건축 중에 땅속에서 도시락을 발견했는데 부친 소유의 부동산 등기필증이 담겨있었다. 처음에는 이기적인 욕망으로 가득했지만...
#
# 3. 그녀가 마지막에 본 것은 (0.5607)
# 👨‍💻 마사키 도시카
# 🔗 https://search.shopping.naver.com/book/catalog/40827394639
# 📖 누구나 행복해야 할 크리스마스이브, 노숙인으로 추정되는 신원 미상의 중년 여성이 시신으로 발견된다. 딱딱한 콘크리트 바닥에 반듯하게 누워 있는 여성의 옷은 흐트러졌고 머리에는 둔기...
#
# 4. 한밤중의 마리오네트 (0.5558)
# 👨‍💻 치넨 미키토
# 🔗 https://search.shopping.naver.com/book/catalog/51896750620
# 📖 내가 살려낸 환자가 약혼자를 죽인 연쇄살인마라면?
# 토막 난 시신 옆에서 발견된 그는…
# 무고한 피해자인가, 아니면 끔찍한 살인마인가?!
#
# 하룻밤 사이에 사람을 토막 내는 엽기살인마,...
#
# 5. 치유를 파는 찻집 (0.5519)
# 👨‍💻 모리사와 아키오
# 🔗 https://search.shopping.naver.com/book/catalog/42074839626
# 📖 가슴이 뭉클해지는 감동 미스터리
# 기상천외한 방법으로 ‘치유를 파는’ 그녀에게
# 어느 날, 살인 예고장이 도착했다!
#
# 찻집 쇼와당의 사장인 키리코는 엉뚱하고 신기한 매력을 가진 미인이...
#
# 6. 움직이는 손가락 (0.5501)
# 👨‍💻 애거서 크리스티
# 🔗 https://search.shopping.naver.com/book/catalog/33435872629
# 📖 전지요양을 위해 조용한 시골마을로 내려간 남매는 생각지도 못한 기분 나쁜 사건에 휘말린다. 악의와 중상에 찬 익명의 편지가 마을사람들에게 무차별적으로 배달되면서 험담, 악의적 소문...
#
# 7. 용의자 X의 헌신 (갈릴레오 시리즈 3) (0.5489)
# 👨‍💻 히가시노 게이고
# 🔗 https://search.shopping.naver.com/book/catalog/32485526273
# 📖 정교한 살인수식에 도전하는 천재 물리학자의 집요한 추적이 시작된다!
#
# 《동급생》, 《백야행》의 작가 히가시노 게이고의 장편소설. 2006년 제134회 나오키 상 수상작이다. 일본 ...
#
# 8. 그날로 다시 돌아가 널 살리고 싶어 (우대경 장편소설) (0.5465)
# 👨‍💻 우대경
# 🔗 https://search.shopping.naver.com/book/catalog/39072822623
# 📖 촉법소년에게 아들을 잃은 은서. 그녀에게 건네진 낡은 일기장.
# 그 일기를 통해 시작된 타임슬립, 그리고 복수.
#
# “내가 과거로 가면 미래가 달라지기라도 하니? 우리 아들이 살아 돌...
#
# 9. 옥중금낭, 첫날밤의 살인사건 (큰글자책) (0.5447)
# 👨‍💻 작자 미상 지음, 서유경 옮김
# 🔗 https://search.shopping.naver.com/book/catalog/51408008630
# 📖 과거를 보러 서울에 올라온 장한응은 아이들의 장난으로 곤경에 처한 맹인 점쟁이를 구해 준다. 점쟁이는 그 사례로 점을 쳐 주는데, 세 가지 액운을 예언한다. 불에 타 죽을 운수와 ...
#
# 10. 옥중금낭, 첫날밤의 살인사건 (0.5436)
# 👨‍💻 작자 미상 지음, 서유경 옮김
# 🔗 https://search.shopping.naver.com/book/catalog/51398618626
# 📖 과거를 보러 서울에 올라온 장한응은 아이들의 장난으로 곤경에 처한 맹인 점쟁이를 구해 준다. 점쟁이는 그 사례로 점을 쳐 주는데, 세 가지 액운을 예언한다. 불에 타 죽을 운수와 ...

# %%
import faiss
import numpy as np
import json
from sentence_transformers import SentenceTransformer
from transformers import RagTokenizer, RagRetriever, RagSequenceForGeneration

# 1️⃣ RAG 모델 로드
rag_model_name = "facebook/rag-token-nq"

# 토크나이저 로드
tokenizer = RagTokenizer.from_pretrained(rag_model_name)

# FAISS 기반 RAG Retriever 설정 (RAG 모델 내에서 검색 기능 사용)
retriever = RagRetriever.from_pretrained(rag_model_name, index_name="exact", use_dummy_dataset=True)

# RAG 모델 로드
rag_model = RagSequenceForGeneration.from_pretrained(rag_model_name, retriever=retriever)

# 2️⃣ BAAI/bge-m3 모델 로드 (벡터 검색용)
embedding_model = SentenceTransformer("BAAI/bge-m3")
embedding_model.max_seq_length = 512

# 3️⃣ FAISS 인덱스 로드
index = faiss.read_index("novel_index_cosine.faiss")

# 4️⃣ 소설 데이터 로드
with open("novel_data.json", "r", encoding="utf-8") as f:
    novels = json.load(f)

# 5️⃣ 검색 함수 (FAISS + RAG)
def search_with_rag(query, top_k=5):
    # 1. FAISS로 관련 소설 검색
    query_embedding = embedding_model.encode([query], normalize_embeddings=True, convert_to_numpy=True)
    faiss.normalize_L2(query_embedding)

    # FAISS 검색 수행
    distances, indices = index.search(query_embedding, top_k)

    # 검색된 소설 정보 수집
    retrieved_novels = []
    for i, idx in enumerate(indices[0]):
        if idx < len(novels):
            retrieved_novels.append({
                "rank": i+1,
                "title": novels[idx]["title"],
                "description": novels[idx]["description"]
            })

    # 2. RAG 모델을 사용해 자연어 응답 생성
    novel_context = "\n".join([f"{novel['title']}: {novel['description']}" for novel in retrieved_novels])
    prompt = f"사용자가 입력한 질문: {query}\n\n아래는 검색된 소설 정보입니다:\n{novel_context}\n\n이 정보 기반으로 사용자의 질문에 가장 적절한 소설을 추천해주세요."

    # RAG 모델을 사용하여 답변 생성
    inputs = tokenizer(prompt, return_tensors="pt")
    generated_output = rag_model.generate(**inputs)
    response = tokenizer.decode(generated_output[0], skip_special_tokens=True)

    return response, retrieved_novels

# 6️⃣ 테스트 검색
query = """
도시락 가게에서 일하는 여성이 있습니다. 그녀는 전남편을 우발적으로 살해했으며, 
그녀의 이웃인 수학 천재 남성은 그녀를 오랫동안 짝사랑해 왔습니다. 
이 남성은 그녀를 돕기 위해 완벽한 알리바이를 만들어주고, 
자신이 대신 죄를 뒤집어쓰려고 합니다. 이 이야기가 담긴 소설의 제목은 무엇인가요?
"""

response, results = search_with_rag(query)

# 7️⃣ 결과 출력
print("📌 AI 추천 응답 (RAG 기반):")
print(response)

print("\n🔍 FAISS 검색된 소설 목록:")
for res in results:
    print(f"{res['rank']}. {res['title']}")
# Out:
# /opt/anaconda3/envs/hi/lib/python3.10/site-packages/transformers/models/bart/configuration_bart.py:176: UserWarning: Please make sure the config includes `forced_bos_token_id=0` in future versions. The config can simply be saved and uploaded again to be fixed.
#   warnings.warn(
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'DPRQuestionEncoderTokenizerFast'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizer'.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'RagTokenizer'.
# The class this function is called from is 'BartTokenizerFast'.
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import shutil
import os

cache_dir = os.path.expanduser('~/.cache/huggingface/transformers/')
if os.path.exists(cache_dir):
    shutil.rmtree(cache_dir)
    print("Hugging Face 모델 캐시가 삭제되었습니다.")

# %%
import requests
import json
import time
import os
from urllib.parse import quote

# 네이버 API 환경변수 가져오기
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# 검색할 미스터리 소설 관련 키워드 (소설 제거)
query_list = [
    "미스터리", "추리", "서스펜스", "공포", 
    "스릴러", "심리 스릴러", "법정 스릴러", "탐정", "고전 추리",
    "해외 미스터리", "한국 미스터리"
]

# 전체 데이터 저장할 딕셔너리 (ISBN 기준 중복 방지)
book_dict = {}

# API 요청 함수 (부적절한 sort 값 수정)
def search_books(query, start=1, display=100, sort="sim"):
    url = "https://openapi.naver.com/v1/search/book.json"
    headers = {
        "X-Naver-Client-Id": CLIENT_ID,
        "X-Naver-Client-Secret": CLIENT_SECRET
    }
    params = {
        "query": query,  # ✅ URL 인코딩 적용
        "display": display,
        "start": start,
        "sort": sort  # ✅ "sim" 또는 "date"만 사용 (count 제거)
    }

    response = requests.get(url, headers=headers, params=params)
    response.encoding = 'utf-8'

    if response.status_code == 400:
        print(f"❌ API 요청 실패 (400): {query}, start={start}")
        print("📌 응답 메시지:", response.text)
        return []

    if response.status_code == 200:
        data = response.json()
        if data.get("total", 0) == 0:  # ✅ 검색 결과 없음 처리
            print(f"❌ '{query}' 검색 결과 없음. 건너뜀.")
            return []
        return data["items"]
    
    print(f"❌ API 요청 실패 ({response.status_code}): {query}, start={start}")
    return []

# 여러 검색어와 정렬 방식으로 데이터 수집 (sort 옵션 수정)
for query in query_list:
    for sort_option in ["sim", "date"]:  # ✅ "count" 제거
        for start in range(1, 1000, 100):  # 최대 1000권까지 확보
            books = search_books(query, start, sort=sort_option)
            if not books:
                break

            for book in books:
                isbn = book.get("isbn", "")
                if isbn and isbn not in book_dict:  # ISBN 기준 중복 제거
                    book_dict[isbn] = book
            
            time.sleep(1)  # ✅ 1초 대기 (API 제한 방지)

# JSON 파일로 저장
with open("mystery_books_10000.json", "w", encoding="utf-8") as f:
    json.dump(list(book_dict.values()), f, ensure_ascii=False, indent=4)  # ✅ UTF-8 저장 유지

print(f"✅ 총 {len(book_dict)}권의 미스터리 소설 데이터 저장 완료!")
# Out:
# ✅ 총 5683권의 미스터리 소설 데이터 저장 완료!

# %%
import requests
import os
from urllib.parse import quote

CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

query = "미스터리"  # 테스트용 키워드

url = "https://openapi.naver.com/v1/search/book.json"
headers = {
    "X-Naver-Client-Id": CLIENT_ID,
    "X-Naver-Client-Secret": CLIENT_SECRET
}
params = {
    "query": query,
    "sort": "sim"
}

# ✅ 실제 API 요청 URL 확인
request_url = f"{url}?query={params['query']}&display=10&sort=sim"
print(f"📌 실제 요청 URL: {request_url}")

response = requests.get(url, headers=headers, params=params)

if response.status_code == 200:
    data = response.json()
    print("✅ API 응답 데이터:", data)
else:
    print(f"❌ API 요청 실패: {response.status_code}")
    print("응답 메시지:", response.text)
# Out:
# 📌 실제 요청 URL: https://openapi.naver.com/v1/search/book.json?query=미스터리&display=10&sort=sim
# ✅ API 응답 데이터: {'lastBuildDate': 'Thu, 20 Feb 2025 17:23:35 +0900', 'total': 2776, 'start': 1, 'display': 10, 'items': [{'title': '당신이 누군가를 죽였다', 'link': 'https://search.shopping.naver.com/book/catalog/49073690634', 'image': 'https://shopping-phinf.pstatic.net/main_4907369/49073690634.20240713091011.jpg', 'author': '히가시노 게이고', 'discount': '17820', 'publisher': '북다', 'pubdate': '20240723', 'isbn': '9791170611561', 'description': '히가시노 게이고가 재현한\n황금시대 본격 미스터리\n\n히가시노 게이고 101번째 작품에서 미스터리의 원점으로!\n\n“미스터리란 어떤 소설인가? 라는 질문을 들었을 때 \n이런 소설이다, 라고 대답할 수 있는 작품입니다.”\n _히가시노 게이고\n\n일본 최고의 베스트셀러 작가 히가시노 게이고의 최신 장편소설『당신이 누군가를 죽였다』가 북다에서 출간되었다. 작품은 장르문학계의 거장인 작가가 101번째 작품을 맞아 추리소설의 원점으로 돌아가 ‘황금시대 미스터리’의 매력을 유감없이 발휘한 걸작으로 평단과 독자의 호평을 받고 있다. 1986년 발표된 『졸업』을 시작으로 장장 38년째 이어진 히가시노 게이고 미스터리의 정수인 〈가가 형사 시리즈〉 열두 번째 작품이기도 한 신작은, 2023년 출간 즉시 일본 서점 미스터리 판매 전체 1위를 석권하며 세월이 지나도 변치 않는 시리즈의 인기를 증명했다.\n『당신이 누군가를 죽였다』는 호화 별장지에 여름 휴가를 온 다섯 가족의 파티로 시작한다. 하지만 그날 밤, 다섯 명이 살해당하고 한 명이 다치는 사건이 벌어지고, 살아남은 사람들은 참극의 진상을 밝히기 위해 검증회를 연다. 그 자리에 장기 휴가 중이던 형사 ‘가가 교이치로’가 참석하고, 그는 사람들이 저마다 감추고 있던 비밀을 파헤치기 시작한다.\n작품은 재미있는 본격 미스터리의 필수 요소를 몹시 정교하게 구현하고 있다. 진상을 안 이후에는 혀를 내두르며 다시 읽게 되는 교묘한 복선, 이제 알았다 싶으면 또 다른 답을 내놓는 연이은 반전, 그리고 누구도 예측할 수 없는 충격적인 결말까지. 10년 만에 돌아온 ‘가가 교이치로’ 형사가 안내하는 이 흥미진진한 미스터리 소설의 구상 배경에 대해 작가는 “시리즈 중에서도 본격 요소가 짙다고 평가받는 『둘 중 누군가가 그녀를 죽였다』와 『내가 그를 죽였다』의 계보를 잇는 작품”이라고 이야기했다. 또 “미스터리란 어떤 소설인가? 라는 질문을 들었을 때, 이런 소설이다, 라고 대답할 수 있는 작품입니다.”라고 자신 있게 신작을 소개했다.\n\n■ 내용 소개\n\n한여름 호화 별장지에서 일어난 연속 살인사건. 자수한 범인은 범행 과정에 대해 입을 다문다.\n살아남은 사람들은 사건의 진상을 밝히고자 검증회를 열고, 그 자리에 휴가 중인 가가 교이치로 형사가 참석한다. 재구성되는 비극 속, 예측하지 못한 진실이 그 정체를 드러낸다.\n사랑하는 가족을 잃은 건 우연일까, 필연일까.'}, {'title': '용의자 X의 헌신 (제134회 나오키상 수상작, 갈릴레오 시리즈 3)', 'link': 'https://search.shopping.naver.com/book/catalog/32463541483', 'image': 'https://shopping-phinf.pstatic.net/main_3246354/32463541483.20230815075809.jpg', 'author': '히가시노 게이고', 'discount': '16920', 'publisher': '재인', 'pubdate': '20170830', 'isbn': '9788990982704', 'description': '정교한 살인수식에 도전하는 천재 물리학자의 집요한 추적이 시작된다!\n\n히가시노 게이고 문학의 정수로 일컬어지는 추리 소설 『용의자 X의 헌신』. 일본 문학 전문 번역가 양억관이 자신의 번역을 대폭 손질해 원작이 지닌 문학적 향기와 감동을 오롯이 되살려냈다. 일본 추리소설에서 흔히 보여 지는 잔혹함이나 엽기 호러가 아닌 사랑과 헌신이라는 고전적이며 낭만적인 테마를 미로처럼 섬세하게 엮어낸 슬프고 아름다운 이야기로, 제134회 나오키상을 수상했다. \n\n도쿄 에도가와 인근 한 연립 주택에서 중년 남자가 모녀에 의해 살해된다. 숨진 남자는 도가시. 한때 술집 호스티스였으나 지금은 도시락 가게에서 일하면서 첫 남편 사이에 낳은 딸 마사토를 키우고 있는 여자, 하나오카 야스코의 이혼한 두 번째 남편이다. 돈을 갈취하기 위해 찾아와 폭력을 휘두르는 그를 모녀가 우발적으로 목 졸라 살해하고, 우연히 사건을 눈치 채게 된 옆집 사는 고등학교 수학교사 이시가미가 그녀를 돕겠다고 나선다. \n\n마음속으로 야스코를 깊이 사모해 왔던 이시가미는 완전범죄 만들기에 나서게 된다. 대학 시절 백 년에 한번 나올까 말까 한 천재라는 소리를 듣던 그는 빈틈없는 알리바이를 만들고, 경찰 심문에 대응하는 요령까지 모녀에게 세세히 지시하여 경찰의 수사를 혼선에 빠뜨린다. 사건 다음날, 얼굴을 알아볼 수 없는 중년 남자의 변사체가 발견되고, 경찰은 그것이 도가시의 사체임을 밝혀낸다. \n\n야스코가 유력한 용의자로 수사선상에 떠오르고, 경찰은 그녀의 알리바이를 확인하는 데 총력을 기울이지만 별다른 소득을 얻지 못한다. 수사가 답보 상태에 빠진 상황에서 형사 구사나기는 자신이 어려움에 처할 때마다 등장해 사건 해결의 실마리를 던져주던 천재 물리학자, 일명 ‘탐정 갈릴레오’, 유가와에게 S.O.S를 친다. 유가와는 구사나기에게 야스코의 이웃인 이시가미의 이름을 듣고 그가 대학 시절 자신과 전공은 다르지만 서로의 천재성을 인정했던 동창생이라는 사실을 기억해내고, 이시가미가 사건에 개입했음을 직감하는데…….'}, {'title': '악의', 'link': 'https://search.shopping.naver.com/book/catalog/32441026328', 'image': 'https://shopping-phinf.pstatic.net/main_3244102/32441026328.20230829091904.jpg', 'author': '히가시노 게이고', 'discount': '15120', 'publisher': '현대문학', 'pubdate': '20190725', 'isbn': '9788972750031', 'description': '히가시노 게이고가 가장 사랑하는 캐릭터 「가가 형사 시리즈」 전면 개정판!\n\n냉철한 머리, 뜨거운 심장, 빈틈없이 날카로운 눈매로 범인을 쫓지만 어떤 상황에서도 인간에 대한 따뜻한 배려를 잃지 않는 불세출의 형사 가가 교이치로. 시리즈 캐릭터 사용을 최대한 자제하는 히가시노 게이고가 이례적으로 30년 가까이 애정을 쏟으면서 성장시킨 인물로, 작가 자신이 가장 사랑하는 캐릭터이자 그의 페르소나라고 불린다.\n\n「가가 형사 시리즈」는 가가 형사의 대학 시절부터 네리마 경찰서 소속 형사 시기까지를 다룬 7권의 작품을 아우르는 시리즈로, 이번 개정판에서 역자 양윤옥은 10여 년 전 자신의 번역을 대대적으로 수정, 보완했다. 시대의 흐름에 따라 바뀐 한글어문규정을 적용하고 기존 판본의 크고 작은 오류를 바로잡은 것은 물론, 권별로 문장 전체를 3,000군데 이상 다듬어 읽는 맛을 온전히 느낄 수 있도록 했다. 아울러 각 권에 대한 기발한 해석이 빛나는 그림작가 최환욱의 표지화로 시리즈로서의 통일성을 더하여 소장 가치를 높였다.\n\n「가가 형사 시리즈」 제3권 『악의』는 히가시노 게이고의 초기 대표작이자 많은 미스터리 팬들의 필독서 겸 입문서로 사랑받는 소설이다. 한 인기 작가의 죽음에 얽힌 기나긴 악의의 여정을 탐구해가는 이 작품은 번뜩이는 두뇌와 끈기를 자랑하는, 완성형의 가가 교이치로를 만날 수 있을 뿐만 아니라, 사회 과목 교사였던 그가 어째서 교직에서 물러 ...

# %%
import json
import pandas as pd
import re

# 📌 저장된 JSON 파일 불러오기
with open("mystery_books_10000.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# 📌 데이터프레임 변환
df = pd.DataFrame(books_data)

# 📌 1️⃣ ISBN 기준 중복 제거
df.drop_duplicates(subset=["isbn"], inplace=True)

# 📌 2️⃣ 줄거리(description)이 없는 책 제거
df = df[df["description"].str.strip() != ""]

# 📌 3️⃣ 특수문자 제거 (HTML 태그, 공백 등)
df["description"] = df["description"].apply(lambda x: re.sub(r"<.*?>", "", x).strip())  # HTML 태그 제거
df["title"] = df["title"].apply(lambda x: re.sub(r"\[.*?\]|\(.*?\)", "", x).strip())  # 불필요한 괄호 제거

# 📌 4️⃣ 정제된 데이터 저장
cleaned_books = df.to_dict(orient="records")

with open("clean_mystery_books.json", "w", encoding="utf-8") as f:
    json.dump(cleaned_books, f, ensure_ascii=False, indent=4)

# 📌 정제된 데이터 확인

df.head()
print(f"✅ 정제 완료! 중복 제거 후 {len(df)}권 저장 완료!")
# Out:
# ✅ 정제 완료! 중복 제거 후 5572권 저장 완료!

# %%
import requests
import json
import os
import time

# ✅ 네이버 API 환경변수 사용
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# ✅ 정제된 책 데이터 로드
with open("clean_mystery_books.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 네이버 블로그 검색 API 요청 함수 (429 오류 방지)
def search_blog_reviews(query, display=5, retries=3):
    url = "https://openapi.naver.com/v1/search/blog.json"
    headers = {
        "X-Naver-Client-Id": CLIENT_ID,
        "X-Naver-Client-Secret": CLIENT_SECRET
    }
    params = {
        "query": query,
        "display": display,
        "sort": "sim"
    }

    for attempt in range(retries):  # ✅ 최대 3번 재시도
        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 200:
            return response.json()["items"]
        
        elif response.status_code == 429:
            wait_time = (attempt + 1) * 5  # ✅ 5초, 10초, 15초 대기
            print(f"🚨 429 오류: 요청 속도 제한 초과! ({query}) - {attempt + 1}번째 재시도 후 {wait_time}초 대기...")
            time.sleep(wait_time)

        else:
            print(f"❌ API 요청 실패: {response.status_code}, 검색어: {query}")
            return []

    return []  # 3번 재시도 후에도 실패하면 빈 리스트 반환

# ✅ 순차적 크롤링 실행
book_reviews = {}

for index, book in enumerate(books_data, 1):
    title = book["title"]
    reviews = search_blog_reviews(title)
    
    if reviews:
        book_reviews[title] = [review["description"] for review in reviews]

    print(f"📖 {index}/{len(books_data)} - '{title}' 리뷰 수집 완료! ({len(reviews)}개)")
    
    time.sleep(1.5)  # ✅ API 요청 간격 조정 (429 방지)

# ✅ 크롤링된 블로그 리뷰를 JSON 파일로 저장
with open("blog_reviews_sequential.json", "w", encoding="utf-8") as f:
    json.dump(book_reviews, f, ensure_ascii=False, indent=4)

print(f"✅ 총 {len(book_reviews)}권의 블로그 리뷰 저장 완료!")
# Out:
# 📖 1/5572 - '당신이 누군가를 죽였다' 리뷰 수집 완료! (5개)
# 📖 2/5572 - '용의자 X의 헌신' 리뷰 수집 완료! (5개)
# 📖 3/5572 - '악의' 리뷰 수집 완료! (5개)
# 📖 4/5572 - '비정근' 리뷰 수집 완료! (5개)
# 📖 5/5572 - '셜록 홈스의 모험' 리뷰 수집 완료! (5개)
# 📖 6/5572 - '리버 2' 리뷰 수집 완료! (5개)
# 📖 7/5572 - '리버 1' 리뷰 수집 완료! (5개)
# 📖 8/5572 - '미로장의 참극' 리뷰 수집 완료! (5개)
# 📖 9/5572 - '얼음 속의 여인' 리뷰 수집 완료! (5개)
# 📖 10/5572 - '성소의 참새' 리뷰 수집 완료! (5개)
# 📖 11/5572 - '귀신 들린 아이' 리뷰 수집 완료! (5개)
# 📖 12/5572 - '죽은 자의 몸값' 리뷰 수집 완료! (5개)
# 📖 13/5572 - '아이 윌 파인드 유' 리뷰 수집 완료! (5개)
# 📖 14/5572 - '고행의 순례자' 리뷰 수집 완료! (5개)
# 📖 15/5572 - '캐드펠 수사 시리즈' 리뷰 수집 완료! (5개)
# 📖 16/5572 - '청과 부동명왕' 리뷰 수집 완료! (5개)
# 📖 17/5572 - '아서 코난 도일, 선상 미스터리 단편 컬렉션' 리뷰 수집 완료! (5개)
# 📖 18/5572 - '아름답고 위험한 이름, 비너스' 리뷰 수집 완료! (5개)
# 📖 19/5572 - '시체 한 구가 더 있다' 리뷰 수집 완료! (5개)
# 📖 20/5572 - '수도사의 두건' 리뷰 수집 완료! (5개)
# 📖 21/5572 - '세인트자일스의 나환자' 리뷰 수집 완료! (5개)
# 📖 22/5572 - '성 베드로 축일' 리뷰 수집 완료! (5개)
# 📖 23/5572 - '에도가와 란포 기담집' 리뷰 수집 완료! (5개)
# 📖 24/5572 - '유골에 대한 기이한 취향' 리뷰 수집 완료! (5개)
# 📖 25/5572 - '마녀와의 7일' 리뷰 수집 완료! (5개)
# 📖 26/5572 - '추리소설가의 살인사건' 리뷰 수집 완료! (5개)
# 📖 27/5572 - '백설공주에게 죽음을' 리뷰 수집 완료! (5개)
# 📖 28/5572 - '장난감 괴물' 리뷰 수집 완료! (5개)
# 📖 29/5572 - '긴다이치 고스케 걸작선' 리뷰 수집 완료! (5개)
# 📖 30/5572 - '적월 세번째 공포단편' 리뷰 수집 완료! (2개)
# 📖 31/5572 - '셜록 홈즈 베스트12' 리뷰 수집 완료! (5개)
# 📖 32/5572 - '블랙 쇼맨과 운명의 바퀴' 리뷰 수집 완료! (5개)
# 📖 33/5572 - '히가시노 게이고 설산 시리즈' 리뷰 수집 완료! (5개)
# 📖 34/5572 - '여우의 계절' 리뷰 수집 완료! (5개)
# 📖 35/5572 - '페어워닝' 리뷰 수집 완료! (5개)
# 📖 36/5572 - '갈까마귀 살인사건' 리뷰 수집 완료! (5개)
# 📖 37/5572 - '금단의 마술' 리뷰 수집 완료! (5개)
# 📖 38/5572 - '죄의 경계' 리뷰 수집 완료! (5개)
# 📖 39/5572 - '닌자의 딸' 리뷰 수집 완료! (5개)
# 📖 40/5572 - '사자 츠나구 2' 리뷰 수집 완료! (5개)
# 📖 41/5572 - '괴도신사 아르센뤼팽' 리뷰 수집 완료! (5개)
# 📖 42/5572 - '레이크사이드' 리뷰 수집 완료! (5개)
# 📖 43/5572 - '페어리테일 1' 리뷰 수집 완료! (5개)
# 📖 44/5572 - '삼가 이와 같이 아뢰옵니다' 리뷰 수집 완료! (5개)
# 📖 45/5572 - '지옥: 신의 실수' 리뷰 수집 완료! (5개)
# 📖 46/5572 - '치유를 파는 찻집' 리뷰 수집 완료! (5개)
# 📖 47/5572 - '사자 츠나구 1' 리뷰 수집 완료! (5개)
# 📖 48/5572 - '매스커레이드 게임' 리뷰 수집 완료! (5개)
# 📖 49/5572 - '해피 벌쓰데이' 리뷰 수집 완료! (5개)
# 📖 50/5572 - '아르센 뤼팽과 셜록홈즈의 대결' 리뷰 수집 완료! (5개)
# 📖 51/5572 - '인플루언스' 리뷰 수집 완료! (5개)
# 📖 52/5572 - '형사 변호인' 리뷰 수집 완료! (5개)
# 📖 53/5572 - '컬트 1' 리뷰 수집 완료! (5개)
# 📖 54/5572 - '컬트 2' 리뷰 수집 완료! (5개)
# 📖 55/5572 - '컬트 3' 리뷰 수집 완료! (5개)
# 📖 56/5572 - '모성' 리뷰 수집 완료! (5개)
# 📖 57/5572 - '가모 저택 사건' 리뷰 수집 완료! (5개)
# 📖 58/5572 - '클론' 리뷰 수집 완료! (5개)
# 📖 59/5572 - '새왕의 방패' 리뷰 수집 완료! (5개)
# 📖 60/5572 - '탐정 페이터의 수사 일지' 리뷰 수집 완료! (3개)
# 📖 61/5572 - '굿 걸 배드 걸' 리뷰 수집 완료! (5개)
# 📖 62/5572 - '셜록홈즈 베스트 단편선 12' 리뷰 수집 완료! (5개)
# 📖 63/5572 - '나이츠 갬빗' 리뷰 수집 완료! (5개)
# 📖 64/5572 - '희망의 끈' 리뷰 수집 완료! (5개)
# 📖 65/5572 - '추리의 민족' 리뷰 수집 완료! (5개)
# 📖 66/5572 - '동물농장' 리뷰 수집 완료! (5개)
# 📖 67/5572 - '박스 1' 리뷰 수집 완료! (5개)
# 📖 68/5572 - '박스 2' 리뷰 수집 완료! (5개)
# 📖 69/5572 - '박스 3' 리뷰 수집 완료! (5개)
# 📖 70/5572 - '미러하우스' 리뷰 수집 완료! (5개)
# 📖 71/5572 - '돌이킬 수 없는 약속' 리뷰 수집 완료! (5개)
# 📖 72/5572 - '가면산장 살인사건' 리뷰 수집 완료! (5개)
# 📖 73/5572 - '외사랑' 리뷰 수집 완료! (5개)
# 📖 74/5572 - '고딕 X 호러 X 제주' 리뷰 수집 완료! (5개)
# 📖 75/5572 - '가족 대행소 에프' 리뷰 수집 완료! (2개)
# 📖 76/5572 - '봉제인형 살인사건 시리즈 소장본 박스 세트' 리뷰 수집 완료! (5개)
# 📖 77/5572 - '루팡의 딸 시리즈 소장본 박스 세트' 리뷰 수집 완료! (5개)
# 📖 78/5572 - '악연' 리뷰 수집 완료! (5개)
# 📖 79/5572 - '마녀의 은신처' 리뷰 수집 완료! (5개)
# 📖 80/5572 - '셜록 홈스 베스트 장편선 2' 리뷰 수집 완료! (5개)
# 📖 81/5572 - '루팡의 딸 5' 리뷰 수집 완료! (5개)
# 📖 82/5572 - '나중에' 리뷰 수집 완료! (5개)
# 📖 83/5572 - '아기를 부르는 그림' 리뷰 수집 완료! (5개)
# 📖 84/5572 - '에도가와 란포 호반정 사건' 리뷰 수집 완료! (5개)
# 📖 85/5572 - '소녀 지옥' 리뷰 수집 완료! (5개)
# 📖 86/5572 - '형사의 분노' 리뷰 수집 완료! (5개)
# 📖 87/5572 - '셜록 홈스의 모험' 리뷰 수집 완료! (5개)
# 📖 88/5572 - '흡혈귀' 리뷰 수집 완료! (5개)
# 📖 89/5572 - '아폴론 저축은행' 리뷰 수집 완료! (5개)
# 📖 90/5572 - '하카타 돈코츠 라멘즈 5' 리뷰 수집 완료! (5개)
# 📖 91/5572 - '하카타 돈코츠 라멘즈 6' 리뷰 수집 완료! (5개)
# 📖 92/5572 - '영원한 우정으로 2' 리뷰 수집 완료! (5개)
# 📖 93/5572 - '영원한 우정으로 1' 리뷰 수집 완료! (5개)
# 📖 94/5572 - '백조와 박쥐' 리뷰 수집 완료! (5개)
# 📖 95/5572 - '에도가와 란포 단편 추리소설 1' 리뷰 수집 완료! (5개)
# 📖 96/5572 - '사카구치 안고 추리소설 명작 1' 리뷰 수집 완료! (5개)
# 📖 97/5572 - '미궁' 리뷰 수집 완료! (5개)
# 📖 98/5572 - '야미하라' 리뷰 수집 완료! (5개)
# 📖 99/5572 - '인내상자' 리뷰 수집 완료! (5개)
# 📖 100/5572 - '봄에 나는 없었다' 리뷰 수집 완료! (5개)
# 📖 101/5572 - '딸은 딸이다' 리뷰 수집 완료! (5개)
# 📖 102/5572 - '살인의 문 1' 리뷰 수집 완료! (5개)
# 📖 103/5572 - '루팡의 딸 4' 리뷰 수집 완료! (5개)
# 📖 104/5572 - '사라지는 아들' 리뷰 수집 완료! (5개)
# 📖 105/5572 - '장미의 이름 세트' 리뷰 수집 완료! (5개)
# 📖 106/5572 - '질풍론도' 리뷰 수집 완료! (5개)
# 📖 107/5572 - '표정 없는 검사의 사투' 리뷰 수집 완료! (5개)
# 📖 108/5572 - '범인 없는 살인의 밤' 리뷰 수집 완료! (5개)
# 📖 109/5572 - '용의자 X의 헌신' 리뷰 수집 완료! (5개)
# 📖 110/5572 - '숙명' 리뷰 수집 완료! (5개)
# 📖 111/5572 - '회랑정 살인사건' 리뷰 수집 완료! (5개)
# 📖 112/5572 - '잠자는 숲' 리뷰 수집 완료! (5개)
# 📖 113/5572 - '플래티나 데이터' 리뷰 수집 완료! (5개)
# 📖 114/5572 - '둘 중 누군가 그녀를 죽였다' 리뷰 수집 완료! (5개)
# 📖 115/5572 - '루팡의 딸' 리뷰 수집 완료! (5개)
# 📖 116/5572 - '호랑이' 리뷰 수집 완료! (5개)
# 📖 117/5572 - '루팡의 딸 3' 리뷰 수집 완료! (5개)
# 📖 118/5572 - '사악한 늑대' 리뷰 수집 완료! (5개)
# 📖 119/5572 - '어센덴' 리뷰 수집 완료! (5개)
# 📖 120/5572 - '루팡의 딸 2' 리뷰 수집 완료! (5개)
# 📖 121/5572 - '핼러윈 파티  69 ㅣ 영화 '베니스 유령 살인사건' 원작)' 리뷰 수집 완료! (5개)
# 📖 122/5572 - '다섯 마리 아기 돼지' 리뷰 수집 완료! (5개)
# 📖 123/5572 - '낙원 2' 리뷰 수집 완료! (5개)
# 📖 124/5572 - '깨어진 거울' 리뷰 수집 완료! (5개)
# 📖 125/5572 - '크리스마스 푸딩의 모험' 리뷰 수집 완료! (5개)
# 📖 126/5572 - '장미의 이름' 리뷰 수집 완료! (5개)
# 📖 127/5572 - '마지막으로 죽음이 오다' 리뷰 수집 완료! (5개)
# 📖 128/5572 - '시계들  57)' 리뷰 수집 완료! (5개)
# 📖 129/5572 - '세븐 다이얼스 미스터리  35)' 리뷰 수집 완료! (5개)
# 📖 130/5572 - '잠자는 살인  73)' 리뷰 수집 완료! (5개)
# 📖 131/5572 - '갈색 양복의 사나이' 리뷰 수집 완료! (5개)
# 📖 132/5572 - '빛나는 청산가리  61)' 리뷰 수집 완료! (5개)
# 📖 133/5572 - '에지웨어 경의 죽음' 리뷰 수집 완료! (5개)
# 📖 134/5572 - '밤 산책' 리뷰 수집 완료! (5개)
# 📖 135/5572 - '죽은 자의 어리석음  72)' 리뷰 수집 완료! (5개)
# 📖 136/5572 - '히코리 디코리 독  71)' 리뷰 수집 완료! (5개)
# 📖 137/5572 - '애거서 크리스티 전집 21' 리뷰 수집 완료! (5개)
# 📖 138/5572 - '빛이 있는 동안' 리뷰 수집 완료! (5개)
# 📖 139/5572 - '엄지손가락의 아픔  60)' 리뷰 수집 완료! (5개)
# 📖 140/5572 - '푸아로의 크리스마스' 리뷰 수집 완료! (5개)
# 📖 141/5572 - '골프장 살인사건' 리뷰 수집 완료! (5개)
# 📖 142/5572 - '부부 탐정' 리뷰 수집 완료! (5개)
# 📖 143/5572 - '슬픈 사이프러스  47)' 리뷰 수집 완료! (5개)
# 📖 144/5572 - '가면무도회 1' 리뷰 수집 완료! (5개)
# 📖 145/5572 - '코끼리는 기억한다  59)' 리뷰 수집 완료! (5개)
# 📖 146/5572 - '신비의 사나이 할리퀸' 리뷰 수집 완료! (5개)
# 📖 147/5572 - '가면무도회 2' 리뷰 수집 완료! (5개)
# 📖 148/5572 - '시계관의 살인' 리뷰 수집 완료! (5개)
# 📖 149/5572 - '그들은 바그다드로 갔다  63)' 리뷰 수집 완료! (5개)
# 📖 150/5572 - '둔색환시행' 리뷰 수집 완료! (5개)
# 📖 151/5572 - '메소포타미아의 살인' 리뷰 수집 완료! (5개)
# 📖 152/5572 - '삼수탑' 리뷰 수집 완료! (5개)
# 📖 153/5572 - '0시를 향하여' 리뷰 수집 완료! (5개)
# 📖 154/5572 - 'ABC 살인사건' 리뷰 수집 완료! (5개)
# 📖 155/5572 - '백일홍 나무 아래' 리뷰 수집 완료! (5개)
# 📖 156/5572 - '프랑크푸르트 행 승객  66)' 리뷰 수집 완료! (5개)
# 📖 157/5572 - '서재의 시체' 리뷰 수집 완료! (5개)
# 📖 158/5572 - '회상 속의 살인' 리뷰 수집 완료! (5개)
# 📖 159/5572 - '아웃사이더 1~2 세트 - 전2권' 리뷰 수집 완료! (5개)
# 📖 160/5572 - '애거서 크리스티 전집 26   26)' 리뷰 수집 완료! (5개)
# 📖 161/5572 - '세상의 봄' 리뷰 수집 완료! (5개)
# 📖 162/5572 - '삼나무 관' 리뷰 수집 완료! (5개)
# 📖 163/5572 - '위치우드 살인사건' 리뷰 수집 완료! (5개)
# 📖 164/5572 - '벚꽃, 다시 벚꽃' 리뷰 수집 완료! (5개)
# 📖 165/5572 - '누명' 리뷰 수집 완료! (5개)
# 📖 166/5572 - '애거서 크리스티 에디터스 초이스 세트' 리뷰 수집 완료! (5개)
# 📖 167/5572 - '바그다드의 비밀' 리뷰 수집 완료! (5개)
# 📖 168/5572 - '패딩턴발 4시 50분' 리뷰 수집 완료! (5개)
# 📖 169/5572 - '비탄의 문 1' 리뷰 수집 완료! (5개)
# 📖 170/5572 - '끝없는 밤' 리뷰 수집 완료! (5개)
# 📖 171/5572 - '욕망을 파는 집 1' 리뷰 수집 완료! (5개)
# 📖 172/5572 - '운명의 문' 리뷰 수집 완료! (5개)
# 📖 173/5572 - '비밀결사' 리뷰 수집 완료! (5개)
# 📖 174/5572 - '비탄의 문 2' 리뷰 수집 완료! (5개)
# 📖 175/5572 - '미스마플 13수수께끼' 리뷰 수집 완료! (5개)
# 📖 176/5572 - '크리스마스 살인' 리뷰 수집 완료! (5개)
# 📖 177/5572 - '골프장 살인사건' 리뷰 수집 완료! (5개)
# 📖 178/5572 - '죽음의 사냥개' 리뷰 수집 완료! (5개)
# 📖 179/5572 - '셜록 홈즈 전집 세트' 리뷰 수집 완료! (5개)
# 📖 180/5572 - '주머니 속의 죽음' 리뷰 수집 완료! (5개)
# 📖 181/5572 - '코끼리는 기억한다' 리뷰 수집 완료! (5개)
# 📖 182/5572 - '죽음을 향한 발자국' 리뷰 수집 완료! (5개)
# 📖 183/5572 - '진상' 리뷰 수집 완료! (5개)
# 📖 184/5572 - '밤이 끝나는 곳' 리뷰 수집 완료! (5개)
# 📖 185/5572 - '사라진 왕국의 성' 리뷰 수집 완료! (5개)
# 📖 186/5572 - '엔드하우스의 비극' 리뷰 수집 완료! (5개)
# 📖 187/5572 - '헤이즐무어 살인사건' 리뷰 수집 완료! (5개)
# 📖 188/5572 - '0시간으로' 리뷰 수집 완료! (5개)
# 📖 189/5572 - '리스터데일 미스터리' 리뷰 수집 완료! (5개)
# 📖 190/5572 - '빅 포' 리뷰 수집 완료! (5개)
# 📖 191/5572 - '움직이는 손가락' 리뷰 수집 완료! (5개)
# 📖 192/5572 - '3막의 비극' 리뷰 수집 완료! (5개)
# 📖 193/5572 - '나일에서 죽다' 리뷰 수집 완료! (5개)
# 📖 194/5572 - '푸코의 진자 1' 리뷰 수집 완료! (5개)
# 📖 195/5572 - '사흘 그리고 한 인생' 리뷰 수집 완료! (5개)
# 📖 196/5572 - '주머니속의 죽음' 리뷰 수집 완료! (5개)
# 📖 197/5572 - '히코리 디코리 살인사건' 리뷰 수집 완료! (5개)
# 📖 198/5572 - '마술 살인' 리뷰 수집 완료! (5개)
# 📖 199/5572 - '움직이는 손가락' 리뷰 수집 완료! (5개)
# 📖 200/5572 - '복수의 여신' 리뷰 수집 완료! (5개)
# 📖 201/5572 - '벙어리 목격자' 리뷰 수집 완료! (5개)
# 📖 202/5572 - '푸코의 진자 2' 리뷰 수집 완료! (5개)
# 📖 203/5572 - '부머랭 살인사건' 리뷰 수집 완료! (5개)
# 📖 204/5572 - '애국 살인' 리뷰 수집 완료! (5개)
# 📖 205/5572 - '마지막으로 죽음이 온다' 리뷰 수집 완료! (5개)
# 📖 206/5572 - '예고살인' 리뷰 수집 완료! (5개)
# 📖 207/5572 - '목사관 살인사건' 리뷰 수집 완료! (5개)
# 📖 208/5572 - '침니스의 비밀' 리뷰 수집 완료! (5개)
# 📖 209/5572 - 'N 또는 M' 리뷰 수집 완료! (5개)
# 📖 210/5572 - '헤라클레스의 모험' 리뷰 수집 완료! (5개)
# 📖 211/5572 - '4개의 시계' 리뷰 수집 완료! (5개)
# 📖 212/5572 - '욕망을 파는 집 2' 리뷰 수집 완료! (5개)
# 📖 213/5572 - '끝없는 밤에 태어나다' 리뷰 수집 완료! (5개)
# 📖 214/5572 - '우리 이웃의 범죄' 리뷰 수집 완료! (5개)
# 📖 215/5572 - '명탐정 파커 파인' 리뷰 수집 완료! (5개)
# 📖 216/5572 - '13인의 만찬' 리뷰 수집 완료! (5개)
# 📖 217/5572 - '푸른 열차의 죽음' 리뷰 수집 완료! (5개)
# 📖 218/5572 - '커튼' 리뷰 수집 완료! (5개)
# 📖 219/5572 - '장례식을 마치고' 리뷰 수집 완료! (5개)
# 📖 220/5572 - '장례식을 마치고' 리뷰 수집 완료! (5개)
# 📖 221/5572 - '갈색 옷을 입은 사나이' 리뷰 수집 완료! (5개)
# 📖 222/5572 - '포와로 수사집' 리뷰 수집 완료! (5개)
# 📖 223/5572 - '깨어진 거울' 리뷰 수집 완료! (5개)
# 📖 224/5572 - '죽음과의 약속' 리뷰 수집 완료! (5개)
# 📖 225/5572 - 'ABC 살인사건' 리뷰 수집 완료! (5개)
# 📖 226/5572 - '크리스마스 살인' 리뷰 수집 완료! (5개)
# 📖 227/5572 - '스타일즈 저택괴사건' 리뷰 수집 완료! (5개)
# 📖 228/5572 - '움직이는 손가락' 리뷰 수집 완료! (5개)
# 📖 229/5572 - '메소포타미아의 죽음' 리뷰 수집 완료! (5개)
# 📖 230/5572 - '마술 살인' 리뷰 수집 완료! (5개)
# 📖 231/5572 - '엔드하우스의 비극' 리뷰 수집 완료! (5개)
# 📖 232/5572 - '창백한 말' 리뷰 수집 완료! (5개)
# 📖 233/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 234/5572 - '흑거미 클럽' 리뷰 수집 완료! (5개)
# 📖 235/5572 - '장례식을 끝내고' 리뷰 수집 완료! (5개)
# 📖 236/5572 - '잠자는 살인' 리뷰 수집 완료! (5개)
# 📖 237/5572 - '누명' 리뷰 수집 완료! (5개)
# 📖 238/5572 - '3막의 비극' 리뷰 수집 완료! (5개)
# 📖 239/5572 - '마지막으로 죽음이 오다' 리뷰 수집 완료! (5개)
# 📖 240/5572 - '비틀린 집' 리뷰 수집 완료! (5개)
# 📖 241/5572 - '바스커빌가의 개' 리뷰 수집 완료! (5개)
# 📖 242/5572 - '천사의 나이프' 리뷰 수집 완료! (5개)
# 📖 243/5572 - '우편배달부는 벨을 두번 울린다' 리뷰 수집 완료! (5개)
# 📖 244/5572 - '명탐정 푸아로 베스트 세트' 리뷰 수집 완료! (5개)
# 📖 245/5572 - '백주의 악마' 리뷰 수집 완료! (5개)
# 📖 246/5572 - '다섯 마리 아기 돼지' 리뷰 수집 완료! (5개)
# 📖 247/5572 - '나일강의 죽음' 리뷰 수집 완료! (5개)
# 📖 248/5572 - '죽은 자의 어리석음' 리뷰 수집 완료! (5개)
# 📖 249/5572 - '딸은 딸이다' 리뷰 수집 완료! (5개)
# 📖 250/5572 - '패배한 개' 리뷰 수집 완료! (5개)
# 📖 251/5572 - '엔드하우스의 비극' 리뷰 수집 완료! (5개)
# 📖 252/5572 - '메소포타미아의 살인' 리뷰 수집 완료! (5개)
# 📖 253/5572 - '죽음과의 약속' 리뷰 수집 완료! (5개)
# 📖 254/5572 - '오른쪽 주머니에서 나온 이야기' 리뷰 수집 완료! (5개)
# 📖 255/5572 - '오리엔트 특급살인' 리뷰 수집 완료! (5개)
# 📖 256/5572 - '장례식을 마치고' 리뷰 수집 완료! (5개)
# 📖 257/5572 - '구름 속의 죽음' 리뷰 수집 완료! (5개)
# 📖 258/5572 - '맥긴티 부인의 죽음' 리뷰 수집 완료! (5개)
# 📖 259/5572 - '애크로이드 살인사건' 리뷰 수집 완료! (5개)
# 📖 260/5572 - '서재의 시체' 리뷰 수집 완료! (5개)
# 📖 261/5572 - '에지웨어 경의 죽음  34)' 리뷰 수집 완료! (5개)
# 📖 262/5572 - '구름 속의 죽음' 리뷰 수집 완료! (5개)
# 📖 263/5572 - '고구레 사진관' 리뷰 수집 완료! (5개)
# 📖 264/5572 - '고구레 사진관' 리뷰 수집 완료! (5개)
# 📖 265/5572 - '화형 법정' 리뷰 수집 완료! (5개)
# 📖 266/5572 - '혼징살인사건' 리뷰 수집 완료! (5개)
# 📖 267/5572 - '포이즌 도터 홀리 마더' 리뷰 수집 완료! (5개)
# 📖 268/5572 - 'Y의 비극' 리뷰 수집 완료! (5개)
# 📖 269/5572 - '아웃사이더 2' 리뷰 수집 완료! (5개)
# 📖 270/5572 - '병원 고개의 목매달아 죽은 이의 집 1' 리뷰 수집 완료! (5개)
# 📖 271/5572 - '주홍색 연구 )' 리뷰 수집 완료! (5개)
# 📖 272/5572 - '그리스 관 미스터리' 리뷰 수집 완료! (5개)
# 📖 273/5572 - '수박 향기' 리뷰 수집 완료! (5개)
# 📖 274/5572 - '크로스 파이어 1' 리뷰 수집 완료! (5개)
# 📖 275/5572 - '황제의 코담뱃갑' 리뷰 수집 완료! (5개)
# 📖 276/5572 - '에도가와 란포' 리뷰 수집 완료! (5개)
# 📖 277/5572 - '게스트' 리뷰 수집 완료! (5개)
# 📖 278/5572 - '고교 입시' 리뷰 수집 완료! (5개)
# 📖 279/5572 - '소름' 리뷰 수집 완료! (5개)
# 📖 280/5572 - '주석 달린 셜록 홈즈 3' 리뷰 수집 완료! (5개)
# 📖 281/5572 - '기나긴 이별' 리뷰 수집 완료! (5개)
# 📖 282/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 283/5572 - '주석 달린 셜록 홈즈 5' 리뷰 수집 완료! (5개)
# 📖 284/5572 - '주석 달린 셜록 홈즈 6' 리뷰 수집 완료! (5개)
# 📖 285/5572 - '카페 홈즈의 마지막 사랑' 리뷰 수집 완료! (5개)
# 📖 286/5572 - '무당 거미의 이치' 리뷰 수집 완료! (5개)
# 📖 287/5572 - '용은 잠들다' 리뷰 수집 완료! (5개)
# 📖 288/5572 - '외딴섬 악마' 리뷰 수집 완료! (5개)
# 📖 289/5572 - '셜록 홈즈 더 얼티밋 에디션: 왓슨 편' 리뷰 수집 완료! (5개)
# 📖 290/5572 - 'XYZ의 비극' 리뷰 수집 완료! (5개)
# 📖 291/5572 - '셜록 홈즈 사건집' 리뷰 수집 완료! (5개)
# 📖 292/5572 - '네 사람의 서명' 리뷰 수집 완료! (5개)
# 📖 293/5572 - '무당 거미의 이치' 리뷰 수집 완료! (5개)
# 📖 294/5572 - '셜록 홈스의 모험' 리뷰 수집 완료! (5개)
# 📖 295/5572 - '인페르노' 리뷰 수집 완료! (5개)
# 📖 296/5572 - '무당 거미의 이치' 리뷰 수집 완료! (5개)
# 📖 297/5572 - '셜록 홈즈 단편 베스트 12' 리뷰 수집 완료! (5개)
# 📖 298/5572 - '검은집' 리뷰 수집 완료! (5개)
# 📖 299/5572 - '이탈리아 구두' 리뷰 수집 완료! (5개)
# 📖 300/5572 - '셜록 홈스 전집 단편집 세트' 리뷰 수집 완료! (5개)
# 📖 301/5572 - '바스커빌 가문의 사냥개' 리뷰 수집 완료! (5개)
# 📖 302/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 303/5572 - '셜록 홈즈의 모험' 리뷰 수집 완료! (5개)
# 📖 304/5572 - '주석 달린 셜록 홈즈 4' 리뷰 수집 완료! (5개)
# 📖 305/5572 - '셜록홈즈 걸작선 2' 리뷰 수집 완료! (5개)
# 📖 306/5572 - '셜록 1: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 307/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 308/5572 - '셜록 홈즈의 사건집' 리뷰 수집 완료! (5개)
# 📖 309/5572 - '셜록 홈즈 대표 단편선 23' 리뷰 수집 완료! (5개)
# 📖 310/5572 - '배스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 311/5572 - '셜록홈즈 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 312/5572 - '셜록홈즈 네 개의 기호' 리뷰 수집 완료! (5개)
# 📖 313/5572 - '셜록 홈즈의 모험 )' 리뷰 수집 완료! (5개)
# 📖 314/5572 - '돌아온 셜록 홈즈' 리뷰 수집 완료! (5개)
# 📖 315/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 316/5572 - '셜록홈즈 걸작선 3' 리뷰 수집 완료! (5개)
# 📖 317/5572 - '셜록홈즈 그의 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 318/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 319/5572 - '셜록 홈즈 Mini+ 전집: 바스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 320/5572 - '셜록 홈즈의 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 321/5572 - '푸코의 진자 3' 리뷰 수집 완료! (5개)
# 📖 322/5572 - '셜록 홈즈의 모험' 리뷰 수집 완료! (5개)
# 📖 323/5572 - '셜록 홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 324/5572 - '공포의 계곡 )' 리뷰 수집 완료! (5개)
# 📖 325/5572 - '셜록 홈즈의 회상' 리뷰 수집 완료! (5개)
# 📖 326/5572 - '셜록 홈즈의 귀환 )' 리뷰 수집 완료! (5개)
# 📖 327/5572 - '셜록 홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 328/5572 - '셜록 홈즈 전집 세트' 리뷰 수집 완료! (5개)
# 📖 329/5572 - '셜록홈즈 베스트 12' 리뷰 수집 완료! (5개)
# 📖 330/5572 - '셜록홈즈 걸작선' 리뷰 수집 완료! (5개)
# 📖 331/5572 - '바스커빌 씨네 사냥개' 리뷰 수집 완료! (5개)
# 📖 332/5572 - '셜록홈즈 베스트 단편선 13' 리뷰 수집 완료! (5개)
# 📖 333/5572 - '셜록홈즈 모험 걸작선' 리뷰 수집 완료! (5개)
# 📖 334/5572 - '셜록홈즈 배스커빌의 사냥개' 리뷰 수집 완료! (5개)
# 📖 335/5572 - '바스커빌가의 사냥개 )' 리뷰 수집 완료! (5개)
# 📖 336/5572 - '셜록홈즈의 회상' 리뷰 수집 완료! (5개)
# 📖 337/5572 - '셜록 홈즈' 리뷰 수집 완료! (5개)
# 📖 338/5572 - '셜록 홈즈의 회상' 리뷰 수집 완료! (5개)
# 📖 339/5572 - '홀로 남겨져' 리뷰 수집 완료! (5개)
# 📖 340/5572 - '명탐견 마사의 사건 일지' 리뷰 수집 완료! (5개)
# 📖 341/5572 - '셜록 홈스 단편선' 리뷰 수집 완료! (5개)
# 📖 342/5572 - '지옥의 어릿광대' 리뷰 수집 완료! (5개)
# 📖 343/5572 - '셜록 홈즈 베스트 10' 리뷰 수집 완료! (5개)
# 📖 344/5572 - '아버지들의 죄' 리뷰 수집 완료! (5개)
# 📖 345/5572 - '화형법정' 리뷰 수집 완료! (5개)
# 📖 346/5572 - '홈즈 단편베스트 걸작선 17' 리뷰 수집 완료! (5개)
# 📖 347/5572 - '새벽의 데드라인' 리뷰 수집 완료! (5개)
# 📖 348/5572 - '셜록홈즈 주홍색 습작' 리뷰 수집 완료! (5개)
# 📖 349/5572 - '셜록 홈즈의 사건' 리뷰 수집 완료! (5개)
# 📖 350/5572 - '말벌' 리뷰 수집 완료! (5개)
# 📖 351/5572 - '셜록홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 352/5572 - '셜록홈즈의 모험' 리뷰 수집 완료! (5개)
# 📖 353/5572 - '바스커빌의 개' 리뷰 수집 완료! (5개)
# 📖 354/5572 - '셜록 홈즈 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 355/5572 - '셜록 홈즈의 대활약' 리뷰 수집 완료! (5개)
# 📖 356/5572 - '미싱유' 리뷰 수집 완료! (5개)
# 📖 357/5572 - '리틀 시스터' 리뷰 수집 완료! (5개)
# 📖 358/5572 - '붉은 수확' 리뷰 수집 완료! (5개)
# 📖 359/5572 - '매그레와 벤치의 사나이' 리뷰 수집 완료! (5개)
# 📖 360/5572 - '판사와 형리' 리뷰 수집 완료! (5개)
# 📖 361/5572 - '황제의 코담뱃갑' 리뷰 수집 완료! (5개)
# 📖 362/5572 - '셜록 홈스: 바스커빌 가문의 사냥개' 리뷰 수집 완료! (5개)
# 📖 363/5572 - '셜록 홈스: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 364/5572 - '셜록 홈즈 더 얼티밋 에디션 세트' 리뷰 수집 완료! (5개)
# 📖 365/5572 - '셜록 홈스: 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 366/5572 - '셜록 홈즈 1: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 367/5572 - '셜록홈즈 8: 셜록 홈즈의 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 368/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 369/5572 - '셜록 홈즈 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 370/5572 - '셜록 홈즈 9: 셜록 홈즈의 사건집' 리뷰 수집 완료! (5개)
# 📖 371/5572 - '셜록 홈즈 1: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 372/5572 - '배스커빌가의 개' 리뷰 수집 완료! (5개)
# 📖 373/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 374/5572 - '셜록홈즈 7: 셜록 홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 375/5572 - '셜록 홈즈 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 376/5572 - '네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 377/5572 - '셜록 홈즈 대표 장편선' 리뷰 수집 완료! (5개)
# 📖 378/5572 - '홈즈의 검은 그림자' 리뷰 수집 완료! (5개)
# 📖 379/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 380/5572 - '셜록 홈즈 2: 네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 381/5572 - '바스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 382/5572 - '셜록 홈즈 4: 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 383/5572 - '셜록 홈즈 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 384/5572 - '셜록 홈즈 2' 리뷰 수집 완료! (5개)
# 📖 385/5572 - '셜록 홈즈의 대표 걸작선' 리뷰 수집 완료! (5개)
# 📖 386/5572 - '셜록 홈즈 3: 배스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 387/5572 - '네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 388/5572 - '셜록 홈즈 초판본 리커버 전집  + 셜록 홈즈 해설집)' 리뷰 수집 완료! (5개)
# 📖 389/5572 - '셜록홈즈 20' 리뷰 수집 완료! (5개)
# 📖 390/5572 - '바스커빌의 개' 리뷰 수집 완료! (5개)
# 📖 391/5572 - '셜록 홈즈 4: 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 392/5572 - '셜록홈즈 전집 세트' 리뷰 수집 완료! (5개)
# 📖 393/5572 - '셜록홈즈 스페셜 단편집' 리뷰 수집 완료! (5개)
# 📖 394/5572 - '네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 395/5572 - '셜록 홈즈 단편 걸작선' 리뷰 수집 완료! (5개)
# 📖 396/5572 - '셜록 홈즈 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 397/5572 - '홈즈걸작선' 리뷰 수집 완료! (5개)
# 📖 398/5572 - '셜록 홈즈 명작선' 리뷰 수집 완료! (5개)
# 📖 399/5572 - '주홍색연구' 리뷰 수집 완료! (5개)
# 📖 400/5572 - '형사의 아이' 리뷰 수집 완료! (5개)
# 📖 401/5572 - '도박 눈' 리뷰 수집 완료! (5개)
# 📖 402/5572 - '기암성' 리뷰 수집 완료! (5개)
# 📖 403/5572 - '시체는 누구' 리뷰 수집 완료! (5개)
# 📖 404/5572 - '엘러리 퀸의 모험' 리뷰 수집 완료! (5개)
# 📖 405/5572 - '갈레 씨 홀로 죽다' 리뷰 수집 완료! (5개)
# 📖 406/5572 - '스페인 곶 미스터리' 리뷰 수집 완료! (5개)
# 📖 407/5572 - '에드거 앨런 포 베스트 단편선' 리뷰 수집 완료! (5개)
# 📖 408/5572 - '스트레인저' 리뷰 수집 완료! (5개)
# 📖 409/5572 - '레이디 조커 1' 리뷰 수집 완료! (5개)
# 📖 410/5572 - '그레이스 1' 리뷰 수집 완료! (5개)
# 📖 411/5572 - '마술사' 리뷰 수집 완료! (5개)
# 📖 412/5572 - '증인이 너무 많다' 리뷰 수집 완료! (5개)
# 📖 413/5572 - '노랑방의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 414/5572 - 'Z의 비극' 리뷰 수집 완료! (5개)
# 📖 415/5572 - '차이나 오렌지의 비밀' 리뷰 수집 완료! (5개)
# 📖 416/5572 - '자물쇠가 잠긴 방' 리뷰 수집 완료! (5개)
# 📖 417/5572 - '김유신의 머리일까' 리뷰 수집 완료! (5개)
# 📖 418/5572 - '아르센 뤼팽 전집 17' 리뷰 수집 완료! (5개)
# 📖 419/5572 - '아르센 뤼팽 전집 12)' 리뷰 수집 완료! (5개)
# 📖 420/5572 - '아르센 뤼팽 전집 3' 리뷰 수집 완료! (5개)
# 📖 421/5572 - '아르센 뤼팽 전집 14' 리뷰 수집 완료! (5개)
# 📖 422/5572 - '아르센 뤼팽 전집 11)' 리뷰 수집 완료! (5개)
# 📖 423/5572 - '아르센 뤼팽 전집 13' 리뷰 수집 완료! (5개)
# 📖 424/5572 - '아르센 뤼팽 전집 5' 리뷰 수집 완료! (5개)
# 📖 425/5572 - '아르센 뤼팽 전집 16' 리뷰 수집 완료! (5개)
# 📖 426/5572 - '아르센 뤼팽 전집 6' 리뷰 수집 완료! (5개)
# 📖 427/5572 - '아르센 뤼팽 전집 4' 리뷰 수집 완료! (5개)
# 📖 428/5572 - '무덤으로 향하다' 리뷰 수집 완료! (5개)
# 📖 429/5572 - '레이디 조커 2' 리뷰 수집 완료! (5개)
# 📖 430/5572 - '레이디 조커 3' 리뷰 수집 완료! (5개)
# 📖 431/5572 - '목 부러뜨리는 남자를 위한 협주곡' 리뷰 수집 완료! (5개)
# 📖 432/5572 - '마제스틱 호텔의 지하' 리뷰 수집 완료! (5개)
# 📖 433/5572 - '엽기의 말로' 리뷰 수집 완료! (5개)
# 📖 434/5572 - '뉴욕 미스터리' 리뷰 수집 완료! (5개)
# 📖 435/5572 - '난쟁이' 리뷰 수집 완료! (5개)
# 📖 436/5572 - '그리고 누군가 없어졌다' 리뷰 수집 완료! (5개)
# 📖 437/5572 - '교차로의 밤' 리뷰 수집 완료! (5개)
# 📖 438/5572 - '젤프의 기만' 리뷰 수집 완료! (5개)
# 📖 439/5572 - '살인과 창조의 시간' 리뷰 수집 완료! (5개)
# 📖 440/5572 - '루팡의 소식' 리뷰 수집 완료! (5개)
# 📖 441/5572 - '코끼리의 무덤은 없다' 리뷰 수집 완료! (5개)
# 📖 442/5572 - '도불의 연회: 연회의 준비' 리뷰 수집 완료! (5개)
# 📖 443/5572 - '생폴리앵에 지다' 리뷰 수집 완료! (5개)
# 📖 444/5572 - '대실 해밋 전집 세트' 리뷰 수집 완료! (5개)
# 📖 445/5572 - '죽음의 한가운데' 리뷰 수집 완료! (5개)
# 📖 446/5572 - 'Y의 비극' 리뷰 수집 완료! (5개)
# 📖 447/5572 - '코너스톤 3대 고전 추리소설 세트' 리뷰 수집 완료! (5개)
# 📖 448/5572 - '생사의 게임' 리뷰 수집 완료! (5개)
# 📖 449/5572 - '813' 리뷰 수집 완료! (5개)
# 📖 450/5572 - '엽기의 끝' 리뷰 수집 완료! (5개)
# 📖 451/5572 - '수정마개' 리뷰 수집 완료! (5개)
# 📖 452/5572 - '유리 열쇠' 리뷰 수집 완료! (5개)
# 📖 453/5572 - '지혜' 리뷰 수집 완료! (5개)
# 📖 454/5572 - '레베카 2' 리뷰 수집 완료! (5개)
# 📖 455/5572 - '안개의 항구' 리뷰 수집 완료! (5개)
# 📖 456/5572 - '의심' 리뷰 수집 완료! (5개)
# 📖 457/5572 - '벤슨 살인사건' 리뷰 수집 완료! (5개)
# 📖 458/5572 - '불연속 살인사건' 리뷰 수집 완료! (5개)
# 📖 459/5572 - '흑백의 여로' 리뷰 수집 완료! (5개)
# 📖 460/5572 - '제1호 수문' 리뷰 수집 완료! (5개)
# 📖 461/5572 - '상복의 랑데부' 리뷰 수집 완료! (5개)
# 📖 462/5572 - '의학의 초보자' 리뷰 수집 완료! (5개)
# 📖 463/5572 - '괴도신사 뤼팽' 리뷰 수집 완료! (5개)
# 📖 464/5572 - '뤼팽 대 홈즈' 리뷰 수집 완료! (5개)
# 📖 465/5572 - '기암성' 리뷰 수집 완료! (5개)
# 📖 466/5572 - '데인 가의 저주' 리뷰 수집 완료! (5개)
# 📖 467/5572 - '할루인 수사의 고백' 리뷰 수집 완료! (5개)
# 📖 468/5572 - '어둠 속의 갈가마귀' 리뷰 수집 완료! (5개)
# 📖 469/5572 - '그림자 없는 남자' 리뷰 수집 완료! (5개)
# 📖 470/5572 - '수정마개' 리뷰 수집 완료! (5개)
# 📖 471/5572 - '재앙의 거리' 리뷰 수집 완료! (5개)
# 📖 472/5572 - '플랑드르인의 집' 리뷰 수집 완료! (5개)
# 📖 473/5572 - '아르센 뤼팽 대 셜록 홈즈' 리뷰 수집 완료! (5개)
# 📖 474/5572 - '월식도의 마물' 리뷰 수집 완료! (5개)
# 📖 475/5572 - '허몽' 리뷰 수집 완료! (5개)
# 📖 476/5572 - '중간지점의 집' 리뷰 수집 완료! (5개)
# 📖 477/5572 - '나를 닮은 사람' 리뷰 수집 완료! (5개)
# 📖 478/5572 - '꼬리 아홉 고양이' 리뷰 수집 완료! (5개)
# 📖 479/5572 - '10일간의 불가사의' 리뷰 수집 완료! (5개)
# 📖 480/5572 - '맹독' 리뷰 수집 완료! (5개)
# 📖 481/5572 - '바리바 외' 리뷰 수집 완료! (5개)
# 📖 482/5572 - '괴도 루팽 추리 걸작선' 리뷰 수집 완료! (5개)
# 📖 483/5572 - '두 미소를 지닌 여인' 리뷰 수집 완료! (5개)
# 📖 484/5572 - '이상한 집' 리뷰 수집 완료! (5개)
# 📖 485/5572 - '광골의 꿈' 리뷰 수집 완료! (5개)
# 📖 486/5572 - '깊은 잠' 리뷰 수집 완료! (5개)
# 📖 487/5572 - '거대한 잠' 리뷰 수집 완료! (5개)
# 📖 488/5572 - '환상의 여자' 리뷰 수집 완료! (5개)
# 📖 489/5572 - '타인의 목' 리뷰 수집 완료! (5개)
# 📖 490/5572 - '아르센 뤼팽 전집 19' 리뷰 수집 완료! (5개)
# 📖 491/5572 - '아르센 뤼팽 전집 20: 마약수사원 빅토르' 리뷰 수집 완료! (5개)
# 📖 492/5572 - '초록 눈동자의 아가씨 외' 리뷰 수집 완료! (5개)
# 📖 493/5572 - '그리스 관의 비밀' 리뷰 수집 완료! (5개)
# 📖 494/5572 - '813의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 495/5572 - '실업자' 리뷰 수집 완료! (5개)
# 📖 496/5572 - '초록 눈의 아가씨' 리뷰 수집 완료! (5개)
# 📖 497/5572 - '드래건 살인사건' 리뷰 수집 완료! (5개)
# 📖 498/5572 - '뤼팽의 고백' 리뷰 수집 완료! (5개)
# 📖 499/5572 - '시계 종이 여덟 번 울릴 때' 리뷰 수집 완료! (5개)
# 📖 500/5572 - '프리즘' 리뷰 수집 완료! (5개)
# 📖 501/5572 - '신의 등불' 리뷰 수집 완료! (5개)
# 📖 502/5572 - '베르주라크의 광인' 리뷰 수집 완료! (5개)
# 📖 503/5572 - 'Z의비극' 리뷰 수집 완료! (5개)
# 📖 504/5572 - '로마 모자의 비밀' 리뷰 수집 완료! (5개)
# 📖 505/5572 - '칼리오스트로 백작부인의 복수' 리뷰 수집 완료! (5개)
# 📖 506/5572 - '괴도 루팽 추리 걸작선' 리뷰 수집 완료! (5개)
# 📖 507/5572 - '아르센 뤼팽 전집 8' 리뷰 수집 완료! (5개)
# 📖 508/5572 - '아르센 뤼팽 전집 15' 리뷰 수집 완료! (5개)
# 📖 509/5572 - '아르센 뤼팽 전집 10' 리뷰 수집 완료! (5개)
# 📖 510/5572 - '아르센 뤼팽 전집 9' 리뷰 수집 완료! (5개)
# 📖 511/5572 - '뤼팽 베스트 사건 파일' 리뷰 수집 완료! (5개)
# 📖 512/5572 - '벨벳의 악마' 리뷰 수집 완료! (5개)
# 📖 513/5572 - '크림슨의 미궁' 리뷰 수집 완료! (5개)
# 📖 514/5572 - '기암성' 리뷰 수집 완료! (5개)
# 📖 515/5572 - '두 가지 미소를 가진 여자' 리뷰 수집 완료! (5개)
# 📖 516/5572 - '살인방정식' 리뷰 수집 완료! (5개)
# 📖 517/5572 - '뤼뺑이냐 홈즈냐' 리뷰 수집 완료! (5개)
# 📖 518/5572 - '아르센 뤼팽 아르센 뤼팽의 대모험' 리뷰 수집 완료! (5개)
# 📖 519/5572 - '노란방의 비밀 1' 리뷰 수집 완료! (5개)
# 📖 520/5572 - '살인증후군' 리뷰 수집 완료! (5개)
# 📖 521/5572 - '광고하는 살인' 리뷰 수집 완료! (5개)
# 📖 522/5572 - '백귀야행 음' 리뷰 수집 완료! (5개)
# 📖 523/5572 - '살인예언자 1: 오드 토머스 첫 번째 이야기' 리뷰 수집 완료! (5개)
# 📖 524/5572 - '살인예언자 4: 오드 토머스와 흰 옷의 소녀' 리뷰 수집 완료! (5개)
# 📖 525/5572 - '이방인 1' 리뷰 수집 완료! (5개)
# 📖 526/5572 - '라 프로비당스호의 마부' 리뷰 수집 완료! (5개)
# 📖 527/5572 - '엔젤' 리뷰 수집 완료! (5개)
# 📖 528/5572 - '생피아크르 사건' 리뷰 수집 완료! (5개)
# 📖 529/5572 - '얼론 투게더' 리뷰 수집 완료! (5개)
# 📖 530/5572 - '괴도 뤼팽 추리 걸작선' 리뷰 수집 완료! (5개)
# 📖 531/5572 - '뤼팽 단편베스트 걸작선' 리뷰 수집 완료! (5개)
# 📖 532/5572 - '르윈터의 망명' 리뷰 수집 완료! (5개)
# 📖 533/5572 - '아르센 뤼팽 수정마개' 리뷰 수집 완료! (5개)
# 📖 534/5572 - '아르센 뤼팽 기암성' 리뷰 수집 완료! (5개)
# 📖 535/5572 - '813' 리뷰 수집 완료! (5개)
# 📖 536/5572 - '유다의 창' 리뷰 수집 완료! (5개)
# 📖 537/5572 - '황제의 코담베 케이스' 리뷰 수집 완료! (5개)
# 📖 538/5572 - '매그레 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 539/5572 - '유괴증후군' 리뷰 수집 완료! (5개)
# 📖 540/5572 - '실종증후군' 리뷰 수집 완료! (5개)
# 📖 541/5572 - '그때로 다시 돌아간다면' 리뷰 수집 완료! (5개)
# 📖 542/5572 - '두려움보다 강한 감정' 리뷰 수집 완료! (5개)
# 📖 543/5572 - '탐정 백작과 나' 리뷰 수집 완료! (5개)
# 📖 544/5572 - '런던 필즈 1' 리뷰 수집 완료! (5개)
# 📖 545/5572 - '체인 포이즌' 리뷰 수집 완료! (5개)
# 📖 546/5572 - '악몽의 관람차' 리뷰 수집 완료! (5개)
# 📖 547/5572 - '텔로미어' 리뷰 수집 완료! (5개)
# 📖 548/5572 - '죽은 자의 블랙박스를 요청합니다' 리뷰 수집 완료! (5개)
# 📖 549/5572 - '엘리펀트 헤드' 리뷰 수집 완료! (5개)
# 📖 550/5572 - '재버워크의 밤' 리뷰 수집 완료! (5개)
# 📖 551/5572 - '말로 머더 클럽' 리뷰 수집 완료! (5개)
# 📖 552/5572 - '육법추리' 리뷰 수집 완료! (5개)
# 📖 553/5572 - '희대의 비극' 리뷰 수집 완료! (5개)
# 📖 554/5572 - '아이는 무서운 꿈을 꾼다' 리뷰 수집 완료! (5개)
# 📖 555/5572 - '살인 매거진' 리뷰 수집 완료! (5개)
# 📖 556/5572 - '영원의 1초는 얼마인가' 리뷰 수집 완료! (5개)
# 📖 557/5572 - '인버트' 리뷰 수집 완료! (5개)
# 📖 558/5572 - '궁극의 아이 2: 넥스트 차일드' 리뷰 수집 완료! (5개)
# 📖 559/5572 - '궁극의 아이 세트' 리뷰 수집 완료! (5개)
# 📖 560/5572 - '언니의 실종에 관한 48 단서들' 리뷰 수집 완료! (5개)
# 📖 561/5572 - '제로의 늦여름' 리뷰 수집 완료! (5개)
# 📖 562/5572 - '남편을 죽이는 서른 가지 방법' 리뷰 수집 완료! (5개)
# 📖 563/5572 - '4일 간의 가족' 리뷰 수집 완료! (5개)
# 📖 564/5572 - '그녀의 취미생활' 리뷰 수집 완료! (5개)
# 📖 565/5572 - '까마귀 장례식' 리뷰 수집 완료! (5개)
# 📖 566/5572 - '당신의 비밀' 리뷰 수집 완료! (5개)
# 📖 567/5572 - '테사를 찾아서' 리뷰 수집 완료! (5개)
# 📖 568/5572 - '내가 선생님을 죽였다' 리뷰 수집 완료! (5개)
# 📖 569/5572 - '치팅 데이' 리뷰 수집 완료! (5개)
# 📖 570/5572 - '카스트라토: 거세당한 자' 리뷰 수집 완료! (5개)
# 📖 571/5572 - '중편들, 한국 공포문학의 밤 세트' 리뷰 수집 완료! (5개)
# 📖 572/5572 - '중편들, 한국 공포문학의 밤 수요일: 허수아비' 리뷰 수집 완료! (5개)
# 📖 573/5572 - '중편들, 한국 공포문학의 밤 금요일: 벽지 뜯기' 리뷰 수집 완료! (5개)
# 📖 574/5572 - '중편들, 한국 공포문학의 밤 화요일: 사람의 심해' 리뷰 수집 완료! (5개)
# 📖 575/5572 - '중편들, 한국 공포문학의 밤 월요일: 앨리게이터' 리뷰 수집 완료! (5개)
# 📖 576/5572 - '중편들, 한국 공포문학의 밤 일요일: 제로' 리뷰 수집 완료! (5개)
# 📖 577/5572 - '중편들, 한국 공포문학의 밤 토요일: 우물' 리뷰 수집 완료! (5개)
# 📖 578/5572 - '중편들, 한국 공포문학의 밤 목요일: 액연' 리뷰 수집 완료! (5개)
# 📖 579/5572 - '최면술사의 시대' 리뷰 수집 완료! (5개)
# 📖 580/5572 - '기묘한 밤' 리뷰 수집 완료! (5개)
# 📖 581/5572 - '마더: 무덤에서 돌아온 여자' 리뷰 수집 완료! (5개)
# 📖 582/5572 - '완벽한 세상' 리뷰 수집 완료! (5개)
# 📖 583/5572 - '오렌지와 빵칼' 리뷰 수집 완료! (5개)
# 📖 584/5572 - '아침과 저녁의 범죄' 리뷰 수집 완료! (5개)
# 📖 585/5572 - '가연물' 리뷰 수집 완료! (5개)
# 📖 586/5572 - '엄마, 시체를 부탁해' 리뷰 수집 완료! (5개)
# 📖 587/5572 - '악의 고해소' 리뷰 수집 완료! (5개)
# 📖 588/5572 - '기암관의 살인' 리뷰 수집 완료! (5개)
# 📖 589/5572 - '숨겨진 건 죽음' 리뷰 수집 완료! (5개)
# 📖 590/5572 - '런던 비밀 강령회' 리뷰 수집 완료! (5개)
# 📖 591/5572 - '너는 미스터리가 읽고 싶다' 리뷰 수집 완료! (5개)
# 📖 592/5572 - '테사를 찾아서' 리뷰 수집 완료! (5개)
# 📖 593/5572 - '분노의 히어로' 리뷰 수집 완료! (5개)
# 📖 594/5572 - '마피아 찾기' 리뷰 수집 완료! (5개)
# 📖 595/5572 - '엘라의 작은 모험' 리뷰 수집 완료! (5개)
# 📖 596/5572 - '귀우' 리뷰 수집 완료! (5개)
# 📖 597/5572 - '어둠 속의 비행 소년들' 리뷰 수집 완료! (5개)
# 📖 598/5572 - '내가 대답하는 너의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 599/5572 - '누가 제이슨 벨을 죽였나' 리뷰 수집 완료! (5개)
# 📖 600/5572 - '총원산' 리뷰 수집 완료! (5개)
# 📖 601/5572 - '도깨비 사냥' 리뷰 수집 완료! (5개)
# 📖 602/5572 - '킬에이저' 리뷰 수집 완료! (5개)
# 📖 603/5572 - '목걸이 사건의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 604/5572 - '행복도 사람들' 리뷰 수집 완료! (5개)
# 📖 605/5572 - '마치 박사의 네 아들' 리뷰 수집 완료! (5개)
# 📖 606/5572 - '미제레레' 리뷰 수집 완료! (5개)
# 📖 607/5572 - '5번의 죽음 6번의 목숨' 리뷰 수집 완료! (5개)
# 📖 608/5572 - '밤이 길었던 날' 리뷰 수집 완료! (5개)
# 📖 609/5572 - '밤은 눈을 감지 않는다' 리뷰 수집 완료! (5개)
# 📖 610/5572 - '도난: 숨겨진 세계' 리뷰 수집 완료! (5개)
# 📖 611/5572 - '걷는 망자' 리뷰 수집 완료! (5개)
# 📖 612/5572 - '물속의 입' 리뷰 수집 완료! (5개)
# 📖 613/5572 - '따뜻한 손' 리뷰 수집 완료! (5개)
# 📖 614/5572 - '십계' 리뷰 수집 완료! (5개)
# 📖 615/5572 - '아이가 없는 집' 리뷰 수집 완료! (5개)
# 📖 616/5572 - '로건과 샬롯의 탐정일기 : 연쇄살인범의 게임' 리뷰 수집 완료! (5개)
# 📖 617/5572 - '미친 X들' 리뷰 수집 완료! (5개)
# 📖 618/5572 - '사라진 호텔, 겟로스트' 리뷰 수집 완료! (0개)
# 📖 619/5572 - '배드트립' 리뷰 수집 완료! (5개)
# 📖 620/5572 - '기기괴괴 중국 도시 괴담집' 리뷰 수집 완료! (5개)
# 📖 621/5572 - '다크 디텍티브' 리뷰 수집 완료! (5개)
# 📖 622/5572 - 'mymy' 리뷰 수집 완료! (5개)
# 📖 623/5572 - '밤이 길었던 날' 리뷰 수집 완료! (5개)
# 📖 624/5572 - '살인 리스트' 리뷰 수집 완료! (5개)
# 📖 625/5572 - '아름답게 자란 B친여자' 리뷰 수집 완료! (4개)
# 📖 626/5572 - '활자잔혹극' 리뷰 수집 완료! (5개)
# 📖 627/5572 - '바츠먼의 변호인' 리뷰 수집 완료! (5개)
# 📖 628/5572 - '죽이고 싶은 남편들' 리뷰 수집 완료! (5개)
# 📖 629/5572 - '끝없는 바닥' 리뷰 수집 완료! (5개)
# 📖 630/5572 - '달콤한 살인 계획' 리뷰 수집 완료! (5개)
# 📖 631/5572 - '로스트' 리뷰 수집 완료! (5개)
# 📖 632/5572 - '마담 흑조는 곤란한 이야기를 청한다' 리뷰 수집 완료! (5개)
# 📖 633/5572 - '늑대와 토끼의 게임' 리뷰 수집 완료! (5개)
# 📖 634/5572 - '영혼을 단장해드립니다, 챠밍 미용실' 리뷰 수집 완료! (5개)
# 📖 635/5572 - '성스러운 술집이 문 닫을 때' 리뷰 수집 완료! (5개)
# 📖 636/5572 - '부산 느와르 미스터리' 리뷰 수집 완료! (5개)
# 📖 637/5572 - '문이 열리면' 리뷰 수집 완료! (5개)
# 📖 638/5572 - '뱀파이어 탐정단' 리뷰 수집 완료! (5개)
# 📖 639/5572 - 'Tiger' 리뷰 수집 완료! (5개)
# 📖 640/5572 - '꽃다발은 독' 리뷰 수집 완료! (5개)
# 📖 641/5572 - '살인자는 천국에 있다' 리뷰 수집 완료! (5개)
# 📖 642/5572 - '어디에도 휘파람은 없다' 리뷰 수집 완료! (5개)
# 📖 643/5572 - '헤이그의 비밀' 리뷰 수집 완료! (5개)
# 📖 644/5572 - '귀축의 집' 리뷰 수집 완료! (5개)
# 📖 645/5572 - '삶, 범죄자의.' 리뷰 수집 완료! (5개)
# 📖 646/5572 - '지하실의 새' 리뷰 수집 완료! (5개)
# 📖 647/5572 - '뚜식이의 과학일기 2: 미스터리 범죄' 리뷰 수집 완료! (5개)
# 📖 648/5572 - '하이드의 귀환' 리뷰 수집 완료! (5개)
# 📖 649/5572 - '210번관에 어서 오세요' 리뷰 수집 완료! (5개)
# 📖 650/5572 - '연쇄삶인' 리뷰 수집 완료! (5개)
# 📖 651/5572 - '헤드헌터' 리뷰 수집 완료! (5개)
# 📖 652/5572 - '할머니의 야구공' 리뷰 수집 완료! (5개)
# 📖 653/5572 - '전지적 감시자 시점' 리뷰 수집 완료! (5개)
# 📖 654/5572 - '형사刑事 이야기, 윤계식 1' 리뷰 수집 완료! (5개)
# 📖 655/5572 - '형사刑事 이야기, 윤계식 2 完' 리뷰 수집 완료! (5개)
# 📖 656/5572 - '역광' 리뷰 수집 완료! (5개)
# 📖 657/5572 - 'I의 비극' 리뷰 수집 완료! (5개)
# 📖 658/5572 - '한국추리문학상 황금펜상 수상작품집: 2023년 제17회' 리뷰 수집 완료! (5개)
# 📖 659/5572 - '도쿄 사기꾼들' 리뷰 수집 완료! (5개)
# 📖 660/5572 - '원더풀 라이프' 리뷰 수집 완료! (5개)
# 📖 661/5572 - '살인 리스트' 리뷰 수집 완료! (5개)
# 📖 662/5572 - '비밀의 집' 리뷰 수집 완료! (5개)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[1], line 49
#      47 for index, book in enumerate(books_data, 1):
#      48     title = book["title"]
# ---> 49     reviews = search_blog_reviews(title)
#      51     if reviews:
#      52         book_reviews[title] = [review["description"] for review in reviews]
#
# Cell In[1], line 31, in search_blog_reviews(query, display, retries)
#      28 response = requests.get(url, headers=headers, params=params)
#      30 if response.status_code == 200:
# ---> 31     return response.json()["items"]
#      33 elif response.status_code == 429:
#      34     wait_time = (attempt + 1) * 5  # ✅ 5초, 10초, 15초 대기
#
# KeyError: 'items'

# %%
import requests
import json
import os
import time
from urllib3.exceptions import ProtocolError
from requests.exceptions import ConnectionError

# ✅ 네이버 API 환경변수 사용
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# ✅ 정제된 책 데이터 로드
with open("clean_mystery_books.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 네이버 블로그 검색 API 요청 함수 (429 오류 & RemoteDisconnected 예외 처리 추가)
def search_blog_reviews(query, display=5, retries=5):
    url = "https://openapi.naver.com/v1/search/blog.json"
    headers = {
        "X-Naver-Client-Id": CLIENT_ID,
        "X-Naver-Client-Secret": CLIENT_SECRET
    }
    params = {
        "query": query,
        "display": display,
        "sort": "sim"
    }



    for attempt in range(retries):  # ✅ 최대 5번 재시도
        try:
            response = requests.get(url, headers=headers, params=params, timeout=10)

            if response.status_code == 200:
                data = response.json()
                if "items" in data:
                    return data["items"]
                else:
                    print(f"⚠️ '{query}' 검색 결과 없음 (응답에 'items' 없음)")
                    return []

            elif response.status_code == 429:
                wait_time = (attempt + 1) * 5  # ✅ 5초, 10초, 15초, 20초 대기
                print(f"🚨 429 오류: 요청 속도 제한 초과! ({query}) - {attempt + 1}번째 재시도 후 {wait_time}초 대기...")
                time.sleep(wait_time)

            else:
                print(f"❌ API 요청 실패: {response.status_code}, 검색어: {query}")
                return []

        except (requests.exceptions.ConnectionError, requests.exceptions.Timeout, ProtocolError) as e:
            wait_time = (attempt + 1) * 5
            print(f"⚠️ 연결 오류: {query} ({str(e)}) - {attempt + 1}번째 재시도 후 {wait_time}초 대기...")
            time.sleep(wait_time)

    return []  # 5번 재시도 후에도 실패하면 빈 리스트 반환

# ✅ 순차적 크롤링 실행 (예외 처리 추가)
book_reviews = {}

for index, book in enumerate(books_data, 1):
    title = book.get("title", "제목 없음")  # ✅ title 키가 없을 경우 대비

    reviews = search_blog_reviews(title)
    
    if reviews:
        book_reviews[title] = [review["description"] for review in reviews]

    print(f"📖 {index}/{len(books_data)} - '{title}' 리뷰 수집 완료! ({len(reviews)}개)")
    
    time.sleep(3)  # ✅ API 요청 간격 증가 (429 & RemoteDisconnected 방지)

# ✅ 크롤링된 블로그 리뷰를 JSON 파일로 저장
with open("blog_reviews_sequential.json", "w", encoding="utf-8") as f:
    json.dump(book_reviews, f, ensure_ascii=False, indent=4)

print(f"✅ 총 {len(book_reviews)}권의 블로그 리뷰 저장 완료!")
# Out:
# 📖 1/5572 - '당신이 누군가를 죽였다' 리뷰 수집 완료! (5개)
# 📖 2/5572 - '용의자 X의 헌신' 리뷰 수집 완료! (5개)
# 📖 3/5572 - '악의' 리뷰 수집 완료! (5개)
# 📖 4/5572 - '비정근' 리뷰 수집 완료! (5개)
# 📖 5/5572 - '셜록 홈스의 모험' 리뷰 수집 완료! (5개)
# 📖 6/5572 - '리버 2' 리뷰 수집 완료! (5개)
# 📖 7/5572 - '리버 1' 리뷰 수집 완료! (5개)
# 📖 8/5572 - '미로장의 참극' 리뷰 수집 완료! (5개)
# 📖 9/5572 - '얼음 속의 여인' 리뷰 수집 완료! (5개)
# 📖 10/5572 - '성소의 참새' 리뷰 수집 완료! (5개)
# 📖 11/5572 - '귀신 들린 아이' 리뷰 수집 완료! (5개)
# 📖 12/5572 - '죽은 자의 몸값' 리뷰 수집 완료! (5개)
# 📖 13/5572 - '아이 윌 파인드 유' 리뷰 수집 완료! (5개)
# 📖 14/5572 - '고행의 순례자' 리뷰 수집 완료! (5개)
# 📖 15/5572 - '캐드펠 수사 시리즈' 리뷰 수집 완료! (5개)
# 📖 16/5572 - '청과 부동명왕' 리뷰 수집 완료! (5개)
# 📖 17/5572 - '아서 코난 도일, 선상 미스터리 단편 컬렉션' 리뷰 수집 완료! (5개)
# 📖 18/5572 - '아름답고 위험한 이름, 비너스' 리뷰 수집 완료! (5개)
# 📖 19/5572 - '시체 한 구가 더 있다' 리뷰 수집 완료! (5개)
# 📖 20/5572 - '수도사의 두건' 리뷰 수집 완료! (5개)
# 📖 21/5572 - '세인트자일스의 나환자' 리뷰 수집 완료! (5개)
# 📖 22/5572 - '성 베드로 축일' 리뷰 수집 완료! (5개)
# 📖 23/5572 - '에도가와 란포 기담집' 리뷰 수집 완료! (5개)
# 📖 24/5572 - '유골에 대한 기이한 취향' 리뷰 수집 완료! (5개)
# 📖 25/5572 - '마녀와의 7일' 리뷰 수집 완료! (5개)
# 📖 26/5572 - '추리소설가의 살인사건' 리뷰 수집 완료! (5개)
# 📖 27/5572 - '백설공주에게 죽음을' 리뷰 수집 완료! (5개)
# 📖 28/5572 - '장난감 괴물' 리뷰 수집 완료! (5개)
# 📖 29/5572 - '긴다이치 고스케 걸작선' 리뷰 수집 완료! (5개)
# 📖 30/5572 - '적월 세번째 공포단편' 리뷰 수집 완료! (2개)
# 📖 31/5572 - '셜록 홈즈 베스트12' 리뷰 수집 완료! (5개)
# 📖 32/5572 - '블랙 쇼맨과 운명의 바퀴' 리뷰 수집 완료! (5개)
# 📖 33/5572 - '히가시노 게이고 설산 시리즈' 리뷰 수집 완료! (5개)
# 📖 34/5572 - '여우의 계절' 리뷰 수집 완료! (5개)
# 📖 35/5572 - '페어워닝' 리뷰 수집 완료! (5개)
# 📖 36/5572 - '갈까마귀 살인사건' 리뷰 수집 완료! (5개)
# 📖 37/5572 - '금단의 마술' 리뷰 수집 완료! (5개)
# 📖 38/5572 - '죄의 경계' 리뷰 수집 완료! (5개)
# 📖 39/5572 - '닌자의 딸' 리뷰 수집 완료! (5개)
# 📖 40/5572 - '사자 츠나구 2' 리뷰 수집 완료! (5개)
# 📖 41/5572 - '괴도신사 아르센뤼팽' 리뷰 수집 완료! (5개)
# 📖 42/5572 - '레이크사이드' 리뷰 수집 완료! (5개)
# 📖 43/5572 - '페어리테일 1' 리뷰 수집 완료! (5개)
# 📖 44/5572 - '삼가 이와 같이 아뢰옵니다' 리뷰 수집 완료! (5개)
# 📖 45/5572 - '지옥: 신의 실수' 리뷰 수집 완료! (5개)
# 📖 46/5572 - '치유를 파는 찻집' 리뷰 수집 완료! (5개)
# 📖 47/5572 - '사자 츠나구 1' 리뷰 수집 완료! (5개)
# 📖 48/5572 - '매스커레이드 게임' 리뷰 수집 완료! (5개)
# 📖 49/5572 - '해피 벌쓰데이' 리뷰 수집 완료! (5개)
# 📖 50/5572 - '아르센 뤼팽과 셜록홈즈의 대결' 리뷰 수집 완료! (5개)
# 📖 51/5572 - '인플루언스' 리뷰 수집 완료! (5개)
# 📖 52/5572 - '형사 변호인' 리뷰 수집 완료! (5개)
# 📖 53/5572 - '컬트 1' 리뷰 수집 완료! (5개)
# 📖 54/5572 - '컬트 2' 리뷰 수집 완료! (5개)
# 📖 55/5572 - '컬트 3' 리뷰 수집 완료! (5개)
# 📖 56/5572 - '모성' 리뷰 수집 완료! (5개)
# 📖 57/5572 - '가모 저택 사건' 리뷰 수집 완료! (5개)
# 📖 58/5572 - '클론' 리뷰 수집 완료! (5개)
# 📖 59/5572 - '새왕의 방패' 리뷰 수집 완료! (5개)
# 📖 60/5572 - '탐정 페이터의 수사 일지' 리뷰 수집 완료! (3개)
# 📖 61/5572 - '굿 걸 배드 걸' 리뷰 수집 완료! (5개)
# 📖 62/5572 - '셜록홈즈 베스트 단편선 12' 리뷰 수집 완료! (5개)
# 📖 63/5572 - '나이츠 갬빗' 리뷰 수집 완료! (5개)
# 📖 64/5572 - '희망의 끈' 리뷰 수집 완료! (5개)
# 📖 65/5572 - '추리의 민족' 리뷰 수집 완료! (5개)
# 📖 66/5572 - '동물농장' 리뷰 수집 완료! (5개)
# 📖 67/5572 - '박스 1' 리뷰 수집 완료! (5개)
# 📖 68/5572 - '박스 2' 리뷰 수집 완료! (5개)
# 📖 69/5572 - '박스 3' 리뷰 수집 완료! (5개)
# 📖 70/5572 - '미러하우스' 리뷰 수집 완료! (5개)
# 📖 71/5572 - '돌이킬 수 없는 약속' 리뷰 수집 완료! (5개)
# 📖 72/5572 - '가면산장 살인사건' 리뷰 수집 완료! (5개)
# 📖 73/5572 - '외사랑' 리뷰 수집 완료! (5개)
# 📖 74/5572 - '고딕 X 호러 X 제주' 리뷰 수집 완료! (5개)
# 📖 75/5572 - '가족 대행소 에프' 리뷰 수집 완료! (2개)
# 📖 76/5572 - '봉제인형 살인사건 시리즈 소장본 박스 세트' 리뷰 수집 완료! (5개)
# 📖 77/5572 - '루팡의 딸 시리즈 소장본 박스 세트' 리뷰 수집 완료! (5개)
# 📖 78/5572 - '악연' 리뷰 수집 완료! (5개)
# 📖 79/5572 - '마녀의 은신처' 리뷰 수집 완료! (5개)
# 📖 80/5572 - '셜록 홈스 베스트 장편선 2' 리뷰 수집 완료! (5개)
# 📖 81/5572 - '루팡의 딸 5' 리뷰 수집 완료! (5개)
# 📖 82/5572 - '나중에' 리뷰 수집 완료! (5개)
# 📖 83/5572 - '아기를 부르는 그림' 리뷰 수집 완료! (5개)
# 📖 84/5572 - '에도가와 란포 호반정 사건' 리뷰 수집 완료! (5개)
# 📖 85/5572 - '소녀 지옥' 리뷰 수집 완료! (5개)
# 📖 86/5572 - '형사의 분노' 리뷰 수집 완료! (5개)
# 📖 87/5572 - '셜록 홈스의 모험' 리뷰 수집 완료! (5개)
# 📖 88/5572 - '흡혈귀' 리뷰 수집 완료! (5개)
# 📖 89/5572 - '아폴론 저축은행' 리뷰 수집 완료! (5개)
# 📖 90/5572 - '하카타 돈코츠 라멘즈 5' 리뷰 수집 완료! (5개)
# 📖 91/5572 - '하카타 돈코츠 라멘즈 6' 리뷰 수집 완료! (5개)
# 📖 92/5572 - '영원한 우정으로 2' 리뷰 수집 완료! (5개)
# 📖 93/5572 - '영원한 우정으로 1' 리뷰 수집 완료! (5개)
# 📖 94/5572 - '백조와 박쥐' 리뷰 수집 완료! (5개)
# 📖 95/5572 - '에도가와 란포 단편 추리소설 1' 리뷰 수집 완료! (5개)
# 📖 96/5572 - '사카구치 안고 추리소설 명작 1' 리뷰 수집 완료! (5개)
# 📖 97/5572 - '미궁' 리뷰 수집 완료! (5개)
# 📖 98/5572 - '야미하라' 리뷰 수집 완료! (5개)
# 📖 99/5572 - '인내상자' 리뷰 수집 완료! (5개)
# 📖 100/5572 - '봄에 나는 없었다' 리뷰 수집 완료! (5개)
# 📖 101/5572 - '딸은 딸이다' 리뷰 수집 완료! (5개)
# 📖 102/5572 - '살인의 문 1' 리뷰 수집 완료! (5개)
# 📖 103/5572 - '루팡의 딸 4' 리뷰 수집 완료! (5개)
# 📖 104/5572 - '사라지는 아들' 리뷰 수집 완료! (5개)
# 📖 105/5572 - '장미의 이름 세트' 리뷰 수집 완료! (5개)
# 📖 106/5572 - '질풍론도' 리뷰 수집 완료! (5개)
# 📖 107/5572 - '표정 없는 검사의 사투' 리뷰 수집 완료! (5개)
# 📖 108/5572 - '범인 없는 살인의 밤' 리뷰 수집 완료! (5개)
# 📖 109/5572 - '용의자 X의 헌신' 리뷰 수집 완료! (5개)
# 📖 110/5572 - '숙명' 리뷰 수집 완료! (5개)
# 📖 111/5572 - '회랑정 살인사건' 리뷰 수집 완료! (5개)
# 📖 112/5572 - '잠자는 숲' 리뷰 수집 완료! (5개)
# 📖 113/5572 - '플래티나 데이터' 리뷰 수집 완료! (5개)
# 📖 114/5572 - '둘 중 누군가 그녀를 죽였다' 리뷰 수집 완료! (5개)
# 📖 115/5572 - '루팡의 딸' 리뷰 수집 완료! (5개)
# 📖 116/5572 - '호랑이' 리뷰 수집 완료! (5개)
# 📖 117/5572 - '루팡의 딸 3' 리뷰 수집 완료! (5개)
# 📖 118/5572 - '사악한 늑대' 리뷰 수집 완료! (5개)
# 📖 119/5572 - '어센덴' 리뷰 수집 완료! (5개)
# 📖 120/5572 - '루팡의 딸 2' 리뷰 수집 완료! (5개)
# 📖 121/5572 - '핼러윈 파티  69 ㅣ 영화 '베니스 유령 살인사건' 원작)' 리뷰 수집 완료! (5개)
# 📖 122/5572 - '다섯 마리 아기 돼지' 리뷰 수집 완료! (5개)
# 📖 123/5572 - '낙원 2' 리뷰 수집 완료! (5개)
# 📖 124/5572 - '깨어진 거울' 리뷰 수집 완료! (5개)
# 📖 125/5572 - '크리스마스 푸딩의 모험' 리뷰 수집 완료! (5개)
# 📖 126/5572 - '장미의 이름' 리뷰 수집 완료! (5개)
# 📖 127/5572 - '마지막으로 죽음이 오다' 리뷰 수집 완료! (5개)
# 📖 128/5572 - '시계들  57)' 리뷰 수집 완료! (5개)
# 📖 129/5572 - '세븐 다이얼스 미스터리  35)' 리뷰 수집 완료! (5개)
# 📖 130/5572 - '잠자는 살인  73)' 리뷰 수집 완료! (5개)
# 📖 131/5572 - '갈색 양복의 사나이' 리뷰 수집 완료! (5개)
# 📖 132/5572 - '빛나는 청산가리  61)' 리뷰 수집 완료! (5개)
# 📖 133/5572 - '에지웨어 경의 죽음' 리뷰 수집 완료! (5개)
# 📖 134/5572 - '밤 산책' 리뷰 수집 완료! (5개)
# 📖 135/5572 - '죽은 자의 어리석음  72)' 리뷰 수집 완료! (5개)
# 📖 136/5572 - '히코리 디코리 독  71)' 리뷰 수집 완료! (5개)
# 📖 137/5572 - '애거서 크리스티 전집 21' 리뷰 수집 완료! (5개)
# 📖 138/5572 - '빛이 있는 동안' 리뷰 수집 완료! (5개)
# 📖 139/5572 - '엄지손가락의 아픔  60)' 리뷰 수집 완료! (5개)
# 📖 140/5572 - '푸아로의 크리스마스' 리뷰 수집 완료! (5개)
# 📖 141/5572 - '골프장 살인사건' 리뷰 수집 완료! (5개)
# 📖 142/5572 - '부부 탐정' 리뷰 수집 완료! (5개)
# 📖 143/5572 - '슬픈 사이프러스  47)' 리뷰 수집 완료! (5개)
# 📖 144/5572 - '가면무도회 1' 리뷰 수집 완료! (5개)
# 📖 145/5572 - '코끼리는 기억한다  59)' 리뷰 수집 완료! (5개)
# 📖 146/5572 - '신비의 사나이 할리퀸' 리뷰 수집 완료! (5개)
# 📖 147/5572 - '가면무도회 2' 리뷰 수집 완료! (5개)
# 📖 148/5572 - '시계관의 살인' 리뷰 수집 완료! (5개)
# 📖 149/5572 - '그들은 바그다드로 갔다  63)' 리뷰 수집 완료! (5개)
# 📖 150/5572 - '둔색환시행' 리뷰 수집 완료! (5개)
# 📖 151/5572 - '메소포타미아의 살인' 리뷰 수집 완료! (5개)
# 📖 152/5572 - '삼수탑' 리뷰 수집 완료! (5개)
# 📖 153/5572 - '0시를 향하여' 리뷰 수집 완료! (5개)
# 📖 154/5572 - 'ABC 살인사건' 리뷰 수집 완료! (5개)
# 📖 155/5572 - '백일홍 나무 아래' 리뷰 수집 완료! (5개)
# 📖 156/5572 - '프랑크푸르트 행 승객  66)' 리뷰 수집 완료! (5개)
# 📖 157/5572 - '서재의 시체' 리뷰 수집 완료! (5개)
# 📖 158/5572 - '회상 속의 살인' 리뷰 수집 완료! (5개)
# 📖 159/5572 - '아웃사이더 1~2 세트 - 전2권' 리뷰 수집 완료! (5개)
# 📖 160/5572 - '애거서 크리스티 전집 26   26)' 리뷰 수집 완료! (5개)
# 📖 161/5572 - '세상의 봄' 리뷰 수집 완료! (5개)
# 📖 162/5572 - '삼나무 관' 리뷰 수집 완료! (5개)
# 📖 163/5572 - '위치우드 살인사건' 리뷰 수집 완료! (5개)
# 📖 164/5572 - '벚꽃, 다시 벚꽃' 리뷰 수집 완료! (5개)
# 📖 165/5572 - '누명' 리뷰 수집 완료! (5개)
# 📖 166/5572 - '애거서 크리스티 에디터스 초이스 세트' 리뷰 수집 완료! (5개)
# 📖 167/5572 - '바그다드의 비밀' 리뷰 수집 완료! (5개)
# 📖 168/5572 - '패딩턴발 4시 50분' 리뷰 수집 완료! (5개)
# 📖 169/5572 - '비탄의 문 1' 리뷰 수집 완료! (5개)
# 📖 170/5572 - '끝없는 밤' 리뷰 수집 완료! (5개)
# 📖 171/5572 - '욕망을 파는 집 1' 리뷰 수집 완료! (5개)
# 📖 172/5572 - '운명의 문' 리뷰 수집 완료! (5개)
# 📖 173/5572 - '비밀결사' 리뷰 수집 완료! (5개)
# 📖 174/5572 - '비탄의 문 2' 리뷰 수집 완료! (5개)
# 📖 175/5572 - '미스마플 13수수께끼' 리뷰 수집 완료! (5개)
# 📖 176/5572 - '크리스마스 살인' 리뷰 수집 완료! (5개)
# 📖 177/5572 - '골프장 살인사건' 리뷰 수집 완료! (5개)
# 📖 178/5572 - '죽음의 사냥개' 리뷰 수집 완료! (5개)
# 📖 179/5572 - '셜록 홈즈 전집 세트' 리뷰 수집 완료! (5개)
# 📖 180/5572 - '주머니 속의 죽음' 리뷰 수집 완료! (5개)
# 📖 181/5572 - '코끼리는 기억한다' 리뷰 수집 완료! (5개)
# 📖 182/5572 - '죽음을 향한 발자국' 리뷰 수집 완료! (5개)
# 📖 183/5572 - '진상' 리뷰 수집 완료! (5개)
# 📖 184/5572 - '밤이 끝나는 곳' 리뷰 수집 완료! (5개)
# 📖 185/5572 - '사라진 왕국의 성' 리뷰 수집 완료! (5개)
# 📖 186/5572 - '엔드하우스의 비극' 리뷰 수집 완료! (5개)
# 📖 187/5572 - '헤이즐무어 살인사건' 리뷰 수집 완료! (5개)
# 📖 188/5572 - '0시간으로' 리뷰 수집 완료! (5개)
# 📖 189/5572 - '리스터데일 미스터리' 리뷰 수집 완료! (5개)
# 📖 190/5572 - '빅 포' 리뷰 수집 완료! (5개)
# 📖 191/5572 - '움직이는 손가락' 리뷰 수집 완료! (5개)
# 📖 192/5572 - '3막의 비극' 리뷰 수집 완료! (5개)
# 📖 193/5572 - '나일에서 죽다' 리뷰 수집 완료! (5개)
# 📖 194/5572 - '푸코의 진자 1' 리뷰 수집 완료! (5개)
# 📖 195/5572 - '사흘 그리고 한 인생' 리뷰 수집 완료! (5개)
# 📖 196/5572 - '주머니속의 죽음' 리뷰 수집 완료! (5개)
# 📖 197/5572 - '히코리 디코리 살인사건' 리뷰 수집 완료! (5개)
# 📖 198/5572 - '마술 살인' 리뷰 수집 완료! (5개)
# 📖 199/5572 - '움직이는 손가락' 리뷰 수집 완료! (5개)
# 📖 200/5572 - '복수의 여신' 리뷰 수집 완료! (5개)
# 📖 201/5572 - '벙어리 목격자' 리뷰 수집 완료! (5개)
# 📖 202/5572 - '푸코의 진자 2' 리뷰 수집 완료! (5개)
# 📖 203/5572 - '부머랭 살인사건' 리뷰 수집 완료! (5개)
# 📖 204/5572 - '애국 살인' 리뷰 수집 완료! (5개)
# 📖 205/5572 - '마지막으로 죽음이 온다' 리뷰 수집 완료! (5개)
# 📖 206/5572 - '예고살인' 리뷰 수집 완료! (5개)
# 📖 207/5572 - '목사관 살인사건' 리뷰 수집 완료! (5개)
# 📖 208/5572 - '침니스의 비밀' 리뷰 수집 완료! (5개)
# 📖 209/5572 - 'N 또는 M' 리뷰 수집 완료! (5개)
# 📖 210/5572 - '헤라클레스의 모험' 리뷰 수집 완료! (5개)
# 📖 211/5572 - '4개의 시계' 리뷰 수집 완료! (5개)
# 📖 212/5572 - '욕망을 파는 집 2' 리뷰 수집 완료! (5개)
# 📖 213/5572 - '끝없는 밤에 태어나다' 리뷰 수집 완료! (5개)
# 📖 214/5572 - '우리 이웃의 범죄' 리뷰 수집 완료! (5개)
# 📖 215/5572 - '명탐정 파커 파인' 리뷰 수집 완료! (5개)
# 📖 216/5572 - '13인의 만찬' 리뷰 수집 완료! (5개)
# 📖 217/5572 - '푸른 열차의 죽음' 리뷰 수집 완료! (5개)
# 📖 218/5572 - '커튼' 리뷰 수집 완료! (5개)
# 📖 219/5572 - '장례식을 마치고' 리뷰 수집 완료! (5개)
# 📖 220/5572 - '장례식을 마치고' 리뷰 수집 완료! (5개)
# 📖 221/5572 - '갈색 옷을 입은 사나이' 리뷰 수집 완료! (5개)
# 📖 222/5572 - '포와로 수사집' 리뷰 수집 완료! (5개)
# 📖 223/5572 - '깨어진 거울' 리뷰 수집 완료! (5개)
# 📖 224/5572 - '죽음과의 약속' 리뷰 수집 완료! (5개)
# 📖 225/5572 - 'ABC 살인사건' 리뷰 수집 완료! (5개)
# 📖 226/5572 - '크리스마스 살인' 리뷰 수집 완료! (5개)
# 📖 227/5572 - '스타일즈 저택괴사건' 리뷰 수집 완료! (5개)
# 📖 228/5572 - '움직이는 손가락' 리뷰 수집 완료! (5개)
# 📖 229/5572 - '메소포타미아의 죽음' 리뷰 수집 완료! (5개)
# 📖 230/5572 - '마술 살인' 리뷰 수집 완료! (5개)
# 📖 231/5572 - '엔드하우스의 비극' 리뷰 수집 완료! (5개)
# 📖 232/5572 - '창백한 말' 리뷰 수집 완료! (5개)
# 📖 233/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 234/5572 - '흑거미 클럽' 리뷰 수집 완료! (5개)
# 📖 235/5572 - '장례식을 끝내고' 리뷰 수집 완료! (5개)
# 📖 236/5572 - '잠자는 살인' 리뷰 수집 완료! (5개)
# 📖 237/5572 - '누명' 리뷰 수집 완료! (5개)
# 📖 238/5572 - '3막의 비극' 리뷰 수집 완료! (5개)
# 📖 239/5572 - '마지막으로 죽음이 오다' 리뷰 수집 완료! (5개)
# 📖 240/5572 - '비틀린 집' 리뷰 수집 완료! (5개)
# 📖 241/5572 - '바스커빌가의 개' 리뷰 수집 완료! (5개)
# 📖 242/5572 - '천사의 나이프' 리뷰 수집 완료! (5개)
# 📖 243/5572 - '우편배달부는 벨을 두번 울린다' 리뷰 수집 완료! (5개)
# 📖 244/5572 - '명탐정 푸아로 베스트 세트' 리뷰 수집 완료! (5개)
# 📖 245/5572 - '백주의 악마' 리뷰 수집 완료! (5개)
# 📖 246/5572 - '다섯 마리 아기 돼지' 리뷰 수집 완료! (5개)
# 📖 247/5572 - '나일강의 죽음' 리뷰 수집 완료! (5개)
# 📖 248/5572 - '죽은 자의 어리석음' 리뷰 수집 완료! (5개)
# 📖 249/5572 - '딸은 딸이다' 리뷰 수집 완료! (5개)
# 📖 250/5572 - '패배한 개' 리뷰 수집 완료! (5개)
# 📖 251/5572 - '엔드하우스의 비극' 리뷰 수집 완료! (5개)
# 📖 252/5572 - '메소포타미아의 살인' 리뷰 수집 완료! (5개)
# 📖 253/5572 - '죽음과의 약속' 리뷰 수집 완료! (5개)
# 📖 254/5572 - '오른쪽 주머니에서 나온 이야기' 리뷰 수집 완료! (5개)
# 📖 255/5572 - '오리엔트 특급살인' 리뷰 수집 완료! (5개)
# 📖 256/5572 - '장례식을 마치고' 리뷰 수집 완료! (5개)
# 📖 257/5572 - '구름 속의 죽음' 리뷰 수집 완료! (5개)
# 📖 258/5572 - '맥긴티 부인의 죽음' 리뷰 수집 완료! (5개)
# 📖 259/5572 - '애크로이드 살인사건' 리뷰 수집 완료! (5개)
# 📖 260/5572 - '서재의 시체' 리뷰 수집 완료! (5개)
# 📖 261/5572 - '에지웨어 경의 죽음  34)' 리뷰 수집 완료! (5개)
# 📖 262/5572 - '구름 속의 죽음' 리뷰 수집 완료! (5개)
# 📖 263/5572 - '고구레 사진관' 리뷰 수집 완료! (5개)
# 📖 264/5572 - '고구레 사진관' 리뷰 수집 완료! (5개)
# 📖 265/5572 - '화형 법정' 리뷰 수집 완료! (5개)
# 📖 266/5572 - '혼징살인사건' 리뷰 수집 완료! (5개)
# 📖 267/5572 - '포이즌 도터 홀리 마더' 리뷰 수집 완료! (5개)
# 📖 268/5572 - 'Y의 비극' 리뷰 수집 완료! (5개)
# 📖 269/5572 - '아웃사이더 2' 리뷰 수집 완료! (5개)
# 📖 270/5572 - '병원 고개의 목매달아 죽은 이의 집 1' 리뷰 수집 완료! (5개)
# 📖 271/5572 - '주홍색 연구 )' 리뷰 수집 완료! (5개)
# 📖 272/5572 - '그리스 관 미스터리' 리뷰 수집 완료! (5개)
# 📖 273/5572 - '수박 향기' 리뷰 수집 완료! (5개)
# 📖 274/5572 - '크로스 파이어 1' 리뷰 수집 완료! (5개)
# 📖 275/5572 - '황제의 코담뱃갑' 리뷰 수집 완료! (5개)
# 📖 276/5572 - '에도가와 란포' 리뷰 수집 완료! (5개)
# 📖 277/5572 - '게스트' 리뷰 수집 완료! (5개)
# 📖 278/5572 - '고교 입시' 리뷰 수집 완료! (5개)
# 📖 279/5572 - '소름' 리뷰 수집 완료! (5개)
# 📖 280/5572 - '주석 달린 셜록 홈즈 3' 리뷰 수집 완료! (5개)
# 📖 281/5572 - '기나긴 이별' 리뷰 수집 완료! (5개)
# 📖 282/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 283/5572 - '주석 달린 셜록 홈즈 5' 리뷰 수집 완료! (5개)
# 📖 284/5572 - '주석 달린 셜록 홈즈 6' 리뷰 수집 완료! (5개)
# 📖 285/5572 - '카페 홈즈의 마지막 사랑' 리뷰 수집 완료! (5개)
# 📖 286/5572 - '무당 거미의 이치' 리뷰 수집 완료! (5개)
# 📖 287/5572 - '용은 잠들다' 리뷰 수집 완료! (5개)
# 📖 288/5572 - '외딴섬 악마' 리뷰 수집 완료! (5개)
# 📖 289/5572 - '셜록 홈즈 더 얼티밋 에디션: 왓슨 편' 리뷰 수집 완료! (5개)
# 📖 290/5572 - 'XYZ의 비극' 리뷰 수집 완료! (5개)
# 📖 291/5572 - '셜록 홈즈 사건집' 리뷰 수집 완료! (5개)
# 📖 292/5572 - '네 사람의 서명' 리뷰 수집 완료! (5개)
# 📖 293/5572 - '무당 거미의 이치' 리뷰 수집 완료! (5개)
# 📖 294/5572 - '셜록 홈스의 모험' 리뷰 수집 완료! (5개)
# 📖 295/5572 - '인페르노' 리뷰 수집 완료! (5개)
# 📖 296/5572 - '무당 거미의 이치' 리뷰 수집 완료! (5개)
# 📖 297/5572 - '셜록 홈즈 단편 베스트 12' 리뷰 수집 완료! (5개)
# 📖 298/5572 - '검은집' 리뷰 수집 완료! (5개)
# 📖 299/5572 - '이탈리아 구두' 리뷰 수집 완료! (5개)
# 📖 300/5572 - '셜록 홈스 전집 단편집 세트' 리뷰 수집 완료! (5개)
# 📖 301/5572 - '바스커빌 가문의 사냥개' 리뷰 수집 완료! (5개)
# 📖 302/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 303/5572 - '셜록 홈즈의 모험' 리뷰 수집 완료! (5개)
# 📖 304/5572 - '주석 달린 셜록 홈즈 4' 리뷰 수집 완료! (5개)
# 📖 305/5572 - '셜록홈즈 걸작선 2' 리뷰 수집 완료! (5개)
# 📖 306/5572 - '셜록 1: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 307/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 308/5572 - '셜록 홈즈의 사건집' 리뷰 수집 완료! (5개)
# 📖 309/5572 - '셜록 홈즈 대표 단편선 23' 리뷰 수집 완료! (5개)
# 📖 310/5572 - '배스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 311/5572 - '셜록홈즈 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 312/5572 - '셜록홈즈 네 개의 기호' 리뷰 수집 완료! (5개)
# 📖 313/5572 - '셜록 홈즈의 모험 )' 리뷰 수집 완료! (5개)
# 📖 314/5572 - '돌아온 셜록 홈즈' 리뷰 수집 완료! (5개)
# 📖 315/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 316/5572 - '셜록홈즈 걸작선 3' 리뷰 수집 완료! (5개)
# 📖 317/5572 - '셜록홈즈 그의 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 318/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 319/5572 - '셜록 홈즈 Mini+ 전집: 바스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 320/5572 - '셜록 홈즈의 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 321/5572 - '푸코의 진자 3' 리뷰 수집 완료! (5개)
# 📖 322/5572 - '셜록 홈즈의 모험' 리뷰 수집 완료! (5개)
# 📖 323/5572 - '셜록 홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 324/5572 - '공포의 계곡 )' 리뷰 수집 완료! (5개)
# 📖 325/5572 - '셜록 홈즈의 회상' 리뷰 수집 완료! (5개)
# 📖 326/5572 - '셜록 홈즈의 귀환 )' 리뷰 수집 완료! (5개)
# 📖 327/5572 - '셜록 홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 328/5572 - '셜록 홈즈 전집 세트' 리뷰 수집 완료! (5개)
# 📖 329/5572 - '셜록홈즈 베스트 12' 리뷰 수집 완료! (5개)
# 📖 330/5572 - '셜록홈즈 걸작선' 리뷰 수집 완료! (5개)
# 📖 331/5572 - '바스커빌 씨네 사냥개' 리뷰 수집 완료! (5개)
# 📖 332/5572 - '셜록홈즈 베스트 단편선 13' 리뷰 수집 완료! (5개)
# 📖 333/5572 - '셜록홈즈 모험 걸작선' 리뷰 수집 완료! (5개)
# 📖 334/5572 - '셜록홈즈 배스커빌의 사냥개' 리뷰 수집 완료! (5개)
# 📖 335/5572 - '바스커빌가의 사냥개 )' 리뷰 수집 완료! (5개)
# 📖 336/5572 - '셜록홈즈의 회상' 리뷰 수집 완료! (5개)
# 📖 337/5572 - '셜록 홈즈' 리뷰 수집 완료! (5개)
# 📖 338/5572 - '셜록 홈즈의 회상' 리뷰 수집 완료! (5개)
# 📖 339/5572 - '홀로 남겨져' 리뷰 수집 완료! (5개)
# 📖 340/5572 - '명탐견 마사의 사건 일지' 리뷰 수집 완료! (5개)
# 📖 341/5572 - '셜록 홈스 단편선' 리뷰 수집 완료! (5개)
# 📖 342/5572 - '지옥의 어릿광대' 리뷰 수집 완료! (5개)
# 📖 343/5572 - '셜록 홈즈 베스트 10' 리뷰 수집 완료! (5개)
# 📖 344/5572 - '아버지들의 죄' 리뷰 수집 완료! (5개)
# 📖 345/5572 - '화형법정' 리뷰 수집 완료! (5개)
# 📖 346/5572 - '홈즈 단편베스트 걸작선 17' 리뷰 수집 완료! (5개)
# 📖 347/5572 - '새벽의 데드라인' 리뷰 수집 완료! (5개)
# 📖 348/5572 - '셜록홈즈 주홍색 습작' 리뷰 수집 완료! (5개)
# 📖 349/5572 - '셜록 홈즈의 사건' 리뷰 수집 완료! (5개)
# 📖 350/5572 - '말벌' 리뷰 수집 완료! (5개)
# 📖 351/5572 - '셜록홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 352/5572 - '셜록홈즈의 모험' 리뷰 수집 완료! (5개)
# 📖 353/5572 - '바스커빌의 개' 리뷰 수집 완료! (5개)
# 📖 354/5572 - '셜록 홈즈 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 355/5572 - '셜록 홈즈의 대활약' 리뷰 수집 완료! (5개)
# 📖 356/5572 - '미싱유' 리뷰 수집 완료! (5개)
# 📖 357/5572 - '리틀 시스터' 리뷰 수집 완료! (5개)
# 📖 358/5572 - '붉은 수확' 리뷰 수집 완료! (5개)
# 📖 359/5572 - '매그레와 벤치의 사나이' 리뷰 수집 완료! (5개)
# 📖 360/5572 - '판사와 형리' 리뷰 수집 완료! (5개)
# 📖 361/5572 - '황제의 코담뱃갑' 리뷰 수집 완료! (5개)
# 📖 362/5572 - '셜록 홈스: 바스커빌 가문의 사냥개' 리뷰 수집 완료! (5개)
# 📖 363/5572 - '셜록 홈스: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 364/5572 - '셜록 홈즈 더 얼티밋 에디션 세트' 리뷰 수집 완료! (5개)
# 📖 365/5572 - '셜록 홈스: 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 366/5572 - '셜록 홈즈 1: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 367/5572 - '셜록홈즈 8: 셜록 홈즈의 마지막 인사' 리뷰 수집 완료! (5개)
# 📖 368/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 369/5572 - '셜록 홈즈 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 370/5572 - '셜록 홈즈 9: 셜록 홈즈의 사건집' 리뷰 수집 완료! (5개)
# 📖 371/5572 - '셜록 홈즈 1: 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 372/5572 - '배스커빌가의 개' 리뷰 수집 완료! (5개)
# 📖 373/5572 - '주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 374/5572 - '셜록홈즈 7: 셜록 홈즈의 귀환' 리뷰 수집 완료! (5개)
# 📖 375/5572 - '셜록 홈즈 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 376/5572 - '네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 377/5572 - '셜록 홈즈 대표 장편선' 리뷰 수집 완료! (5개)
# 📖 378/5572 - '홈즈의 검은 그림자' 리뷰 수집 완료! (5개)
# 📖 379/5572 - '공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 380/5572 - '셜록 홈즈 2: 네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 381/5572 - '바스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 382/5572 - '셜록 홈즈 4: 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 383/5572 - '셜록 홈즈 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 384/5572 - '셜록 홈즈 2' 리뷰 수집 완료! (5개)
# 📖 385/5572 - '셜록 홈즈의 대표 걸작선' 리뷰 수집 완료! (5개)
# 📖 386/5572 - '셜록 홈즈 3: 배스커빌 가의 개' 리뷰 수집 완료! (5개)
# 📖 387/5572 - '네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 388/5572 - '셜록 홈즈 초판본 리커버 전집  + 셜록 홈즈 해설집)' 리뷰 수집 완료! (5개)
# 📖 389/5572 - '셜록홈즈 20' 리뷰 수집 완료! (5개)
# 📖 390/5572 - '바스커빌의 개' 리뷰 수집 완료! (5개)
# 📖 391/5572 - '셜록 홈즈 4: 공포의 계곡' 리뷰 수집 완료! (5개)
# 📖 392/5572 - '셜록홈즈 전집 세트' 리뷰 수집 완료! (5개)
# 📖 393/5572 - '셜록홈즈 스페셜 단편집' 리뷰 수집 완료! (5개)
# 📖 394/5572 - '네 개의 서명' 리뷰 수집 완료! (5개)
# 📖 395/5572 - '셜록 홈즈 단편 걸작선' 리뷰 수집 완료! (5개)
# 📖 396/5572 - '셜록 홈즈 주홍색 연구' 리뷰 수집 완료! (5개)
# 📖 397/5572 - '홈즈걸작선' 리뷰 수집 완료! (5개)
# 📖 398/5572 - '셜록 홈즈 명작선' 리뷰 수집 완료! (5개)
# 📖 399/5572 - '주홍색연구' 리뷰 수집 완료! (5개)
# 📖 400/5572 - '형사의 아이' 리뷰 수집 완료! (5개)
# 📖 401/5572 - '도박 눈' 리뷰 수집 완료! (5개)
# 📖 402/5572 - '기암성' 리뷰 수집 완료! (5개)
# 📖 403/5572 - '시체는 누구' 리뷰 수집 완료! (5개)
# 📖 404/5572 - '엘러리 퀸의 모험' 리뷰 수집 완료! (5개)
# 📖 405/5572 - '갈레 씨 홀로 죽다' 리뷰 수집 완료! (5개)
# 📖 406/5572 - '스페인 곶 미스터리' 리뷰 수집 완료! (5개)
# 📖 407/5572 - '에드거 앨런 포 베스트 단편선' 리뷰 수집 완료! (5개)
# 📖 408/5572 - '스트레인저' 리뷰 수집 완료! (5개)
# 📖 409/5572 - '레이디 조커 1' 리뷰 수집 완료! (5개)
# 📖 410/5572 - '그레이스 1' 리뷰 수집 완료! (5개)
# 📖 411/5572 - '마술사' 리뷰 수집 완료! (5개)
# 📖 412/5572 - '증인이 너무 많다' 리뷰 수집 완료! (5개)
# 📖 413/5572 - '노랑방의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 414/5572 - 'Z의 비극' 리뷰 수집 완료! (5개)
# 📖 415/5572 - '차이나 오렌지의 비밀' 리뷰 수집 완료! (5개)
# 📖 416/5572 - '자물쇠가 잠긴 방' 리뷰 수집 완료! (5개)
# 📖 417/5572 - '김유신의 머리일까' 리뷰 수집 완료! (5개)
# 📖 418/5572 - '아르센 뤼팽 전집 17' 리뷰 수집 완료! (5개)
# 📖 419/5572 - '아르센 뤼팽 전집 12)' 리뷰 수집 완료! (5개)
# 📖 420/5572 - '아르센 뤼팽 전집 3' 리뷰 수집 완료! (5개)
# 📖 421/5572 - '아르센 뤼팽 전집 14' 리뷰 수집 완료! (5개)
# 📖 422/5572 - '아르센 뤼팽 전집 11)' 리뷰 수집 완료! (5개)
# 📖 423/5572 - '아르센 뤼팽 전집 13' 리뷰 수집 완료! (5개)
# 📖 424/5572 - '아르센 뤼팽 전집 5' 리뷰 수집 완료! (5개)
# 📖 425/5572 - '아르센 뤼팽 전집 16' 리뷰 수집 완료! (5개)
# 📖 426/5572 - '아르센 뤼팽 전집 6' 리뷰 수집 완료! (5개)
# 📖 427/5572 - '아르센 뤼팽 전집 4' 리뷰 수집 완료! (5개)
# 📖 428/5572 - '무덤으로 향하다' 리뷰 수집 완료! (5개)
# 📖 429/5572 - '레이디 조커 2' 리뷰 수집 완료! (5개)
# 📖 430/5572 - '레이디 조커 3' 리뷰 수집 완료! (5개)
# 📖 431/5572 - '목 부러뜨리는 남자를 위한 협주곡' 리뷰 수집 완료! (5개)
# 📖 432/5572 - '마제스틱 호텔의 지하' 리뷰 수집 완료! (5개)
# 📖 433/5572 - '엽기의 말로' 리뷰 수집 완료! (5개)
# 📖 434/5572 - '뉴욕 미스터리' 리뷰 수집 완료! (5개)
# 📖 435/5572 - '난쟁이' 리뷰 수집 완료! (5개)
# 📖 436/5572 - '그리고 누군가 없어졌다' 리뷰 수집 완료! (5개)
# 📖 437/5572 - '교차로의 밤' 리뷰 수집 완료! (5개)
# 📖 438/5572 - '젤프의 기만' 리뷰 수집 완료! (5개)
# 📖 439/5572 - '살인과 창조의 시간' 리뷰 수집 완료! (5개)
# 📖 440/5572 - '루팡의 소식' 리뷰 수집 완료! (5개)
# 📖 441/5572 - '코끼리의 무덤은 없다' 리뷰 수집 완료! (5개)
# 📖 442/5572 - '도불의 연회: 연회의 준비' 리뷰 수집 완료! (5개)
# 📖 443/5572 - '생폴리앵에 지다' 리뷰 수집 완료! (5개)
# 📖 444/5572 - '대실 해밋 전집 세트' 리뷰 수집 완료! (5개)
# 📖 445/5572 - '죽음의 한가운데' 리뷰 수집 완료! (5개)
# 📖 446/5572 - 'Y의 비극' 리뷰 수집 완료! (5개)
# 📖 447/5572 - '코너스톤 3대 고전 추리소설 세트' 리뷰 수집 완료! (5개)
# 📖 448/5572 - '생사의 게임' 리뷰 수집 완료! (5개)
# 📖 449/5572 - '813' 리뷰 수집 완료! (5개)
# 📖 450/5572 - '엽기의 끝' 리뷰 수집 완료! (5개)
# 📖 451/5572 - '수정마개' 리뷰 수집 완료! (5개)
# 📖 452/5572 - '유리 열쇠' 리뷰 수집 완료! (5개)
# 📖 453/5572 - '지혜' 리뷰 수집 완료! (5개)
# 📖 454/5572 - '레베카 2' 리뷰 수집 완료! (5개)
# 📖 455/5572 - '안개의 항구' 리뷰 수집 완료! (5개)
# 📖 456/5572 - '의심' 리뷰 수집 완료! (5개)
# 📖 457/5572 - '벤슨 살인사건' 리뷰 수집 완료! (5개)
# 📖 458/5572 - '불연속 살인사건' 리뷰 수집 완료! (5개)
# 📖 459/5572 - '흑백의 여로' 리뷰 수집 완료! (5개)
# 📖 460/5572 - '제1호 수문' 리뷰 수집 완료! (5개)
# 📖 461/5572 - '상복의 랑데부' 리뷰 수집 완료! (5개)
# 📖 462/5572 - '의학의 초보자' 리뷰 수집 완료! (5개)
# 📖 463/5572 - '괴도신사 뤼팽' 리뷰 수집 완료! (5개)
# 📖 464/5572 - '뤼팽 대 홈즈' 리뷰 수집 완료! (5개)
# 📖 465/5572 - '기암성' 리뷰 수집 완료! (5개)
# 📖 466/5572 - '데인 가의 저주' 리뷰 수집 완료! (5개)
# 📖 467/5572 - '할루인 수사의 고백' 리뷰 수집 완료! (5개)
# 📖 468/5572 - '어둠 속의 갈가마귀' 리뷰 수집 완료! (5개)
# 📖 469/5572 - '그림자 없는 남자' 리뷰 수집 완료! (5개)
# 📖 470/5572 - '수정마개' 리뷰 수집 완료! (5개)
# 📖 471/5572 - '재앙의 거리' 리뷰 수집 완료! (5개)
# 📖 472/5572 - '플랑드르인의 집' 리뷰 수집 완료! (5개)
# 📖 473/5572 - '아르센 뤼팽 대 셜록 홈즈' 리뷰 수집 완료! (5개)
# 📖 474/5572 - '월식도의 마물' 리뷰 수집 완료! (5개)
# 📖 475/5572 - '허몽' 리뷰 수집 완료! (5개)
# 📖 476/5572 - '중간지점의 집' 리뷰 수집 완료! (5개)
# 📖 477/5572 - '나를 닮은 사람' 리뷰 수집 완료! (5개)
# 📖 478/5572 - '꼬리 아홉 고양이' 리뷰 수집 완료! (5개)
# 📖 479/5572 - '10일간의 불가사의' 리뷰 수집 완료! (5개)
# 📖 480/5572 - '맹독' 리뷰 수집 완료! (5개)
# 📖 481/5572 - '바리바 외' 리뷰 수집 완료! (5개)
# 📖 482/5572 - '괴도 루팽 추리 걸작선' 리뷰 수집 완료! (5개)
# 📖 483/5572 - '두 미소를 지닌 여인' 리뷰 수집 완료! (5개)
# 📖 484/5572 - '이상한 집' 리뷰 수집 완료! (5개)
# 📖 485/5572 - '광골의 꿈' 리뷰 수집 완료! (5개)
# 📖 486/5572 - '깊은 잠' 리뷰 수집 완료! (5개)
# 📖 487/5572 - '거대한 잠' 리뷰 수집 완료! (5개)
# 📖 488/5572 - '환상의 여자' 리뷰 수집 완료! (5개)
# 📖 489/5572 - '타인의 목' 리뷰 수집 완료! (5개)
# 📖 490/5572 - '아르센 뤼팽 전집 19' 리뷰 수집 완료! (5개)
# 📖 491/5572 - '아르센 뤼팽 전집 20: 마약수사원 빅토르' 리뷰 수집 완료! (5개)
# 📖 492/5572 - '초록 눈동자의 아가씨 외' 리뷰 수집 완료! (5개)
# 📖 493/5572 - '그리스 관의 비밀' 리뷰 수집 완료! (5개)
# 📖 494/5572 - '813의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 495/5572 - '실업자' 리뷰 수집 완료! (5개)
# 📖 496/5572 - '초록 눈의 아가씨' 리뷰 수집 완료! (5개)
# 📖 497/5572 - '드래건 살인사건' 리뷰 수집 완료! (5개)
# 📖 498/5572 - '뤼팽의 고백' 리뷰 수집 완료! (5개)
# 📖 499/5572 - '시계 종이 여덟 번 울릴 때' 리뷰 수집 완료! (5개)
# 📖 500/5572 - '프리즘' 리뷰 수집 완료! (5개)
# 📖 501/5572 - '신의 등불' 리뷰 수집 완료! (5개)
# 📖 502/5572 - '베르주라크의 광인' 리뷰 수집 완료! (5개)
# 📖 503/5572 - 'Z의비극' 리뷰 수집 완료! (5개)
# 📖 504/5572 - '로마 모자의 비밀' 리뷰 수집 완료! (5개)
# 📖 505/5572 - '칼리오스트로 백작부인의 복수' 리뷰 수집 완료! (5개)
# 📖 506/5572 - '괴도 루팽 추리 걸작선' 리뷰 수집 완료! (5개)
# 📖 507/5572 - '아르센 뤼팽 전집 8' 리뷰 수집 완료! (5개)
# 📖 508/5572 - '아르센 뤼팽 전집 15' 리뷰 수집 완료! (5개)
# 📖 509/5572 - '아르센 뤼팽 전집 10' 리뷰 수집 완료! (5개)
# 📖 510/5572 - '아르센 뤼팽 전집 9' 리뷰 수집 완료! (5개)
# 📖 511/5572 - '뤼팽 베스트 사건 파일' 리뷰 수집 완료! (5개)
# 📖 512/5572 - '벨벳의 악마' 리뷰 수집 완료! (5개)
# 📖 513/5572 - '크림슨의 미궁' 리뷰 수집 완료! (5개)
# 📖 514/5572 - '기암성' 리뷰 수집 완료! (5개)
# 📖 515/5572 - '두 가지 미소를 가진 여자' 리뷰 수집 완료! (5개)
# 📖 516/5572 - '살인방정식' 리뷰 수집 완료! (5개)
# 📖 517/5572 - '뤼뺑이냐 홈즈냐' 리뷰 수집 완료! (5개)
# 📖 518/5572 - '아르센 뤼팽 아르센 뤼팽의 대모험' 리뷰 수집 완료! (5개)
# 📖 519/5572 - '노란방의 비밀 1' 리뷰 수집 완료! (5개)
# 📖 520/5572 - '살인증후군' 리뷰 수집 완료! (5개)
# 📖 521/5572 - '광고하는 살인' 리뷰 수집 완료! (5개)
# 📖 522/5572 - '백귀야행 음' 리뷰 수집 완료! (5개)
# 📖 523/5572 - '살인예언자 1: 오드 토머스 첫 번째 이야기' 리뷰 수집 완료! (5개)
# 📖 524/5572 - '살인예언자 4: 오드 토머스와 흰 옷의 소녀' 리뷰 수집 완료! (5개)
# 📖 525/5572 - '이방인 1' 리뷰 수집 완료! (5개)
# 📖 526/5572 - '라 프로비당스호의 마부' 리뷰 수집 완료! (5개)
# 📖 527/5572 - '엔젤' 리뷰 수집 완료! (5개)
# 📖 528/5572 - '생피아크르 사건' 리뷰 수집 완료! (5개)
# 📖 529/5572 - '얼론 투게더' 리뷰 수집 완료! (5개)
# 📖 530/5572 - '괴도 뤼팽 추리 걸작선' 리뷰 수집 완료! (5개)
# 📖 531/5572 - '뤼팽 단편베스트 걸작선' 리뷰 수집 완료! (5개)
# 📖 532/5572 - '르윈터의 망명' 리뷰 수집 완료! (5개)
# 📖 533/5572 - '아르센 뤼팽 수정마개' 리뷰 수집 완료! (5개)
# 📖 534/5572 - '아르센 뤼팽 기암성' 리뷰 수집 완료! (5개)
# 📖 535/5572 - '813' 리뷰 수집 완료! (5개)
# 📖 536/5572 - '유다의 창' 리뷰 수집 완료! (5개)
# 📖 537/5572 - '황제의 코담베 케이스' 리뷰 수집 완료! (5개)
# 📖 538/5572 - '매그레 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 539/5572 - '유괴증후군' 리뷰 수집 완료! (5개)
# 📖 540/5572 - '실종증후군' 리뷰 수집 완료! (5개)
# 📖 541/5572 - '그때로 다시 돌아간다면' 리뷰 수집 완료! (5개)
# 📖 542/5572 - '두려움보다 강한 감정' 리뷰 수집 완료! (5개)
# 📖 543/5572 - '탐정 백작과 나' 리뷰 수집 완료! (5개)
# 📖 544/5572 - '런던 필즈 1' 리뷰 수집 완료! (5개)
# 📖 545/5572 - '체인 포이즌' 리뷰 수집 완료! (5개)
# 📖 546/5572 - '악몽의 관람차' 리뷰 수집 완료! (5개)
# 📖 547/5572 - '텔로미어' 리뷰 수집 완료! (5개)
# 📖 548/5572 - '죽은 자의 블랙박스를 요청합니다' 리뷰 수집 완료! (5개)
# 📖 549/5572 - '엘리펀트 헤드' 리뷰 수집 완료! (5개)
# 📖 550/5572 - '재버워크의 밤' 리뷰 수집 완료! (5개)
# 📖 551/5572 - '말로 머더 클럽' 리뷰 수집 완료! (5개)
# 📖 552/5572 - '육법추리' 리뷰 수집 완료! (5개)
# 📖 553/5572 - '희대의 비극' 리뷰 수집 완료! (5개)
# 📖 554/5572 - '아이는 무서운 꿈을 꾼다' 리뷰 수집 완료! (5개)
# 📖 555/5572 - '살인 매거진' 리뷰 수집 완료! (5개)
# 📖 556/5572 - '영원의 1초는 얼마인가' 리뷰 수집 완료! (5개)
# 📖 557/5572 - '인버트' 리뷰 수집 완료! (5개)
# 📖 558/5572 - '궁극의 아이 2: 넥스트 차일드' 리뷰 수집 완료! (5개)
# 📖 559/5572 - '궁극의 아이 세트' 리뷰 수집 완료! (5개)
# 📖 560/5572 - '언니의 실종에 관한 48 단서들' 리뷰 수집 완료! (5개)
# 📖 561/5572 - '제로의 늦여름' 리뷰 수집 완료! (5개)
# 📖 562/5572 - '남편을 죽이는 서른 가지 방법' 리뷰 수집 완료! (5개)
# 📖 563/5572 - '4일 간의 가족' 리뷰 수집 완료! (5개)
# 📖 564/5572 - '그녀의 취미생활' 리뷰 수집 완료! (5개)
# 📖 565/5572 - '까마귀 장례식' 리뷰 수집 완료! (5개)
# 📖 566/5572 - '당신의 비밀' 리뷰 수집 완료! (5개)
# 📖 567/5572 - '테사를 찾아서' 리뷰 수집 완료! (5개)
# 📖 568/5572 - '내가 선생님을 죽였다' 리뷰 수집 완료! (5개)
# 📖 569/5572 - '치팅 데이' 리뷰 수집 완료! (5개)
# 📖 570/5572 - '카스트라토: 거세당한 자' 리뷰 수집 완료! (5개)
# 📖 571/5572 - '중편들, 한국 공포문학의 밤 세트' 리뷰 수집 완료! (5개)
# 📖 572/5572 - '중편들, 한국 공포문학의 밤 수요일: 허수아비' 리뷰 수집 완료! (5개)
# 📖 573/5572 - '중편들, 한국 공포문학의 밤 금요일: 벽지 뜯기' 리뷰 수집 완료! (5개)
# 📖 574/5572 - '중편들, 한국 공포문학의 밤 화요일: 사람의 심해' 리뷰 수집 완료! (5개)
# 📖 575/5572 - '중편들, 한국 공포문학의 밤 월요일: 앨리게이터' 리뷰 수집 완료! (5개)
# 📖 576/5572 - '중편들, 한국 공포문학의 밤 일요일: 제로' 리뷰 수집 완료! (5개)
# 📖 577/5572 - '중편들, 한국 공포문학의 밤 토요일: 우물' 리뷰 수집 완료! (5개)
# 📖 578/5572 - '중편들, 한국 공포문학의 밤 목요일: 액연' 리뷰 수집 완료! (5개)
# 📖 579/5572 - '최면술사의 시대' 리뷰 수집 완료! (5개)
# 📖 580/5572 - '기묘한 밤' 리뷰 수집 완료! (5개)
# 📖 581/5572 - '마더: 무덤에서 돌아온 여자' 리뷰 수집 완료! (5개)
# 📖 582/5572 - '완벽한 세상' 리뷰 수집 완료! (5개)
# 📖 583/5572 - '오렌지와 빵칼' 리뷰 수집 완료! (5개)
# 📖 584/5572 - '아침과 저녁의 범죄' 리뷰 수집 완료! (5개)
# 📖 585/5572 - '가연물' 리뷰 수집 완료! (5개)
# 📖 586/5572 - '엄마, 시체를 부탁해' 리뷰 수집 완료! (5개)
# 📖 587/5572 - '악의 고해소' 리뷰 수집 완료! (5개)
# 📖 588/5572 - '기암관의 살인' 리뷰 수집 완료! (5개)
# 📖 589/5572 - '숨겨진 건 죽음' 리뷰 수집 완료! (5개)
# 📖 590/5572 - '런던 비밀 강령회' 리뷰 수집 완료! (5개)
# 📖 591/5572 - '너는 미스터리가 읽고 싶다' 리뷰 수집 완료! (5개)
# 📖 592/5572 - '테사를 찾아서' 리뷰 수집 완료! (5개)
# 📖 593/5572 - '분노의 히어로' 리뷰 수집 완료! (5개)
# 📖 594/5572 - '마피아 찾기' 리뷰 수집 완료! (5개)
# 📖 595/5572 - '엘라의 작은 모험' 리뷰 수집 완료! (5개)
# 📖 596/5572 - '귀우' 리뷰 수집 완료! (5개)
# 📖 597/5572 - '어둠 속의 비행 소년들' 리뷰 수집 완료! (5개)
# 📖 598/5572 - '내가 대답하는 너의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 599/5572 - '누가 제이슨 벨을 죽였나' 리뷰 수집 완료! (5개)
# 📖 600/5572 - '총원산' 리뷰 수집 완료! (5개)
# 📖 601/5572 - '도깨비 사냥' 리뷰 수집 완료! (5개)
# 📖 602/5572 - '킬에이저' 리뷰 수집 완료! (5개)
# 📖 603/5572 - '목걸이 사건의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 604/5572 - '행복도 사람들' 리뷰 수집 완료! (5개)
# 📖 605/5572 - '마치 박사의 네 아들' 리뷰 수집 완료! (5개)
# 📖 606/5572 - '미제레레' 리뷰 수집 완료! (5개)
# 📖 607/5572 - '5번의 죽음 6번의 목숨' 리뷰 수집 완료! (5개)
# 📖 608/5572 - '밤이 길었던 날' 리뷰 수집 완료! (5개)
# 📖 609/5572 - '밤은 눈을 감지 않는다' 리뷰 수집 완료! (5개)
# 📖 610/5572 - '도난: 숨겨진 세계' 리뷰 수집 완료! (5개)
# 📖 611/5572 - '걷는 망자' 리뷰 수집 완료! (5개)
# 📖 612/5572 - '물속의 입' 리뷰 수집 완료! (5개)
# 📖 613/5572 - '따뜻한 손' 리뷰 수집 완료! (5개)
# 📖 614/5572 - '십계' 리뷰 수집 완료! (5개)
# 📖 615/5572 - '아이가 없는 집' 리뷰 수집 완료! (5개)
# 📖 616/5572 - '로건과 샬롯의 탐정일기 : 연쇄살인범의 게임' 리뷰 수집 완료! (5개)
# 📖 617/5572 - '미친 X들' 리뷰 수집 완료! (5개)
# 📖 618/5572 - '사라진 호텔, 겟로스트' 리뷰 수집 완료! (0개)
# 📖 619/5572 - '배드트립' 리뷰 수집 완료! (5개)
# 📖 620/5572 - '기기괴괴 중국 도시 괴담집' 리뷰 수집 완료! (5개)
# 📖 621/5572 - '다크 디텍티브' 리뷰 수집 완료! (5개)
# 📖 622/5572 - 'mymy' 리뷰 수집 완료! (5개)
# 📖 623/5572 - '밤이 길었던 날' 리뷰 수집 완료! (5개)
# 📖 624/5572 - '살인 리스트' 리뷰 수집 완료! (5개)
# 📖 625/5572 - '아름답게 자란 B친여자' 리뷰 수집 완료! (4개)
# 📖 626/5572 - '활자잔혹극' 리뷰 수집 완료! (5개)
# 📖 627/5572 - '바츠먼의 변호인' 리뷰 수집 완료! (5개)
# 📖 628/5572 - '죽이고 싶은 남편들' 리뷰 수집 완료! (5개)
# 📖 629/5572 - '끝없는 바닥' 리뷰 수집 완료! (5개)
# 📖 630/5572 - '달콤한 살인 계획' 리뷰 수집 완료! (5개)
# 📖 631/5572 - '로스트' 리뷰 수집 완료! (5개)
# 📖 632/5572 - '마담 흑조는 곤란한 이야기를 청한다' 리뷰 수집 완료! (5개)
# 📖 633/5572 - '늑대와 토끼의 게임' 리뷰 수집 완료! (5개)
# 📖 634/5572 - '영혼을 단장해드립니다, 챠밍 미용실' 리뷰 수집 완료! (5개)
# 📖 635/5572 - '성스러운 술집이 문 닫을 때' 리뷰 수집 완료! (5개)
# 📖 636/5572 - '부산 느와르 미스터리' 리뷰 수집 완료! (5개)
# 📖 637/5572 - '문이 열리면' 리뷰 수집 완료! (5개)
# 📖 638/5572 - '뱀파이어 탐정단' 리뷰 수집 완료! (5개)
# 📖 639/5572 - 'Tiger' 리뷰 수집 완료! (5개)
# 📖 640/5572 - '꽃다발은 독' 리뷰 수집 완료! (5개)
# 📖 641/5572 - '살인자는 천국에 있다' 리뷰 수집 완료! (5개)
# 📖 642/5572 - '어디에도 휘파람은 없다' 리뷰 수집 완료! (5개)
# 📖 643/5572 - '헤이그의 비밀' 리뷰 수집 완료! (5개)
# 📖 644/5572 - '귀축의 집' 리뷰 수집 완료! (5개)
# 📖 645/5572 - '삶, 범죄자의.' 리뷰 수집 완료! (5개)
# 📖 646/5572 - '지하실의 새' 리뷰 수집 완료! (5개)
# 📖 647/5572 - '뚜식이의 과학일기 2: 미스터리 범죄' 리뷰 수집 완료! (5개)
# 📖 648/5572 - '하이드의 귀환' 리뷰 수집 완료! (5개)
# 📖 649/5572 - '210번관에 어서 오세요' 리뷰 수집 완료! (5개)
# 📖 650/5572 - '연쇄삶인' 리뷰 수집 완료! (5개)
# 📖 651/5572 - '헤드헌터' 리뷰 수집 완료! (5개)
# 📖 652/5572 - '할머니의 야구공' 리뷰 수집 완료! (5개)
# 📖 653/5572 - '전지적 감시자 시점' 리뷰 수집 완료! (5개)
# 📖 654/5572 - '형사刑事 이야기, 윤계식 1' 리뷰 수집 완료! (5개)
# 📖 655/5572 - '형사刑事 이야기, 윤계식 2 完' 리뷰 수집 완료! (5개)
# 📖 656/5572 - '역광' 리뷰 수집 완료! (5개)
# 📖 657/5572 - 'I의 비극' 리뷰 수집 완료! (5개)
# 📖 658/5572 - '한국추리문학상 황금펜상 수상작품집: 2023년 제17회' 리뷰 수집 완료! (5개)
# 📖 659/5572 - '도쿄 사기꾼들' 리뷰 수집 완료! (5개)
# 📖 660/5572 - '원더풀 라이프' 리뷰 수집 완료! (5개)
# 📖 661/5572 - '살인 리스트' 리뷰 수집 완료! (5개)
# 📖 662/5572 - '비밀의 집' 리뷰 수집 완료! (5개)
# ⚠️ '빨간 집' 검색 결과 없음 (응답에 'items' 없음)
# 📖 663/5572 - '빨간 집' 리뷰 수집 완료! (0개)
# 📖 664/5572 - '이성과 본능' 리뷰 수집 완료! (5개)
# 📖 665/5572 - '레디 슛' 리뷰 수집 완료! (5개)
# 📖 666/5572 - '금붕어 룰렛' 리뷰 수집 완료! (5개)
# 📖 667/5572 - '새들의 집' 리뷰 수집 완료! (5개)
# 📖 668/5572 - '시공여행자의 모래시계' 리뷰 수집 완료! (5개)
# 📖 669/5572 - '옐로우 레이디' 리뷰 수집 완료! (5개)
# 📖 670/5572 - '이름 없는 여자들의 궁궐 기담' 리뷰 수집 완료! (5개)
# 📖 671/5572 - '그리고 너는 속고 있다' 리뷰 수집 완료! (5개)
# 📖 672/5572 - '수호신' 리뷰 수집 완료! (5개)
# 📖 673/5572 - '사례 연구' 리뷰 수집 완료! (5개)
# 📖 674/5572 - '카인의 오만' 리뷰 수집 완료! (5개)
# 📖 675/5572 - '백만 유튜버 죽이기' 리뷰 수집 완료! (5개)
# 📖 676/5572 - '야구자' 리뷰 수집 완료! (5개)
# 📖 677/5572 - '송곳니' 리뷰 수집 완료! (5개)
# ⚠️ '빨간 집' 검색 결과 없음 (응답에 'items' 없음)
# 📖 678/5572 - '빨간 집' 리뷰 수집 완료! (0개)
# 📖 679/5572 - '그림자 속의 속삭임' 리뷰 수집 완료! (5개)
# 📖 680/5572 - '법정유희' 리뷰 수집 완료! (5개)
# 📖 681/5572 - '붉은 상자' 리뷰 수집 완료! (5개)
# 📖 682/5572 - '앤티크 숍 THE MOON' 리뷰 수집 완료! (5개)
# 📖 683/5572 - '유미의 공부' 리뷰 수집 완료! (5개)
# 📖 684/5572 - '타오르는 폐곡선' 리뷰 수집 완료! (5개)
# 📖 685/5572 - '덧없는 양들의 축연' 리뷰 수집 완료! (5개)
# 📖 686/5572 - '마라의 요람' 리뷰 수집 완료! (5개)
# 📖 687/5572 - '마이크 해머 시리즈 세트' 리뷰 수집 완료! (5개)
# 📖 688/5572 - 'ㅈㄱ거래' 리뷰 수집 완료! (5개)
# 📖 689/5572 - '당근의 추억 2' 리뷰 수집 완료! (5개)
# 📖 690/5572 - '렉카 김재희' 리뷰 수집 완료! (5개)
# 📖 691/5572 - '요괴' 리뷰 수집 완료! (5개)
# 📖 692/5572 - '교수상회' 리뷰 수집 완료! (5개)
# 📖 693/5572 - '비밀의 집' 리뷰 수집 완료! (5개)
# 📖 694/5572 - '고양이가 보았어' 리뷰 수집 완료! (5개)
# 📖 695/5572 - '우리 가족은 모두 살인자다' 리뷰 수집 완료! (5개)
# 📖 696/5572 - '트윈 풀 호텔의 살인 사건' 리뷰 수집 완료! (5개)
# 📖 697/5572 - '흥민 빌라 404' 리뷰 수집 완료! (0개)
# 📖 698/5572 - '특수청소부' 리뷰 수집 완료! (5개)
# 📖 699/5572 - '별에서의 살인' 리뷰 수집 완료! (5개)
# 📖 700/5572 - '시간을 거슬러 간 나비' 리뷰 수집 완료! (5개)
# 📖 701/5572 - '명탐정의 창자' 리뷰 수집 완료! (5개)
# 📖 702/5572 - '제니로 알려진 노금희' 리뷰 수집 완료! (0개)
# 📖 703/5572 - '속임수의 섬' 리뷰 수집 완료! (5개)
# 📖 704/5572 - 'Zzz Virus' 리뷰 수집 완료! (5개)
# 📖 705/5572 - '진 버든' 리뷰 수집 완료! (5개)
# ⚠️ '죽이고 싶지만 섹스는 하고 싶어' 검색 결과 없음 (응답에 'items' 없음)
# 📖 706/5572 - '죽이고 싶지만 섹스는 하고 싶어' 리뷰 수집 완료! (0개)
# 📖 707/5572 - '내가 너와 만나 사랑에 빠질 확률' 리뷰 수집 완료! (5개)
# 📖 708/5572 - '타인의 숲' 리뷰 수집 완료! (5개)
# 📖 709/5572 - '기생록' 리뷰 수집 완료! (5개)
# 📖 710/5572 - '완전 부부 범죄' 리뷰 수집 완료! (5개)
# 📖 711/5572 - '살해되려는 욕구' 리뷰 수집 완료! (5개)
# 📖 712/5572 - '묵시록 살인사건' 리뷰 수집 완료! (5개)
# 📖 713/5572 - '비앙또 단편선' 리뷰 수집 완료! (5개)
# 📖 714/5572 - '호수 속의 여인' 리뷰 수집 완료! (5개)
# 📖 715/5572 - '감찰무녀전' 리뷰 수집 완료! (5개)
# 📖 716/5572 - '호랑이 부름' 리뷰 수집 완료! (5개)
# 📖 717/5572 - '피라미드' 리뷰 수집 완료! (5개)
# 📖 718/5572 - '휴브리스' 리뷰 수집 완료! (5개)
# 📖 719/5572 - '마트료시카의 밤' 리뷰 수집 완료! (5개)
# 📖 720/5572 - '오프라인' 리뷰 수집 완료! (5개)
# 📖 721/5572 - '디 앱' 리뷰 수집 완료! (5개)
# 📖 722/5572 - '세상 끝의 살인' 리뷰 수집 완료! (5개)
# 📖 723/5572 - '직감과 두려움' 리뷰 수집 완료! (5개)
# 📖 724/5572 - '표리부동' 리뷰 수집 완료! (5개)
# 📖 725/5572 - '오피스 괴담' 리뷰 수집 완료! (5개)
# 📖 726/5572 - '신을 죽인 여자들' 리뷰 수집 완료! (5개)
# 📖 727/5572 - '블랙 아이스' 리뷰 수집 완료! (5개)
# 📖 728/5572 - '시그널 2' 리뷰 수집 완료! (5개)
# 📖 729/5572 - '한국추리문학상 황금펜상 수상작품집: 2023년 제17회' 리뷰 수집 완료! (5개)
# 📖 730/5572 - '페일 블루 아이' 리뷰 수집 완료! (5개)
# 📖 731/5572 - '아홉 꼬리의 전설' 리뷰 수집 완료! (5개)
# 📖 732/5572 - '인형의 집의 참극' 리뷰 수집 완료! (5개)
# 📖 733/5572 - '비로소 내가 되었다' 리뷰 수집 완료! (5개)
# 📖 734/5572 - '테러리스트' 리뷰 수집 완료! (5개)
# 📖 735/5572 - '몽키스 구단 미해결 사건집' 리뷰 수집 완료! (5개)
# 📖 736/5572 - '항설백물어 세트 - 전4권' 리뷰 수집 완료! (5개)
# 📖 737/5572 - '몽키스 구단 에이스팀 사건집 세트' 리뷰 수집 완료! (5개)
# 📖 738/5572 - '폭발물 처리반이 조우한 스핀' 리뷰 수집 완료! (5개)
# 📖 739/5572 - '다다상조 회사' 리뷰 수집 완료! (5개)
# 📖 740/5572 - '알마티의 현금 밴' 리뷰 수집 완료! (5개)
# 📖 741/5572 - '트럼프 죽이기' 리뷰 수집 완료! (5개)
# 📖 742/5572 - '이토록 완벽한 실종' 리뷰 수집 완료! (5개)
# 📖 743/5572 - '진 버든' 리뷰 수집 완료! (5개)
# 📖 744/5572 - '기억 속의 유괴' 리뷰 수집 완료! (5개)
# 📖 745/5572 - '감귤마켓 셜록' 리뷰 수집 완료! (5개)
# 📖 746/5572 - '모조품' 리뷰 수집 완료! (5개)
# 📖 747/5572 - '막장의 품격' 리뷰 수집 완료! (5개)
# 📖 748/5572 - '킴 스톤 4: 죽음의 연극' 리뷰 수집 완료! (5개)
# 📖 749/5572 - '포스트 캡슐' 리뷰 수집 완료! (5개)
# 📖 750/5572 - '레몬과 살인귀' 리뷰 수집 완료! (5개)
# 📖 751/5572 - '스네이크 아일랜드 1권 죽고 싶지만 복수는 하고 싶어' 리뷰 수집 완료! (0개)
# 📖 752/5572 - '레귤러 가족' 리뷰 수집 완료! (5개)
# 📖 753/5572 - '돌봄살인' 리뷰 수집 완료! (5개)
# 📖 754/5572 - '전기인간의 공포' 리뷰 수집 완료! (5개)
# 📖 755/5572 - '레몬과 살인귀' 리뷰 수집 완료! (5개)
# 📖 756/5572 - '여섯 번째 살인' 리뷰 수집 완료! (5개)
# 📖 757/5572 - '굿 걸, 배드 블러드' 리뷰 수집 완료! (5개)
# 📖 758/5572 - '폭포의 밤' 리뷰 수집 완료! (5개)
# 📖 759/5572 - '당신에게 보내는 도전장' 리뷰 수집 완료! (5개)
# 📖 760/5572 - '공정의 파수꾼' 리뷰 수집 완료! (5개)
# 📖 761/5572 - '이브의 대관람차' 리뷰 수집 완료! (5개)
# 📖 762/5572 - '경범죄 전문 흥신소' 리뷰 수집 완료! (5개)
# 📖 763/5572 - '1961 도쿄 하우스' 리뷰 수집 완료! (5개)
# 📖 764/5572 - '목소리' 리뷰 수집 완료! (5개)
# 📖 765/5572 - '복수의 협주곡' 리뷰 수집 완료! (5개)
# 📖 766/5572 - '흉인저의 살인' 리뷰 수집 완료! (5개)
# 📖 767/5572 - '미스터리한 러브스토리' 리뷰 수집 완료! (5개)
# 📖 768/5572 - '사랑에 이르는 병' 리뷰 수집 완료! (5개)
# 📖 769/5572 - '평양골드러시' 리뷰 수집 완료! (5개)
# 📖 770/5572 - '카니발리즘' 리뷰 수집 완료! (5개)
# 📖 771/5572 - '내가 최선을 다하지 않았다고' 리뷰 수집 완료! (5개)
# 📖 772/5572 - '퀀트, 아리아, 도마' 리뷰 수집 완료! (2개)
# 📖 773/5572 - '테디베어는 죽지 않아' 리뷰 수집 완료! (5개)
# 📖 774/5572 - '드라이버에 40번 찔린 시체에 관하여' 리뷰 수집 완료! (5개)
# 📖 775/5572 - '붉은 박물관' 리뷰 수집 완료! (5개)
# 📖 776/5572 - 'AI 미제 사건 전담반' 리뷰 수집 완료! (5개)
# 📖 777/5572 - '섀도 하우스' 리뷰 수집 완료! (5개)
# 📖 778/5572 - '6시 20분의 남자' 리뷰 수집 완료! (5개)
# 📖 779/5572 - '잘못된 장소 잘못된 시간' 리뷰 수집 완료! (5개)
# 📖 780/5572 - '습기' 리뷰 수집 완료! (5개)
# 📖 781/5572 - '명탐정으로 있어줘' 리뷰 수집 완료! (5개)
# 📖 782/5572 - '불특정 다수' 리뷰 수집 완료! (5개)
# 📖 783/5572 - '가짜 영매사' 리뷰 수집 완료! (5개)
# 📖 784/5572 - '초대받지 않은 손님들을 위한 뷔페' 리뷰 수집 완료! (5개)
# 📖 785/5572 - '내 이름의 살인자' 리뷰 수집 완료! (5개)
# 📖 786/5572 - '미스터리 살인 사건 7+1' 리뷰 수집 완료! (5개)
# 📖 787/5572 - '중요한 건 살인' 리뷰 수집 완료! (5개)
# 📖 788/5572 - '죽이기 시리즈 4종 세트' 리뷰 수집 완료! (5개)
# 📖 789/5572 - '코인' 리뷰 수집 완료! (5개)
# 📖 790/5572 - '그림자 인간' 리뷰 수집 완료! (5개)
# 📖 791/5572 - '너의 퀴즈' 리뷰 수집 완료! (5개)
# 📖 792/5572 - '악어의 눈물' 리뷰 수집 완료! (5개)
# 📖 793/5572 - '불귀도 살인사건' 리뷰 수집 완료! (5개)
# 📖 794/5572 - '유리의 성벽' 리뷰 수집 완료! (5개)
# 📖 795/5572 - '마지막 수학시간' 리뷰 수집 완료! (5개)
# 📖 796/5572 - '악의 사냥' 리뷰 수집 완료! (5개)
# 📖 797/5572 - '데니스 에버 애프터' 리뷰 수집 완료! (5개)
# 📖 798/5572 - '이상한 그림' 리뷰 수집 완료! (5개)
# 📖 799/5572 - '명탐정의 제물' 리뷰 수집 완료! (5개)
# 📖 800/5572 - '빨간 모자, 피노키오를 줍고 시체를 만났습니다' 리뷰 수집 완료! (5개)
# 📖 801/5572 - '나는 그녀를 모른다' 리뷰 수집 완료! (5개)
# 📖 802/5572 - '우리가 세상을 바꿀 수 없다면 1' 리뷰 수집 완료! (5개)
# 📖 803/5572 - '추상오단장' 리뷰 수집 완료! (5개)
# 📖 804/5572 - '이름 없는 별의 비가' 리뷰 수집 완료! (5개)
# 📖 805/5572 - '구속' 리뷰 수집 완료! (5개)
# 📖 806/5572 - '나는 실수로 투명인간을 죽였다' 리뷰 수집 완료! (5개)
# 📖 807/5572 - '안개꽃 빌라의 탐식가들' 리뷰 수집 완료! (5개)
# 📖 808/5572 - '거짓과 상상 혹은 죄와 벌' 리뷰 수집 완료! (5개)
# 📖 809/5572 - '길 떠나는 하얀 겨울 나비' 리뷰 수집 완료! (5개)
# 📖 810/5572 - '트로피컬 나이트' 리뷰 수집 완료! (5개)
# 📖 811/5572 - '가시의 집' 리뷰 수집 완료! (5개)
# 📖 812/5572 - '그리고 아무도 없었다' 리뷰 수집 완료! (5개)
# 📖 813/5572 - '허실시 기담괴설 사건집' 리뷰 수집 완료! (5개)
# 📖 814/5572 - '옛날 철공소' 리뷰 수집 완료! (5개)
# 📖 815/5572 - '허실시 일상신비 사건집' 리뷰 수집 완료! (5개)
# 📖 816/5572 - '이달의 장르소설 10' 리뷰 수집 완료! (5개)
# 📖 817/5572 - '살인자의 숫자' 리뷰 수집 완료! (5개)
# 📖 818/5572 - '나쁜 것이 오지 않기를' 리뷰 수집 완료! (5개)
# 📖 819/5572 - '누아르 레버넌트 2' 리뷰 수집 완료! (5개)
# 📖 820/5572 - '파괴자들의 밤' 리뷰 수집 완료! (5개)
# 📖 821/5572 - '누아르 레버넌트 세트' 리뷰 수집 완료! (5개)
# 📖 822/5572 - '누아르 레버넌트 1' 리뷰 수집 완료! (5개)
# 📖 823/5572 - '향단이는 누가 죽였나' 리뷰 수집 완료! (5개)
# 📖 824/5572 - '나쁜 여름' 리뷰 수집 완료! (5개)
# 📖 825/5572 - '몽상가의 침묵' 리뷰 수집 완료! (5개)
# 📖 826/5572 - '슈' 리뷰 수집 완료! (5개)
# 📖 827/5572 - '킴 스톤 1: 소리 없는 비명' 리뷰 수집 완료! (5개)
# 📖 828/5572 - '킴 스톤 2: 악마의 게임' 리뷰 수집 완료! (5개)
# 📖 829/5572 - '조커' 리뷰 수집 완료! (5개)
# 📖 830/5572 - '킴 스톤 3: 사라진 소녀들' 리뷰 수집 완료! (5개)
# 📖 831/5572 - '그녀가 마지막에 본 것은' 리뷰 수집 완료! (5개)
# 📖 832/5572 - '수인번호 1004' 리뷰 수집 완료! (5개)
# 📖 833/5572 - '뒤틀린 시간의 법정' 리뷰 수집 완료! (5개)
# 📖 834/5572 - '저주 받은 피' 리뷰 수집 완료! (5개)
# 📖 835/5572 - '시크릿 플레이스' 리뷰 수집 완료! (5개)
# 📖 836/5572 - '삼국평화고등학교 테러 사건' 리뷰 수집 완료! (5개)
# 📖 837/5572 - '이달의 장르소설 9' 리뷰 수집 완료! (5개)
# 📖 838/5572 - 'R:UBY' 리뷰 수집 완료! (5개)
# 📖 839/5572 - '하객 명단' 리뷰 수집 완료! (5개)
# 📖 840/5572 - '푸른 수염의 방' 리뷰 수집 완료! (5개)
# 📖 841/5572 - '사설탐정사의 밤' 리뷰 수집 완료! (5개)
# 📖 842/5572 - '신의 숨겨진 얼굴' 리뷰 수집 완료! (5개)
# 📖 843/5572 - '우리 집으로 와, 악마의 이론을 들려 줄게...' 리뷰 수집 완료! (5개)
# 📖 844/5572 - '혐오스런 선데이 클럽' 리뷰 수집 완료! (5개)
# 📖 845/5572 - '폭탄' 리뷰 수집 완료! (5개)
# 📖 846/5572 - '데드맨' 리뷰 수집 완료! (5개)
# 📖 847/5572 - '3인의 명탐정' 리뷰 수집 완료! (5개)
# 📖 848/5572 - '이리하여 아무도 없었다' 리뷰 수집 완료! (5개)
# 📖 849/5572 - '잭 런던 환상문학 단편선' 리뷰 수집 완료! (5개)
# 📖 850/5572 - '폭탄' 리뷰 수집 완료! (5개)
# 📖 851/5572 - '코드612 누가 어린왕자를 죽였는가' 리뷰 수집 완료! (5개)
# 📖 852/5572 - '다감 선생님은 아이들이 싫다' 리뷰 수집 완료! (5개)
# 📖 853/5572 - '따르는 사람들' 리뷰 수집 완료! (5개)
# 📖 854/5572 - '샘 호손 박사의 세 번째 불가능 사건집' 리뷰 수집 완료! (5개)
# 📖 855/5572 - '여고생 핍의 사건 파일' 리뷰 수집 완료! (5개)
# 📖 856/5572 - '표정없는 검사의 분투' 리뷰 수집 완료! (5개)
# 📖 857/5572 - '방주' 리뷰 수집 완료! (5개)
# 📖 858/5572 - '십자도 살인사건' 리뷰 수집 완료! (5개)
# 📖 859/5572 - '푸른 수염의 방' 리뷰 수집 완료! (5개)
# 📖 860/5572 - '대리인 2' 리뷰 수집 완료! (5개)
# 📖 861/5572 - '대리인 1' 리뷰 수집 완료! (5개)
# 📖 862/5572 - '죽음이 갈라놓을 때까지' 리뷰 수집 완료! (5개)
# 📖 863/5572 - '하얀 마물의 탑' 리뷰 수집 완료! (5개)
# 📖 864/5572 - '심심포차 심심 사건' 리뷰 수집 완료! (5개)
# 📖 865/5572 - '새벽 2시의 코인 세탁소' 리뷰 수집 완료! (5개)
# 📖 866/5572 - '광기를 비추는 등대 라이트하우스 1' 리뷰 수집 완료! (5개)
# 📖 867/5572 - '#진상을 말씀드립니다' 리뷰 수집 완료! (5개)
# 📖 868/5572 - '그날로 다시 돌아가 널 살리고 싶어' 리뷰 수집 완료! (5개)
# 📖 869/5572 - '요란한 아침의 나라' 리뷰 수집 완료! (5개)
# 📖 870/5572 - '다마논드호' 리뷰 수집 완료! (5개)
# 📖 871/5572 - '퍼핏 쇼' 리뷰 수집 완료! (5개)
# 📖 872/5572 - '경찰 살해자' 리뷰 수집 완료! (5개)
# 📖 873/5572 - '13.67' 리뷰 수집 완료! (5개)
# 📖 874/5572 - '모파상 환상문학 단편선' 리뷰 수집 완료! (5개)
# 📖 875/5572 - '한국추리소설 걸작선 1' 리뷰 수집 완료! (5개)
# 📖 876/5572 - '더블' 리뷰 수집 완료! (5개)
# 📖 877/5572 - '오전 0시의 몸값' 리뷰 수집 완료! (5개)
# 📖 878/5572 - '출생지, 개미지옥' 리뷰 수집 완료! (5개)
# 📖 879/5572 - '곧 죽어도 힙합' 리뷰 수집 완료! (5개)
# 📖 880/5572 - '밤의 소리를 듣다' 리뷰 수집 완료! (5개)
# 📖 881/5572 - '15세 테러리스트' 리뷰 수집 완료! (5개)
# 📖 882/5572 - '업자에게 잊혀진 시체 보관 기록' 리뷰 수집 완료! (5개)
# 📖 883/5572 - '코난 도일 호러 걸작선' 리뷰 수집 완료! (5개)
# 📖 884/5572 - '조직범죄 대책과 시라타카 아마네' 리뷰 수집 완료! (5개)
# 📖 885/5572 - '우린 그림자가 보이지 않는다' 리뷰 수집 완료! (5개)
# 📖 886/5572 - '시그니처' 리뷰 수집 완료! (5개)
# 📖 887/5572 - '곰과 결혼한 여자' 리뷰 수집 완료! (5개)
# 📖 888/5572 - '붉은 커튼' 리뷰 수집 완료! (5개)
# 📖 889/5572 - '이달의 장르소설 8' 리뷰 수집 완료! (5개)
# 📖 890/5572 - '도쿄 한복판의 유력 용의자' 리뷰 수집 완료! (5개)
# 📖 891/5572 - '살인자 없는 살인' 리뷰 수집 완료! (5개)
# 📖 892/5572 - '프리먼 환상문학 단편선 : 남서향 방, 장미 덤불에 부는 바람, 벽 그림자, 길 잃은 유령, 빈터, 복도 맨 끝 방' 리뷰 수집 완료! (5개)
# 📖 893/5572 - '한국추리문학상 황금펜상 수상작품집: 2022 제16회' 리뷰 수집 완료! (5개)
# 📖 894/5572 - '배니시드' 리뷰 수집 완료! (5개)
# 📖 895/5572 - '곶자왈에서' 리뷰 수집 완료! (5개)
# 📖 896/5572 - '노비스 탐정 길은목' 리뷰 수집 완료! (5개)
# 📖 897/5572 - '묵찌빠' 리뷰 수집 완료! (5개)
# 📖 898/5572 - '선생님이 알아서는 안 되는 학교 폭력 일기' 리뷰 수집 완료! (5개)
# 📖 899/5572 - '내 것이 아닌 잘못' 리뷰 수집 완료! (5개)
# 📖 900/5572 - '테스카틀리포카' 리뷰 수집 완료! (5개)
# 📖 901/5572 - '노스텔지어' 리뷰 수집 완료! (5개)
# 📖 902/5572 - '브로큰 하버' 리뷰 수집 완료! (5개)
# 📖 903/5572 - '24시간 : 삶과 죽음' 리뷰 수집 완료! (5개)
# 📖 904/5572 - '토요미스테리' 리뷰 수집 완료! (5개)
# 📖 905/5572 - '카피캣 식당' 리뷰 수집 완료! (5개)
# 📖 906/5572 - '안락탐정' 리뷰 수집 완료! (5개)
# 📖 907/5572 - '열린 어둠' 리뷰 수집 완료! (5개)
# 📖 908/5572 - '잔혹범죄전담팀 라플레시아 걸' 리뷰 수집 완료! (5개)
# 📖 909/5572 - '르네 마그리트의 연인 2' 리뷰 수집 완료! (5개)
# 📖 910/5572 - '르네 마그리트의 연인 1' 리뷰 수집 완료! (5개)
# 📖 911/5572 - '네메시스' 리뷰 수집 완료! (5개)
# 📖 912/5572 - '살변의 창' 리뷰 수집 완료! (5개)
# 📖 913/5572 - '이달의 장르소설 7' 리뷰 수집 완료! (5개)
# 📖 914/5572 - '특별배송 하시겠습니까' 리뷰 수집 완료! (5개)
# 📖 915/5572 - '호풍환우' 리뷰 수집 완료! (5개)
# 📖 916/5572 - '라이언 블루  장편소설)' 리뷰 수집 완료! (5개)
# 📖 917/5572 - '아멜리아와 네 개의 보석' 리뷰 수집 완료! (5개)
# 📖 918/5572 - '한국추리문학상 황금펜상 수상작품집: 2022 제16회' 리뷰 수집 완료! (5개)
# 📖 919/5572 - '그렇게 할 수밖에' 리뷰 수집 완료! (5개)
# 📖 920/5572 - '뉴서울파크 젤리장수 대학살' 리뷰 수집 완료! (5개)
# 📖 921/5572 - '이달의 장르소설 6' 리뷰 수집 완료! (5개)
# 📖 922/5572 - '사건의 기록' 리뷰 수집 완료! (5개)
# 📖 923/5572 - '천국에서 온 탐정' 리뷰 수집 완료! (5개)
# 📖 924/5572 - '머더 하우스' 리뷰 수집 완료! (5개)
# 📖 925/5572 - '우중괴담' 리뷰 수집 완료! (5개)
# 📖 926/5572 - '시간은 흐르지 않는다' 리뷰 수집 완료! (5개)
# 📖 927/5572 - '시체를 보는 사나이 3부: 다크킹덤 1' 리뷰 수집 완료! (5개)
# 📖 928/5572 - '시체를 보는 사나이 3부: 다크킹덤 2' 리뷰 수집 완료! (5개)
# 📖 929/5572 - '벨벳 속의 발톱' 리뷰 수집 완료! (5개)
# 📖 930/5572 - '마그리트의 껍질' 리뷰 수집 완료! (5개)
# 📖 931/5572 - '정말일까?' 리뷰 수집 완료! (5개)
# 📖 932/5572 - '철교 살인 사건' 리뷰 수집 완료! (5개)
# 📖 933/5572 - '밀랍 인형' 리뷰 수집 완료! (5개)
# 📖 934/5572 - '조심해, 독이야!' 리뷰 수집 완료! (5개)
# 📖 935/5572 - '옛날 옛적 어느 마을에 역시 시체가 있었습니다' 리뷰 수집 완료! (5개)
# 📖 936/5572 - '닥터 데스의 유산' 리뷰 수집 완료! (5개)
# 📖 937/5572 - '스타더스트 패밀리' 리뷰 수집 완료! (5개)
# 📖 938/5572 - '대인기피증이지만 탐정입니다' 리뷰 수집 완료! (5개)
# 📖 939/5572 - '우리는 여기에 없었다' 리뷰 수집 완료! (5개)
# 📖 940/5572 - '범인' 리뷰 수집 완료! (5개)
# 📖 941/5572 - '서점 탐정 유동인 2' 리뷰 수집 완료! (5개)
# 📖 942/5572 - '아르키메데스는 손을 더럽히지 않는다' 리뷰 수집 완료! (5개)
# 📖 943/5572 - '악마의 계약서는 만기 되지 않는다' 리뷰 수집 완료! (5개)
# 📖 944/5572 - '오늘이 아닌 뉴스 1: 침묵하는 목격자' 리뷰 수집 완료! (5개)
# 📖 945/5572 - '오늘이 아닌 뉴스 2' 리뷰 수집 완료! (5개)
# 📖 946/5572 - '이달의 장르소설 5' 리뷰 수집 완료! (5개)
# 📖 947/5572 - '샤론 저택의 비밀' 리뷰 수집 완료! (5개)
# 📖 948/5572 - '흑뢰성' 리뷰 수집 완료! (5개)
# 📖 949/5572 - '백작 부인의 납치' 리뷰 수집 완료! (5개)
# 📖 950/5572 - '종이학 살인사건' 리뷰 수집 완료! (5개)
# 📖 951/5572 - '고스트 라이터' 리뷰 수집 완료! (5개)
# 📖 952/5572 - '그림자밟기 여관의 괴담' 리뷰 수집 완료! (5개)
# 📖 953/5572 - 'S.T.E.P스텝' 리뷰 수집 완료! (5개)
# 📖 954/5572 - '인사이트 밀' 리뷰 수집 완료! (5개)
# 📖 955/5572 - '탐정 홍련' 리뷰 수집 완료! (5개)
# 📖 956/5572 - '인면창 탐정' 리뷰 수집 완료! (5개)
# 📖 957/5572 - '박제사의 사랑' 리뷰 수집 완료! (5개)
# 📖 958/5572 - '누가 세바스찬을 쏘았는가' 리뷰 수집 완료! (4개)
# 📖 959/5572 - '사라진 여자들' 리뷰 수집 완료! (5개)
# 📖 960/5572 - '이달의 장르소설 4' 리뷰 수집 완료! (5개)
# 📖 961/5572 - '무엇 때문에' 리뷰 수집 완료! (5개)
# 📖 962/5572 - 'Pro Kio?' 리뷰 수집 완료! (5개)
# 📖 963/5572 - '&#x8C0B; &#x6740;' 리뷰 수집 완료! (5개)
# 📖 964/5572 - '우리에게는 비밀이 없다' 리뷰 수집 완료! (5개)
# 📖 965/5572 - '나는 실수로 투명인간을 죽였다' 리뷰 수집 완료! (5개)
# 📖 966/5572 - '좀비 3.0' 리뷰 수집 완료! (5개)
# 📖 967/5572 - '시그니처' 리뷰 수집 완료! (5개)
# 📖 968/5572 - 'DAVID' 리뷰 수집 완료! (5개)
# 📖 969/5572 - '규방 부인 정탐기' 리뷰 수집 완료! (5개)
# 📖 970/5572 - '미스터리의 미남들' 리뷰 수집 완료! (5개)
# 📖 971/5572 - '잠 못 드는 밤의 궁궐 기담' 리뷰 수집 완료! (5개)
# 📖 972/5572 - '밀실살인게임 왕수비차잡기' 리뷰 수집 완료! (5개)
# 📖 973/5572 - '말괄량이 사이코패스' 리뷰 수집 완료! (5개)
# 📖 974/5572 - '15초 후에 죽는다' 리뷰 수집 완료! (5개)
# 📖 975/5572 - '적월 - 두번째 공포 단편' 리뷰 수집 완료! (5개)
# 📖 976/5572 - '철수 삼촌' 리뷰 수집 완료! (5개)
# 📖 977/5572 - '이달의 장르소설 3' 리뷰 수집 완료! (5개)
# 📖 978/5572 - '윈저 노트, 여왕의 비밀 수사 일지' 리뷰 수집 완료! (5개)
# 📖 979/5572 - '명탐정 6' 리뷰 수집 완료! (5개)
# 📖 980/5572 - '밀실살인게임 2.0' 리뷰 수집 완료! (5개)
# 📖 981/5572 - '흑백합' 리뷰 수집 완료! (5개)
# 📖 982/5572 - '고가 사부로 단편 추리소설' 리뷰 수집 완료! (5개)
# 📖 983/5572 - '나의 미스터리한 일상' 리뷰 수집 완료! (5개)
# 📖 984/5572 - 'ㅅ ㅅㅅㅈ:  이유있는 살인' 리뷰 수집 완료! (5개)
# 📖 985/5572 - '밀실살인게임 마니악스' 리뷰 수집 완료! (5개)
# 📖 986/5572 - '사라진 사람들' 리뷰 수집 완료! (5개)
# 📖 987/5572 - '나의 차가운 일상' 리뷰 수집 완료! (5개)
# 📖 988/5572 - '유리탑의 살인' 리뷰 수집 완료! (5개)
# 📖 989/5572 - '소녀무녀 봄: 청동방울편' 리뷰 수집 완료! (5개)
# 📖 990/5572 - '킬링 클럽' 리뷰 수집 완료! (5개)
# 📖 991/5572 - '구하는 조사관' 리뷰 수집 완료! (5개)
# 📖 992/5572 - '내가 당신이었을 때' 리뷰 수집 완료! (5개)
# 📖 993/5572 - '소녀무녀 봄: 청동방울편' 리뷰 수집 완료! (5개)
# 📖 994/5572 - '나는 그 정도로 나쁜 사람은 아니다' 리뷰 수집 완료! (5개)
# 📖 995/5572 - '팬데믹 바이러스의 유통과정' 리뷰 수집 완료! (5개)
# 📖 996/5572 - '살인 오마카세' 리뷰 수집 완료! (5개)
# 📖 997/5572 - '죽음을 걷는 여자' 리뷰 수집 완료! (5개)
# 📖 998/5572 - '오늘도 뇌 마음대로 하는 중' 리뷰 수집 완료! (5개)
# 📖 999/5572 - '미스터리라 하지 말지어다 14' 리뷰 수집 완료! (5개)
# 📖 1000/5572 - '청나라 흥망사의 수수께끼' 리뷰 수집 완료! (5개)
# 📖 1001/5572 - '확보하고 격리하고 보호하라 SCP재단 1' 리뷰 수집 완료! (5개)
# 📖 1002/5572 - '무한의 계단 추리 게임왕 3' 리뷰 수집 완료! (5개)
# 📖 1003/5572 - '계간 미스터리 2024 겨울 84호' 리뷰 수집 완료! (5개)
# 📖 1004/5572 - '타키포오 허징의 수상한 만물상점 2' 리뷰 수집 완료! (5개)
# 📖 1005/5572 - '1분만 미스터리 방탈출 1: 비밀의 병원' 리뷰 수집 완료! (5개)
# 📖 1006/5572 - '명탐정 스탠리와 미술관 미스터리' 리뷰 수집 완료! (5개)
# 📖 1007/5572 - '미카엘라 4: 긴급! 친구 실종 미스터리' 리뷰 수집 완료! (5개)
# 📖 1008/5572 - '오싹오싹 과학 미스터리 2' 리뷰 수집 완료! (5개)
# 📖 1009/5572 - '미스터리 과학 조사단 7: 달의 운동과 모양 변화' 리뷰 수집 완료! (5개)
# 📖 1010/5572 - '더 기묘한 미술관' 리뷰 수집 완료! (5개)
# 📖 1011/5572 - '확보하고 격리하고 보호하라 SCP 재단 9' 리뷰 수집 완료! (5개)
# 📖 1012/5572 - '수상한 보물 탐험대 1: 템플 기사단과 이웃집의 미스터리' 리뷰 수집 완료! (5개)
# 📖 1013/5572 - '미스터리 유튜브 4: 괴담 학교 TV의 비밀' 리뷰 수집 완료! (5개)
# 📖 1014/5572 - '미스터리는 월요일에 풀린다 4' 리뷰 수집 완료! (5개)
# 📖 1015/5572 - '계간 미스터리 2024 가을호' 리뷰 수집 완료! (5개)
# 📖 1016/5572 - '이것은 유해한 장르다' 리뷰 수집 완료! (5개)
# 📖 1017/5572 - '더 기묘한 미술관' 리뷰 수집 완료! (5개)
# 📖 1018/5572 - '어쩌면 당신이 원했던 미스터리 문명 1: 풀지 못한 문명' 리뷰 수집 완료! (5개)
# 📖 1019/5572 - '어쩌면 당신이 원했던 미스터리 문명 2: 잃어버린 문명' 리뷰 수집 완료! (5개)
# 📖 1020/5572 - '세계사 명장면 97 지식도감' 리뷰 수집 완료! (5개)
# 📖 1021/5572 - '방과 후 미스터리 클럽 3: 움직이는 동상' 리뷰 수집 완료! (5개)
# 📖 1022/5572 - '비밀요원 레너드 정가 인하 세트A' 리뷰 수집 완료! (5개)
# 📖 1023/5572 - '이것은 유해한 장르다' 리뷰 수집 완료! (5개)
# 📖 1024/5572 - '천재탐정코냥 사건번호 002: 세계 8대 미스터리를 밝혀라!' 리뷰 수집 완료! (5개)
# 📖 1025/5572 - '무한의 계단 추리 게임왕 2' 리뷰 수집 완료! (5개)
# 📖 1026/5572 - '비밀요원 레너드 20: 미스터리 서클의 비밀을 밝혀라!' 리뷰 수집 완료! (5개)
# 📖 1027/5572 - '미스터리 철학 클럽' 리뷰 수집 완료! (5개)
# 📖 1028/5572 - '허징의 수상한 만물상점 1' 리뷰 수집 완료! (5개)
# 📖 1029/5572 - '방과 후 미스터리 클럽 2: 미스터리 서클' 리뷰 수집 완료! (5개)
# 📖 1030/5572 - '미스터리 추리동화_찰리 9세 11-20번 시리즈' 리뷰 수집 완료! (5개)
# 📖 1031/5572 - '오싹오싹 과학 미스터리 1' 리뷰 수집 완료! (5개)
# 📖 1032/5572 - '방과후 미스터리 클럽 1' 리뷰 수집 완료! (5개)
# 📖 1033/5572 - '외행성계 미스터리' 리뷰 수집 완료! (5개)
# 📖 1034/5572 - '돌림판 작가 허아른의 소설 분투기: 주제는 랜덤 결과는 미스터리' 리뷰 수집 완료! (5개)
# 📖 1035/5572 - '계간 미스터리 2024 여름 82호' 리뷰 수집 완료! (5개)
# 📖 1036/5572 - '하루 한 권, 생활 속 열 과학' 리뷰 수집 완료! (5개)
# 📖 1037/5572 - '미스터리 과학 조사단 6: 몸의 구조와 기능' 리뷰 수집 완료! (5개)
# 📖 1038/5572 - '두뇌가 쑥쑥! 재미가 팡팡! 미로찾기 : 미스터리' 리뷰 수집 완료! (5개)
# 📖 1039/5572 - '무한의 계단 추리 게임왕 1' 리뷰 수집 완료! (5개)
# 📖 1040/5572 - '이웃집 프로파일러 하이다의 사건 파일 7: 보이지 않는 감옥' 리뷰 수집 완료! (5개)
# 📖 1041/5572 - '비밀요원 레너드 19 : 설문대할망을 구하라!' 리뷰 수집 완료! (5개)
# 📖 1042/5572 - '미스터리는 월요일에 풀린다 3' 리뷰 수집 완료! (5개)
# 📖 1043/5572 - '맹성렬 박사의 지켜라! 지구인 2' 리뷰 수집 완료! (5개)
# 📖 1044/5572 - '미스터리 차일드 클럽 4: 우주' 리뷰 수집 완료! (2개)
# 📖 1045/5572 - '계간 미스터리' 리뷰 수집 완료! (5개)
# 📖 1046/5572 - '두근두근 미스터리의 밤' 리뷰 수집 완료! (5개)
# 📖 1047/5572 - '삐까 뿌까의 미스터리 음악여행' 리뷰 수집 완료! (1개)
# 📖 1048/5572 - '미스터리는 월요일에 풀린다 2' 리뷰 수집 완료! (5개)
# 📖 1049/5572 - '이웃집 프로파일러 하이다의 사건 파일 6: 루미미 골든 타임' 리뷰 수집 완료! (5개)
# 📖 1050/5572 - '토깽이네 지구 구출 대작전 8: 꿀벌 실종 미스터리를 풀어라!' 리뷰 수집 완료! (5개)
# 📖 1051/5572 - '팩토피아 7: 미스터리 상식' 리뷰 수집 완료! (5개)
# 📖 1052/5572 - '비밀요원 레너드 18: 좀비가 나타났다!' 리뷰 수집 완료! (5개)
# 📖 1053/5572 - '미스터리 과학 조사단 5: 강과 환경 오염' 리뷰 수집 완료! (5개)
# 📖 1054/5572 - '미스터리 수사대 사건파일 1권' 리뷰 수집 완료! (5개)
# 📖 1055/5572 - '더 미스터리 2: 사상 최악의 사건' 리뷰 수집 완료! (5개)
# 📖 1056/5572 - '더 미스터리 1: 미지의 공포' 리뷰 수집 완료! (5개)
# 📖 1057/5572 - '미스터리라 하지 말지어다 13' 리뷰 수집 완료! (5개)
# 📖 1058/5572 - '비밀의 신 한피라리 5: 보름달 밤의 미스터리' 리뷰 수집 완료! (5개)
# 📖 1059/5572 - '계간 미스터리' 리뷰 수집 완료! (5개)
# 📖 1060/5572 - '세계사 탐정 코난 11 : 마리 앙투아네트 미스터리' 리뷰 수집 완료! (5개)
# 📖 1061/5572 - '세계사 탐정 코난 9: 마야 문명 미스터리' 리뷰 수집 완료! (5개)
# ⚠️ '세계사 탐정 코난 10 : 아라비안나이트 미스터리' 검색 결과 없음 (응답에 'items' 없음)
# 📖 1062/5572 - '세계사 탐정 코난 10 : 아라비안나이트 미스터리' 리뷰 수집 완료! (0개)
# 📖 1063/5572 - '세계사 탐정 코난 8: 폼페이 미스터리' 리뷰 수집 완료! (5개)
# 📖 1064/5572 - '세계사 탐정 코난 12 : 달 착륙 미스터리' 리뷰 수집 완료! (5개)
# 📖 1065/5572 - '세계사 탐정 코난 7: 클레오파트라 미스터리' 리뷰 수집 완료! (5개)
# 📖 1066/5572 - '명탐정 브라운 신부의 미스터리 사건12' 리뷰 수집 완료! (5개)
# 📖 1067/5572 - '살의의 형태' 리뷰 수집 완료! (5개)
# 📖 1068/5572 - '가짜 환자, 로젠한 실험 미스터리' 리뷰 수집 완료! (5개)
# 📖 1069/5572 - '도꺄비 탐정 탱구 2: 세쌍둥이 미스터리' 리뷰 수집 완료! (5개)
# 📖 1070/5572 - '미스터리는 월요일에 풀린다 1' 리뷰 수집 완료! (5개)
# 📖 1071/5572 - '이웃집 프로파일러 하이다의 사건 파일 5: 몬스터 카드의 함정' 리뷰 수집 완료! (5개)
# 📖 1072/5572 - '한번도 경험해보지 못한 법카' 리뷰 수집 완료! (5개)
# 📖 1073/5572 - '미스터리 수학 탐정단 8: 왕실의 보물을 지켜라!' 리뷰 수집 완료! (5개)
# 📖 1074/5572 - '맹성렬 박사의 지켜라! 지구인 1' 리뷰 수집 완료! (5개)
# 📖 1075/5572 - '미스터리 유튜브 3: 실화 공포 웹툰의 비밀' 리뷰 수집 완료! (5개)
# 📖 1076/5572 - '미스터리 스토리텔링 사전' 리뷰 수집 완료! (5개)
# 📖 1077/5572 - '미스터리 과학 조사단 4: 그림자와 소리' 리뷰 수집 완료! (5개)
# 📖 1078/5572 - '계간 미스터리' 리뷰 수집 완료! (5개)
# 📖 1079/5572 - '노르웨이 라면왕 미스터 리 이야기: BE HAPPY' 리뷰 수집 완료! (5개)
# 📖 1080/5572 - '대한민국 미스터리 사건 수첩' 리뷰 수집 완료! (5개)
# 📖 1081/5572 - '린든 샌즈 미스터리' 리뷰 수집 완료! (5개)
# 📖 1082/5572 - '그림자 덫' 리뷰 수집 완료! (5개)
# 📖 1083/5572 - '하루 한 권, 생활 속 열 과학' 리뷰 수집 완료! (5개)
# 📖 1084/5572 - '미스터리라 하지 말지어다 12' 리뷰 수집 완료! (5개)
# 📖 1085/5572 - '이웃 사람 1' 리뷰 수집 완료! (5개)
# 📖 1086/5572 - '이웃 사람 2' 리뷰 수집 완료! (5개)
# 📖 1087/5572 - '이웃 사람 1~3 세트' 리뷰 수집 완료! (5개)
# 📖 1088/5572 - '이웃 사람 3' 리뷰 수집 완료! (5개)
# 📖 1089/5572 - '세계사 탐정 코난 5' 리뷰 수집 완료! (5개)
# 📖 1090/5572 - '미스터리 어드벤처' 리뷰 수집 완료! (5개)
# 📖 1091/5572 - '미스터리 어드벤처' 리뷰 수집 완료! (5개)
# 📖 1092/5572 - '세계사 탐정 코난 4' 리뷰 수집 완료! (5개)
# 📖 1093/5572 - '세계사 탐정 코난 1' 리뷰 수집 완료! (5개)
# 📖 1094/5572 - '세계사 탐정 코난 6' 리뷰 수집 완료! (5개)
# 📖 1095/5572 - '세계사 탐정 코난 2' 리뷰 수집 완료! (5개)
# 📖 1096/5572 - '세계사 탐정 코난 3' 리뷰 수집 완료! (5개)
# 📖 1097/5572 - '도꺄비 탐정 탱구 1: 미스터리한 과학 탐정의 등장' 리뷰 수집 완료! (5개)
# 📖 1098/5572 - '겨울밤 미스터리' 리뷰 수집 완료! (5개)
# 📖 1099/5572 - '계간 미스터리' 리뷰 수집 완료! (5개)
# 📖 1100/5572 - 'SCP 재단: 확보하고 격리하고 보호하라 7' 리뷰 수집 완료! (5개)
# 📖 1101/5572 - '이웃집 프로파일러 하이다의 사건 파일 3: 고요동 사건의 시그널' 리뷰 수집 완료! (5개)
# 📖 1102/5572 - '엉뚱소심 유령 탐정단 5: 비밀의 방 미스터리' 리뷰 수집 완료! (5개)
# 📖 1103/5572 - '미스터리 어드벤처' 리뷰 수집 완료! (5개)
# 📖 1104/5572 - '미스터리 어드벤처' 리뷰 수집 완료! (5개)
# 📖 1105/5572 - '미스터리 수학 탐정단 7: 뒤엉킨 위기의 매듭을 풀어라!' 리뷰 수집 완료! (5개)
# 📖 1106/5572 - '잔혹하고 기묘한 이야기 : 미스터리 호러 단편선' 리뷰 수집 완료! (5개)
# 📖 1107/5572 - '미스터리 과학 조사단 3: 바다와 갯벌 생태계' 리뷰 수집 완료! (5개)
# 📖 1108/5572 - '미스터리라 하지 말지어다 11' 리뷰 수집 완료! (5개)
# 📖 1109/5572 - '조금 수상한 비타민C의 역사' 리뷰 수집 완료! (5개)
# 📖 1110/5572 - '비밀요원 레너드 15 15' 리뷰 수집 완료! (5개)
# 📖 1111/5572 - '미스터리 차일드 클럽 3: 식물' 리뷰 수집 완료! (5개)
# 📖 1112/5572 - '행복배틀' 리뷰 수집 완료! (5개)
# 📖 1113/5572 - '미스터리 수학 탐정단 6: 백만장자의 유언 속 암호를 풀어라!' 리뷰 수집 완료! (5개)
# 📖 1114/5572 - '계간 미스터리' 리뷰 수집 완료! (5개)
# 📖 1115/5572 - '이웃집 프로파일러 하이다의 사건 파일 2: 추적! 해커의 시그니처' 리뷰 수집 완료! (5개)
# 📖 1116/5572 - '교도소 괴담' 리뷰 수집 완료! (5개)
# 📖 1117/5572 - '100대 미스터리 시리즈 전3권 세트' 리뷰 수집 완료! (5개)
# 📖 1118/5572 - '미스터리라 하지 말지어다 10' 리뷰 수집 완료! (5개)
# 📖 1119/5572 - '밥스 패밀리 4' 리뷰 수집 완료! (5개)
# 📖 1120/5572 - '영생의 피' 리뷰 수집 완료! (5개)
# 📖 1121/5572 - '미스터리 과학 도감 1~8 세트 - 전8권' 리뷰 수집 완료! (5개)
# 📖 1122/5572 - '문방구TV SCP 재단 코믹툰' 리뷰 수집 완료! (5개)
# 📖 1123/5572 - '지구의 미스터리' 리뷰 수집 완료! (5개)
# 📖 1124/5572 - 'Why? 한국사 미스터리' 리뷰 수집 완료! (5개)
# 📖 1125/5572 - '비밀요원 레너드 1: 옷장 속 괴물 부기맨이 나타났다!' 리뷰 수집 완료! (5개)
# 📖 1126/5572 - '백앤아 1 1' 리뷰 수집 완료! (5개)
# 📖 1127/5572 - '비밀요원 레너드 14: 달에 사는 토끼가 사라졌다!' 리뷰 수집 완료! (5개)
# 📖 1128/5572 - '미스터리 수학 탐정단 5' 리뷰 수집 완료! (5개)
# 📖 1129/5572 - '아일랜드 2부 박스판' 리뷰 수집 완료! (5개)
# 📖 1130/5572 - '지금, 만화' 리뷰 수집 완료! (5개)
# 📖 1131/5572 - '이웃집 프로파일러 하이다의 사건 파일 1: 낙인찍힌 아이' 리뷰 수집 완료! (5개)
# 📖 1132/5572 - '비밀요원 레너드 4: 파라오의 저주는 사실일까?' 리뷰 수집 완료! (5개)
# 📖 1133/5572 - '암호 클럽 18: 미스터리 투어가 우릴 부른다!' 리뷰 수집 완료! (5개)
# 📖 1134/5572 - '미스터리 차일드 클럽 2: 우리 몸' 리뷰 수집 완료! (5개)
# 📖 1135/5572 - '성경의 미스터리' 리뷰 수집 완료! (5개)
# 📖 1136/5572 - '아일랜드 소장판 1부 1~4 박스판 세트' 리뷰 수집 완료! (5개)
# 📖 1137/5572 - '미스터리 과학 도감 1~7권 세트' 리뷰 수집 완료! (5개)
# 📖 1138/5572 - '계간 미스터리 2022 겨울호' 리뷰 수집 완료! (5개)
# 📖 1139/5572 - '미스터리 과학 조사단 2: 물체를 이루는 물질' 리뷰 수집 완료! (5개)
# 📖 1140/5572 - '호치포치 호텔' 리뷰 수집 완료! (5개)
# 📖 1141/5572 - 'SCP 재단: 확보하고 격리하고 보호하라 6' 리뷰 수집 완료! (5개)
# 📖 1142/5572 - '미스터리라 하지 말지어다 9' 리뷰 수집 완료! (5개)
# 📖 1143/5572 - '미스터리 수학 탐정단 4' 리뷰 수집 완료! (5개)
# 📖 1144/5572 - '비밀요원 레너드 13: 투명인간은 정말 있을까?' 리뷰 수집 완료! (5개)
# 📖 1145/5572 - '닥터 K의 오싹한 의학 미스터리 1' 리뷰 수집 완료! (5개)
# 📖 1146/5572 - '닥터 K의 오싹한 의학 미스터리 2' 리뷰 수집 완료! (5개)
# 📖 1147/5572 - '닥터 K의 오싹한 의학 미스터리 세트' 리뷰 수집 완료! (5개)
# 📖 1148/5572 - '셜록 홈스 이스케이프 룸 퍼즐' 리뷰 수집 완료! (5개)
# 📖 1149/5572 - '아머드 사우루스 1: 미스터리 섬의 비밀' 리뷰 수집 완료! (5개)
# 📖 1150/5572 - '계간 미스터리 2022 가을호' 리뷰 수집 완료! (5개)
# 📖 1151/5572 - '미스터리 클럽' 리뷰 수집 완료! (5개)
# 📖 1152/5572 - '알수록 재미있는 미스터리 과학' 리뷰 수집 완료! (5개)
# 📖 1153/5572 - '오라, 달콤한 장르소설이여' 리뷰 수집 완료! (5개)
# 📖 1154/5572 - '교도소 괴담' 리뷰 수집 완료! (5개)
# ...
# 📖 5272/5572 - '맛 탐정 림보와 사라진 요리책' 리뷰 수집 완료! (5개)
# 📖 5273/5572 - '밥스 패밀리 5' 리뷰 수집 완료! (5개)
# 📖 5274/5572 - '어린이를 위한 모든 순간의 물리학' 리뷰 수집 완료! (5개)
# 📖 5275/5572 - '지식 탐정단 헌터구리스 2: 플라워랜드의 샤랄라 꿀단지 도난 사건' 리뷰 수집 완료! (5개)
# 📖 5276/5572 - '신사숙녀의 자기방어술' 리뷰 수집 완료! (5개)
# 📖 5277/5572 - '미래 과학의 필수 과목, 어린이를 위한 뇌 과학 이야기' 리뷰 수집 완료! (5개)
# 📖 5278/5572 - '발자국 탐정 왈녹 1: 사라진 꿀벌을 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5279/5572 - 'K탐정의 척척척 대한민국 6' 리뷰 수집 완료! (5개)
# 📖 5280/5572 - '초등탐정 강이치 시즌 10 : 유령 손님' 리뷰 수집 완료! (5개)
# ⚠️ '방울이TV 방뎅이 탐정 3: 굼벵이 박사의 첫사랑' 검색 결과 없음 (응답에 'items' 없음)
# 📖 5281/5572 - '방울이TV 방뎅이 탐정 3: 굼벵이 박사의 첫사랑' 리뷰 수집 완료! (0개)
# 📖 5282/5572 - '쌍둥이 탐정 똥똥구리 5: 거울귀신과 쌍둥이 마을' 리뷰 수집 완료! (5개)
# 📖 5283/5572 - '쌍둥이 탐정 똥똥구리 세트' 리뷰 수집 완료! (5개)
# 📖 5284/5572 - '엉뚱소심 유령 탐정단 8: 기묘한 숨바꼭질' 리뷰 수집 완료! (5개)
# 📖 5285/5572 - '오늘부터 프린세스 탐정! 4: 도둑맞은 왕실 명화 사건' 리뷰 수집 완료! (5개)
# 📖 5286/5572 - '오늘부터 프린세스 탐정 3: 송곳니 호수 괴물 사건' 리뷰 수집 완료! (5개)
# 📖 5287/5572 - 'K탐정의 척척척 대한민국 5' 리뷰 수집 완료! (5개)
# 📖 5288/5572 - '언더독 탐정 사무소 5: 바다 괴물을 낚아라!' 리뷰 수집 완료! (5개)
# 📖 5289/5572 - '명탐정 코난 스티커팩 80' 리뷰 수집 완료! (5개)
# 📖 5290/5572 - '기량 탐정 사무소 3: 보름달 축제와 일식의 저주' 리뷰 수집 완료! (5개)
# 📖 5291/5572 - '명탐정 코난처럼 생각하라' 리뷰 수집 완료! (5개)
# 📖 5292/5572 - '코딱지탐정 문해력 놀이 일력 365' 리뷰 수집 완료! (5개)
# 📖 5293/5572 - '名偵探柯南 100+PLUS 超百科 명탐정 코난 100+PLUS 백과사전' 리뷰 수집 완료! (5개)
# 📖 5294/5572 - '명탐정 닭다리 탐정 4: 파리 미술관 도난 사건' 리뷰 수집 완료! (5개)
# 📖 5295/5572 - '지식 탐정단 헌터구리스 1: 글리제 581d 행성의 우주 지식 도난 사건' 리뷰 수집 완료! (5개)
# 📖 5296/5572 - '엉뚱소심 유령 탐정단 7: 나무집의 유령' 리뷰 수집 완료! (5개)
# 📖 5297/5572 - '곤충 탐정 정브르 1~5 세트 - 전5권' 리뷰 수집 완료! (5개)
# 📖 5298/5572 - '2024년 명탐정 코난 벽걸이 달력' 리뷰 수집 완료! (5개)
# 📖 5299/5572 - '고고 탐정단 사라진 절대 반지' 리뷰 수집 완료! (5개)
# 📖 5300/5572 - '숨은그림찾기 1004 : 탐정' 리뷰 수집 완료! (5개)
# 📖 5301/5572 - '개비의 매직하우스 스토리북 6 매직하우스의 탐정들' 리뷰 수집 완료! (5개)
# 📖 5302/5572 - '명화 탐정 진짜 명화를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5303/5572 - '구미호 탐정 사무소: 검은 요괴를 잡아라!' 리뷰 수집 완료! (5개)
# 📖 5304/5572 - '명탐정 준의 AI 파란노트' 리뷰 수집 완료! (5개)
# 📖 5305/5572 - '언더독 탐정 사무소 4: 황금 기타를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5306/5572 - '수상한 국어 탐정단 시리즈' 리뷰 수집 완료! (5개)
# 📖 5307/5572 - '수상한 국어 탐정단 5: 기억의 땅과 타임캡슐' 리뷰 수집 완료! (5개)
# ⚠️ '방울이TV 방뎅이 탐정 2: 물음표 가면의 정체' 검색 결과 없음 (응답에 'items' 없음)
# 📖 5308/5572 - '방울이TV 방뎅이 탐정 2: 물음표 가면의 정체' 리뷰 수집 완료! (0개)
# 📖 5309/5572 - '쌍둥이 탐정 똥똥구리 세트' 리뷰 수집 완료! (5개)
# 📖 5310/5572 - '쌍둥이 탐정 똥똥구리 4: 천도복숭아 도둑' 리뷰 수집 완료! (5개)
# 📖 5311/5572 - '국제탐정 K: 달의 두 얼굴' 리뷰 수집 완료! (5개)
# 📖 5312/5572 - '엉뚱소심 유령 탐정단 6: 소방서의 유령' 리뷰 수집 완료! (5개)
# 📖 5313/5572 - '인성천재로 레벨업 7: 좋은습관' 리뷰 수집 완료! (5개)
# 📖 5314/5572 - '출동! 쓰레기 탐정단: 정크 아트의 비밀을 파헤쳐라' 리뷰 수집 완료! (5개)
# 📖 5315/5572 - '초등탐정 강이치 시즌 9 : 피해자들' 리뷰 수집 완료! (5개)
# 📖 5316/5572 - '홍 탐정님 장래희망 좀 찾아주세요!' 리뷰 수집 완료! (5개)
# 📖 5317/5572 - '소년 탐정 칼레 1~3 세트 - 전3권' 리뷰 수집 완료! (5개)
# 📖 5318/5572 - '늑대는 탐정을 잡아먹고 싶어 2' 리뷰 수집 완료! (5개)
# 📖 5319/5572 - 'K탐정의 척척척 대한민국 4' 리뷰 수집 완료! (5개)
# 📖 5320/5572 - '탐정활동의 이론과 실무' 리뷰 수집 완료! (5개)
# 📖 5321/5572 - '고구마 탐정 과학 3: 파라오의 보물을 지켜라!' 리뷰 수집 완료! (5개)
# 📖 5322/5572 - '과학 탐정 나조노 신지쓰 5: 과학 탐정 vs. 사라진 섬' 리뷰 수집 완료! (5개)
# 📖 5323/5572 - '흡혈귀 탐정 클럽 3: 사건파일  꿈꾸는 괴물들의 밤' 리뷰 수집 완료! (5개)
# 📖 5324/5572 - '수학탐정 매키와 수학도둑 누팡의 대결 1: 수와 연산' 리뷰 수집 완료! (5개)
# 📖 5325/5572 - '수학탐정 매키와 수학도둑 누팡의 대결 5: 경우의 수와 통계' 리뷰 수집 완료! (5개)
# 📖 5326/5572 - '수학탐정 매키와 수학도둑 누팡의 대결 3: 문자와 식' 리뷰 수집 완료! (5개)
# 📖 5327/5572 - '수학탐정 매키와 수학도둑 누팡의 대결 4: 규칙성과 함수' 리뷰 수집 완료! (5개)
# 📖 5328/5572 - '수학탐정 매키와 수학도둑 누팡의 대결 2: 도형' 리뷰 수집 완료! (5개)
# 📖 5329/5572 - '소녀탐정 루아와 악마의 인형' 리뷰 수집 완료! (5개)
# 📖 5330/5572 - '너구리 탐정 사무소 1 : 판다가 훔친 과자를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5331/5572 - '언더독 탐정 사무소 3: 최고 기록을 깨라!' 리뷰 수집 완료! (5개)
# 📖 5332/5572 - '엉뚱소심 유령 탐정단 4: 다섯 시 유령' 리뷰 수집 완료! (5개)
# 📖 5333/5572 - '과학 탐정 나조노 신지쓰 4' 리뷰 수집 완료! (5개)
# 📖 5334/5572 - '도미 탐정, 사라진 지킬 박사를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5335/5572 - '곤충 탐정 정브르 3: 반딧불이의 보물을 지켜라!' 리뷰 수집 완료! (5개)
# 📖 5336/5572 - '쌍둥이 탐정 똥똥구리 1~3권 세트' 리뷰 수집 완료! (5개)
# 📖 5337/5572 - '이건 어떤 감정이에요?' 리뷰 수집 완료! (5개)
# 📖 5338/5572 - '늑대는 탐정을 잡아먹고 싶어 1' 리뷰 수집 완료! (5개)
# 📖 5339/5572 - '쌍둥이 탐정 똥똥구리 3: 외계인의 보물' 리뷰 수집 완료! (5개)
# 📖 5340/5572 - 'K탐정의 척척척 대한민국 3' 리뷰 수집 완료! (5개)
# 📖 5341/5572 - '명탐정 티미 7: 내가 끝이라고 해야 끝이야!' 리뷰 수집 완료! (5개)
# 📖 5342/5572 - '기량 탐정 사무소 2: 민폐리얼 호텔과 대낮 적응 캠프' 리뷰 수집 완료! (5개)
# 📖 5343/5572 - '수상한 국어 탐정단 4: 사라진 왕자와 거미 숲' 리뷰 수집 완료! (5개)
# 📖 5344/5572 - '기후 위기 해결사, 사이다 탐정 3: 산불 방화범 찾기 대작전' 리뷰 수집 완료! (5개)
# 📖 5345/5572 - '초등탐정 강이치 시즌 8 : 찾기 게임' 리뷰 수집 완료! (5개)
# 📖 5346/5572 - '역사 컬렉터, 탐정이 되다' 리뷰 수집 완료! (5개)
# 📖 5347/5572 - '공룡탐정의 구조 대모험' 리뷰 수집 완료! (5개)
# 📖 5348/5572 - '탐정 삼손, 잃어버린 보물을 찾아 줘!' 리뷰 수집 완료! (5개)
# 📖 5349/5572 - '명탐정 티미 6: 보물찾기 소동' 리뷰 수집 완료! (5개)
# 📖 5350/5572 - '열두 살 궁그미를 위한 철학 탐정' 리뷰 수집 완료! (5개)
# 📖 5351/5572 - '역사탐정 만두와 함께하는 이야기 한국사' 리뷰 수집 완료! (5개)
# 📖 5352/5572 - '마법 숲 탐정 6: 사과숲을 지켜라!' 리뷰 수집 완료! (5개)
# 📖 5353/5572 - '엉뚱소심 유령 탐정단 3: 무대 뒤의 유령' 리뷰 수집 완료! (5개)
# 📖 5354/5572 - '수학탐정단과 삼각비의 개념' 리뷰 수집 완료! (5개)
# 📖 5355/5572 - '명탐정 티미 5: 가지고 있으면 안 될 기밀문서' 리뷰 수집 완료! (5개)
# 📖 5356/5572 - '초원의 명탐정 몽구리: 요리 대회의 비밀을 밝혀라' 리뷰 수집 완료! (5개)
# 📖 5357/5572 - '소토무라 탐정사무소의 초대받지 못한 손님' 리뷰 수집 완료! (5개)
# 📖 5358/5572 - '엉덩이 탐정 애니메이션 코믹북 9: 오페라의 괴도' 리뷰 수집 완료! (5개)
# 📖 5359/5572 - '셜록 홈즈 두뇌 퍼즐' 리뷰 수집 완료! (5개)
# 📖 5360/5572 - '탐정 칸 : 부리부리단의 습격' 리뷰 수집 완료! (5개)
# 📖 5361/5572 - '명탐정 셜록 홈즈 11~15 전5권 세트/아동도서+노트 증정' 리뷰 수집 완료! (5개)
# 📖 5362/5572 - '수학탐정단과 이차방정식의 개념 )' 리뷰 수집 완료! (5개)
# 📖 5363/5572 - '명탐정 닭다리 탐정 3: 로마에서 사라진 반지' 리뷰 수집 완료! (5개)
# 📖 5364/5572 - '오늘부터 프린세스 탐정! 2: 금빛 드레스 도난 사건' 리뷰 수집 완료! (5개)
# 📖 5365/5572 - '명탐정, 블랙맨을 잡아라!' 리뷰 수집 완료! (5개)
# 📖 5366/5572 - '곤충 탐정 정브르 1~2 세트 - 전2권' 리뷰 수집 완료! (5개)
# 📖 5367/5572 - '흡혈귀 탐정 클럽 2: 사건 파일 소원을 이뤄 주는 채팅방' 리뷰 수집 완료! (5개)
# 📖 5368/5572 - '쌍둥이 탐정 똥똥구리 2: 색깔 먹는 하마' 리뷰 수집 완료! (5개)
# 📖 5369/5572 - '쌍둥이 탐정 똥똥구리 1~2권 세트' 리뷰 수집 완료! (5개)
# 📖 5370/5572 - '수상한 국어 탐정단 3: 흑망토단의 도전장' 리뷰 수집 완료! (5개)
# 📖 5371/5572 - '고구마 탐정 수학 2: 음악가 동장군의 비밀 금고' 리뷰 수집 완료! (5개)
# 📖 5372/5572 - '천년야화 : 명탐정 스타게이저' 리뷰 수집 완료! (5개)
# 📖 5373/5572 - '명탐정과 되살아난 시체' 리뷰 수집 완료! (5개)
# 📖 5374/5572 - '제주도에 간 전설의 고양이 탐정 4: 사라진 뱀 단지' 리뷰 수집 완료! (5개)
# 📖 5375/5572 - '셜록 홈순 탐정단: 도깨비 광산의 비밀' 리뷰 수집 완료! (5개)
# 📖 5376/5572 - '최신 국가정보학  탐정 기본서 및 수험대비)' 리뷰 수집 완료! (5개)
# 📖 5377/5572 - '세계사 명탐정 유물편, 인물편 세트' 리뷰 수집 완료! (5개)
# 📖 5378/5572 - '세계사 명탐정 연대기 세트' 리뷰 수집 완료! (5개)
# 📖 5379/5572 - '세계사 명탐정 인물편 세트' 리뷰 수집 완료! (4개)
# 📖 5380/5572 - '마법 숲 탐정 5: 명탐정 사총사의 오싹오싹 앞마당 캠핑' 리뷰 수집 완료! (5개)
# 📖 5381/5572 - '밥스 패밀리 3' 리뷰 수집 완료! (5개)
# 📖 5382/5572 - '곤충 탐정 정브르 1: 장수말벌 비비 실종 사건' 리뷰 수집 완료! (5개)
# 📖 5383/5572 - '초등탐정 강이치 시즌7 진짜? 가짜? 진짜!' 리뷰 수집 완료! (5개)
# 📖 5384/5572 - '500원 토끼 퀴즈를 풀어라!: 명탐정편' 리뷰 수집 완료! (5개)
# 📖 5385/5572 - '수학탐정단과 피타고라스 )' 리뷰 수집 완료! (5개)
# 📖 5386/5572 - '쌍둥이 탐정 똥똥구리 1: 야광귀와 사라진 아이들' 리뷰 수집 완료! (5개)
# 📖 5387/5572 - '도전 명탐정 프로젝트 1~3 세트 - 전3권' 리뷰 수집 완료! (5개)
# 📖 5388/5572 - '기량 탐정 사무소 1: 드라큘라의 사라진 송곳니' 리뷰 수집 완료! (5개)
# 📖 5389/5572 - '오늘부터 프린세스 탐정! 1: 사라진 다이아몬드 왕관 사건' 리뷰 수집 완료! (5개)
# 📖 5390/5572 - '기후 위기 해결사, 사이다 탐정 2: 사라진 판다 의사' 리뷰 수집 완료! (5개)
# 📖 5391/5572 - '명탐정 두덕 씨와 탈옥수' 리뷰 수집 완료! (5개)
# 📖 5392/5572 - '두덕탐정단과 보물섬 대탈출' 리뷰 수집 완료! (5개)
# 📖 5393/5572 - '탐정 두덕 씨와 보물 창고' 리뷰 수집 완료! (5개)
# 📖 5394/5572 - '과학 탐정 나조노 신지쓰 3: 과학 탐정 vs. 마계의 도시 전설' 리뷰 수집 완료! (5개)
# 📖 5395/5572 - '멍멍이 탐정과 엄마 잃은 알' 리뷰 수집 완료! (5개)
# 📖 5396/5572 - '멍멍이 탐정과 사라진 케이크' 리뷰 수집 완료! (5개)
# 📖 5397/5572 - '수학탐정단과 방정식의 개념 )' 리뷰 수집 완료! (5개)
# 📖 5398/5572 - '흡혈귀 탐정 클럽 1: 사건 파일 거울 세계 실종 사건' 리뷰 수집 완료! (5개)
# 📖 5399/5572 - '엉덩이 탐정 애니메이션 코믹북 7' 리뷰 수집 완료! (5개)
# 📖 5400/5572 - '공주 탐정 엘리자베트 세트' 리뷰 수집 완료! (5개)
# 📖 5401/5572 - '초등학생을 위한 똑똑한 좋은 뉴스' 리뷰 수집 완료! (5개)
# 📖 5402/5572 - '꼬마 탐정 요누 까만 우유를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5403/5572 - '고구마 탐정 과학 2: 비듬마을에 나타난 코브라' 리뷰 수집 완료! (5개)
# 📖 5404/5572 - '가모가와 식당 5' 리뷰 수집 완료! (5개)
# 📖 5405/5572 - '밥스 패밀리 2' 리뷰 수집 완료! (5개)
# 📖 5406/5572 - '수상한 국어 탐정단 2: 까망 마법사의 저주' 리뷰 수집 완료! (5개)
# 📖 5407/5572 - '명탐정 코우코는 우울해 1' 리뷰 수집 완료! (5개)
# 📖 5408/5572 - '여자에게 어울리는 장르, 추리소설' 리뷰 수집 완료! (5개)
# 📖 5409/5572 - '고양이 탐정 윈스턴: 용감한 비밀 요원' 리뷰 수집 완료! (5개)
# 📖 5410/5572 - '공주 탐정 엘리자베트 3: 마지막 수수께끼를 풀다' 리뷰 수집 완료! (5개)
# 📖 5411/5572 - 'K탐정의 척척척 대한민국 1' 리뷰 수집 완료! (5개)
# 📖 5412/5572 - 'K탐정의 척척척 대한민국 2' 리뷰 수집 완료! (5개)
# 📖 5413/5572 - '수학탐정단과 도형의 개념 )' 리뷰 수집 완료! (5개)
# 📖 5414/5572 - '내가 만드는 움직이는 종이로봇: 탐정 아르' 리뷰 수집 완료! (5개)
# 📖 5415/5572 - '알지오매스 수학코딩 탐정단' 리뷰 수집 완료! (5개)
# 📖 5416/5572 - '공주 탐정 엘리자베트 2: 바이올리니스트의 비밀을 밝히다' 리뷰 수집 완료! (5개)
# 📖 5417/5572 - '초등탐정 강이치: 의뢰인' 리뷰 수집 완료! (5개)
# 📖 5418/5572 - '엉덩이탐정 스티커 컬렉션북' 리뷰 수집 완료! (5개)
# 📖 5419/5572 - '수학탐정단과 메타버스 실종사건 )' 리뷰 수집 완료! (5개)
# 📖 5420/5572 - '비밀수집가; 와플 탐정과 댄싱 파이터' 리뷰 수집 완료! (5개)
# 📖 5421/5572 - '마법 숲 탐정 4: 달빛 극장 귀신 소동' 리뷰 수집 완료! (5개)
# 📖 5422/5572 - '공주 탐정 엘리자베트 1: 뮤직박스의 암호를 찾다' 리뷰 수집 완료! (5개)
# 📖 5423/5572 - '백신 탐정 기어코: 가짜 뉴스에 감염된 세상을 구하라!' 리뷰 수집 완료! (5개)
# 📖 5424/5572 - '빈 깡통 탐정단의 비밀 수첩' 리뷰 수집 완료! (5개)
# 📖 5425/5572 - '밥스 패밀리 1' 리뷰 수집 완료! (5개)
# 📖 5426/5572 - '기후 위기 해결사, 사이다 탐정 1' 리뷰 수집 완료! (5개)
# 📖 5427/5572 - '엉덩이 탐정 애니메이션 코믹북 6' 리뷰 수집 완료! (5개)
# 📖 5428/5572 - '스티커 도둑과 탐정 이기정' 리뷰 수집 완료! (5개)
# 📖 5429/5572 - '과학 탐정 셜록 옴즈 1~2 세트 - 전2권' 리뷰 수집 완료! (5개)
# 📖 5430/5572 - '심장 없는 탐정 메이슨 무니 1: 저주 받은 저택의 비밀' 리뷰 수집 완료! (5개)
# 📖 5431/5572 - '심장 없는 탐정 메이슨 무니 2: 사악한 도플갱어의 습격' 리뷰 수집 완료! (5개)
# 📖 5432/5572 - '책으로 배우고 보드게임으로 완성! 유아 보드게임 세트' 리뷰 수집 완료! (5개)
# 📖 5433/5572 - '꼬마 탐정 차례로: 거울 속의 이스터 에그' 리뷰 수집 완료! (5개)
# 📖 5434/5572 - '할머니 탐정, 단서를 찾아라! 4단계: 두칼레 궁전 절도 사건' 리뷰 수집 완료! (5개)
# 📖 5435/5572 - '할머니 탐정, 단서를 찾아라! 5단계: 지중해 유람선 파괴 사건' 리뷰 수집 완료! (5개)
# 📖 5436/5572 - '세종의 허리 가우디의 뼈' 리뷰 수집 완료! (5개)
# 📖 5437/5572 - '수상한 국어 탐정단 1: 신비한 책과 수수께끼 왕자' 리뷰 수집 완료! (5개)
# 📖 5438/5572 - '소녀귀신탐정 3: 너에겐 아무런 잘못이 없어' 리뷰 수집 완료! (5개)
# 📖 5439/5572 - '엉덩이탐정 DIY 캔버스 색칠' 리뷰 수집 완료! (5개)
# 📖 5440/5572 - '엉덩이 탐정 애니메이션 코믹북 5' 리뷰 수집 완료! (5개)
# 📖 5441/5572 - '과학 탐정 나조노 신지쓰 2: 과학 탐정 vs. 저주받은 수학여행' 리뷰 수집 완료! (5개)
# 📖 5442/5572 - '엔트리 코딩 탐정단 1: 화재 편' 리뷰 수집 완료! (5개)
# 📖 5443/5572 - '엔트리 코딩 탐정단 3: 대탈출 편' 리뷰 수집 완료! (5개)
# 📖 5444/5572 - '엔트리 코딩 탐정단 2: 박물관 편' 리뷰 수집 완료! (5개)
# 📖 5445/5572 - '고양이 탐정 윈스턴: 열두 살 여자아이가 되다' 리뷰 수집 완료! (5개)
# 📖 5446/5572 - '제주도에 간 전설의 고양이 탐정 3: 넋 들이는 집' 리뷰 수집 완료! (5개)
# 📖 5447/5572 - '고구마 탐정 수학 1: 사각형 씨의 위대한 유산' 리뷰 수집 완료! (5개)
# 📖 5448/5572 - '마법 숲 탐정 3: 비밀 다락방의 보물 상자' 리뷰 수집 완료! (5개)
# 📖 5449/5572 - '찍냥이 수수께끼 탐정단' 리뷰 수집 완료! (5개)
# 📖 5450/5572 - '셜록 홈스와 함께하는 나의 첫 추리퀴즈' 리뷰 수집 완료! (5개)
# 📖 5451/5572 - '스무고개 탐정 Game Book' 리뷰 수집 완료! (5개)
# 📖 5452/5572 - '시즈카 할머니와 은령 탐정사' 리뷰 수집 완료! (5개)
# 📖 5453/5572 - '초등 1~2학년 문해력 필독서 세트' 리뷰 수집 완료! (5개)
# 📖 5454/5572 - '과학 탐정 나조노 신지쓰 1: 과학 탐정 vs. 학교 7대 불가사의' 리뷰 수집 완료! (5개)
# 📖 5455/5572 - '코딱지탐정, 숫자도둑을 잡아라!' 리뷰 수집 완료! (5개)
# 📖 5456/5572 - '엉덩이 탐정 내가 만드는 스크린북' 리뷰 수집 완료! (5개)
# 📖 5457/5572 - '초등탐정 강이치: 곳곳에서' 리뷰 수집 완료! (5개)
# 📖 5458/5572 - '재빠른 탐정님의 탐정수업 2' 리뷰 수집 완료! (5개)
# 📖 5459/5572 - '재빠른 탐정님의 탐정수업 1' 리뷰 수집 완료! (5개)
# 📖 5460/5572 - '엉덩이 탐정 애니메이션 코믹북 4' 리뷰 수집 완료! (5개)
# 📖 5461/5572 - '다파헤쳐 멸종동물 그림책 세트' 리뷰 수집 완료! (5개)
# 📖 5462/5572 - '귀결사 2' 리뷰 수집 완료! (2개)
# 📖 5463/5572 - '귀결사 세트' 리뷰 수집 완료! (1개)
# 📖 5464/5572 - '귀결사 1' 리뷰 수집 완료! (3개)
# 📖 5465/5572 - '천재 추리 탐정 셜록 홈즈 5' 리뷰 수집 완료! (5개)
# 📖 5466/5572 - '명탐정 코난 직소퍼즐 150pcs: 극장판 비색의 탄환.1: 집결의순간' 리뷰 수집 완료! (5개)
# 📖 5467/5572 - '명탐정 코난: 비색의 탄환' 리뷰 수집 완료! (5개)
# 📖 5468/5572 - '명탐정 코난 극장판 2021 비색의 탄환 500 직소퍼즐' 리뷰 수집 완료! (5개)
# 📖 5469/5572 - '명탐정 코난 직소퍼즐 1000pcs: 극장판 비색의 탄환' 리뷰 수집 완료! (5개)
# 📖 5470/5572 - '명탐정 코난 비색의 탄환 직소퍼즐 300pcs: A-Family' 리뷰 수집 완료! (5개)
# 📖 5471/5572 - '명탐정 코난 비색의 탄환 직소퍼즐 300' 리뷰 수집 완료! (5개)
# 📖 5472/5572 - '맥거크 탐정단 10: 눈 속에 갇힌 스파이' 리뷰 수집 완료! (5개)
# 📖 5473/5572 - '가모가와 식당 4' 리뷰 수집 완료! (5개)
# 📖 5474/5572 - '탐정활동 및 탐정실무기법 2' 리뷰 수집 완료! (5개)
# 📖 5475/5572 - '귀신 보는 추리 탐정, 콩 1~5 세트 - 전5권' 리뷰 수집 완료! (5개)
# 📖 5476/5572 - '엉덩이 탐정 숨은 암호를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5477/5572 - '비밀 역사 탐정단 Z 1-6권 세트' 리뷰 수집 완료! (5개)
# 📖 5478/5572 - '귀신 보는 추리 탐정, 콩 5: 이름 없는 아이와 최판관' 리뷰 수집 완료! (5개)
# 📖 5479/5572 - '카카오프렌즈 과학탐정단1~6+레벨업1~10+다 푼다1~5 전21권 세트/아동도서6권+노트3권 증정' 리뷰 수집 완료! (5개)
# 📖 5480/5572 - '귀신 보는 추리 탐정, 콩 1~5권 세트/아동도서+노트2권 증정' 리뷰 수집 완료! (5개)
# 📖 5481/5572 - '수상한 유튜버 과학 탐정' 리뷰 수집 완료! (5개)
# 📖 5482/5572 - '다파헤쳐 도도새의 탐정 일기' 리뷰 수집 완료! (5개)
# 📖 5483/5572 - '탐정활동의 이론 및 실무' 리뷰 수집 완료! (5개)
# 📖 5484/5572 - '마법 숲 탐정 1: 사과숲 이층집의 전설' 리뷰 수집 완료! (5개)
# 📖 5485/5572 - '탐정학 핵심문제집' 리뷰 수집 완료! (2개)
# 📖 5486/5572 - 'IQ: 탐정 아이제아 퀸타베의 사건노트' 리뷰 수집 완료! (5개)
# 📖 5487/5572 - '귀신 보는 추리 탐정, 콩 4: 개천이를 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5488/5572 - '명탐정 코난 17기 1~5권 세트/아동도서 증정' 리뷰 수집 완료! (5개)
# 📖 5489/5572 - '올컬러 만화 천재 추리 탐정 셜록 홈즈 4' 리뷰 수집 완료! (5개)
# 📖 5490/5572 - '스티커 탐정 컹크 3: 우승 팔찌와 흔들 비행기' 리뷰 수집 완료! (5개)
# 📖 5491/5572 - '스티커 탐정 컹크 2: 다이아몬드 목걸이와 유령 기차' 리뷰 수집 완료! (5개)
# 📖 5492/5572 - '경성 고양이 탐정 독고&#47917;' 리뷰 수집 완료! (5개)
# 📖 5493/5572 - '아홉 살 탐정 레베카 5: 수상한 마을의 미스터리' 리뷰 수집 완료! (5개)
# 📖 5494/5572 - '귀신 보는 추리 탐정, 콩 3: 이상한 총각 귀신' 리뷰 수집 완료! (5개)
# 📖 5495/5572 - '올컬러 만화 천재 추리 탐정 셜록 홈즈 3' 리뷰 수집 완료! (5개)
# 📖 5496/5572 - '고구마 탐정 과학 1: 사라진 대왕 진주 귀걸이' 리뷰 수집 완료! (5개)
# 📖 5497/5572 - '귀신 보는 추리 탐정, 콩 2: 날 버리지 마!' 리뷰 수집 완료! (5개)
# 📖 5498/5572 - '귀신 보는 추리 탐정, 콩 1: 나에게 말해 줘!' 리뷰 수집 완료! (5개)
# 📖 5499/5572 - '탐정사 자격검정시험 세트' 리뷰 수집 완료! (5개)
# 📖 5500/5572 - '탐정사 2차 자격검정시험' 리뷰 수집 완료! (5개)
# 📖 5501/5572 - '탐정사 1차 자격검정시험' 리뷰 수집 완료! (5개)
# 📖 5502/5572 - '끙끙 탐정의 신기한 우주선' 리뷰 수집 완료! (3개)
# 📖 5503/5572 - '명탐정 셜록 샘 5: 도쿄 인기 만화가 실종 사건' 리뷰 수집 완료! (5개)
# 📖 5504/5572 - '명탐정 셜록 샘 1~5권 세트/아동도서 증정' 리뷰 수집 완료! (5개)
# 📖 5505/5572 - '할머니 탐정, 단서를 찾아라 3단계: 미술관 가짜 그림 사건' 리뷰 수집 완료! (5개)
# 📖 5506/5572 - '할머니 탐정, 단서를 찾아라 3단계: 미술관 가짜 그림 사건' 리뷰 수집 완료! (5개)
# 📖 5507/5572 - '떴다! 지식 탐험대: 화산과 지진' 리뷰 수집 완료! (5개)
# 📖 5508/5572 - '탐정 클럽 1~3 세트 - 전3권' 리뷰 수집 완료! (5개)
# 📖 5509/5572 - '추리 천재 엉덩이 탐정 1~10+카레 사건 전11권 세트/아동도서2권+노트+텀블러 증정' 리뷰 수집 완료! (5개)
# 📖 5510/5572 - '추리 천재 엉덩이 탐정 10' 리뷰 수집 완료! (5개)
# 📖 5511/5572 - '엉덩이 탐정 붙였다 떼었다 미니 스티커 놀이북 1' 리뷰 수집 완료! (5개)
# 📖 5512/5572 - '엉덩이 탐정 붙였다 떼었다 미니 스티커 놀이북 2' 리뷰 수집 완료! (5개)
# 📖 5513/5572 - '츤데레 탐정은 어느 경관을 죽이고 싶다' 리뷰 수집 완료! (5개)
# 📖 5514/5572 - '카트리에일의 수수께끼 사건파일 2' 리뷰 수집 완료! (5개)
# 📖 5515/5572 - '엉덩이 탐정 사다리게임' 리뷰 수집 완료! (5개)
# 📖 5516/5572 - '엉덩이 탐정 퍼즐관찰게임' 리뷰 수집 완료! (5개)
# 📖 5517/5572 - '출동! 무무스 탐정: 목이 늘어나도 사건은 해결해야지' 리뷰 수집 완료! (5개)
# 📖 5518/5572 - '명탐정 셜록 샘 4: 서울 미스터리 게임 대결' 리뷰 수집 완료! (5개)
# 📖 5519/5572 - '신비아파트 시즌3 파트2 직소퍼즐: 300pcs 탐정가 신비' 리뷰 수집 완료! (5개)
# 📖 5520/5572 - '카카오프렌즈 과학탐정단 1~6권 세트/아동도서+노트 증정' 리뷰 수집 완료! (5개)
# 📖 5521/5572 - '버본과 허니 토스트: 탐정은 거짓말을 한다' 리뷰 수집 완료! (5개)
# 📖 5522/5572 - '수상한 전학생 IQ 탐정 뮤 1~3 세트 - 전3권' 리뷰 수집 완료! (5개)
# 📖 5523/5572 - '수상한 전학생 IQ 탐정 뮤 3' 리뷰 수집 완료! (5개)
# 📖 5524/5572 - '하루 10분 매일 즐거운 엉덩이 탐정 종이접기' 리뷰 수집 완료! (5개)
# 📖 5525/5572 - '엉덩이탐정 스탬프' 리뷰 수집 완료! (5개)
# 📖 5526/5572 - '엉덩이탐정 앞치마/토시 세트' 리뷰 수집 완료! (5개)
# 📖 5527/5572 - '수상한 전학생 IQ 탐정 뮤 2' 리뷰 수집 완료! (5개)
# 📖 5528/5572 - '수상한 전학생 IQ 탐정 뮤 1~2 세트 - 전2권' 리뷰 수집 완료! (5개)
# 📖 5529/5572 - '예비탐정이 개업을 준비할 때 알아야 할 필수팁 모음집' 리뷰 수집 완료! (5개)
# 📖 5530/5572 - '엉덩이 탐정 아이템을 찾아라!' 리뷰 수집 완료! (5개)
# 📖 5531/5572 - '엉덩이탐정 미로게임북' 리뷰 수집 완료! (5개)
# 📖 5532/5572 - '엉덩이 탐정 올록볼록 모양 색칠북' 리뷰 수집 완료! (5개)
# 📖 5533/5572 - '스티커 탐정 컹크 1: 황금 메달과 덜컹 버스' 리뷰 수집 완료! (5개)
# 📖 5534/5572 - '맥거크 탐정단 9 : 나무위의 보물' 리뷰 수집 완료! (5개)
# 📖 5535/5572 - '초등탐정 강이치: 부메랑 사건' 리뷰 수집 완료! (5개)
# 📖 5536/5572 - '초등탐정 강이치: 부메랑 사건' 리뷰 수집 완료! (5개)
# 📖 5537/5572 - '엉덩이 탐정 메모리게임' 리뷰 수집 완료! (5개)
# 📖 5538/5572 - '명탐정 코난 직소퍼즐 300피스 6: 특별한 하루' 리뷰 수집 완료! (5개)
# 📖 5539/5572 - '올컬러 만화 천재 추리 탐정 셜록 홈즈 2' 리뷰 수집 완료! (5개)
# 📖 5540/5572 - '명탐정 코난 직소퍼즐 150피스 7: 화려한 비행쇼' 리뷰 수집 완료! (5개)
# 📖 5541/5572 - '명탐정 코난 직소퍼즐 150피스 8: 괴도키드의 속삭임' 리뷰 수집 완료! (5개)
# 📖 5542/5572 - '명탐정 코난 직소퍼즐 500피스 2: 응원!' 리뷰 수집 완료! (5개)
# 📖 5543/5572 - '명탐정 코난 직소퍼즐 150피스 6: 벚꽃 아래' 리뷰 수집 완료! (5개)
# 📖 5544/5572 - '붉은 실' 리뷰 수집 완료! (5개)
# 📖 5545/5572 - '르루주 사건' 리뷰 수집 완료! (5개)
# 📖 5546/5572 - '아틀라스 옵스큐라' 리뷰 수집 완료! (5개)
# 📖 5547/5572 - '살면서 길을 잃었거든 산티아고에 가라' 리뷰 수집 완료! (5개)
# 📖 5548/5572 - '미스터리 한국사' 리뷰 수집 완료! (5개)
# 📖 5549/5572 - '미스터리 한국사 1' 리뷰 수집 완료! (5개)
# 📖 5550/5572 - '우리들의 현대 침묵사' 리뷰 수집 완료! (5개)
# 📖 5551/5572 - '박정희 장군, 나를 꼭 죽여야겠소' 리뷰 수집 완료! (5개)
# 📖 5552/5572 - '12인 12색' 리뷰 수집 완료! (5개)
# 📖 5553/5572 - '한국 추리 스릴러 단편선 3' 리뷰 수집 완료! (5개)
# 📖 5554/5572 - '사도세자 암살 미스터리 3일 1' 리뷰 수집 완료! (5개)
# 📖 5555/5572 - '한국 추리 스릴러 단편선' 리뷰 수집 완료! (5개)
# 📖 5556/5572 - '두 명의 목격자' 리뷰 수집 완료! (5개)
# 📖 5557/5572 - '괴물딴지 미스터리 사전 스폐셜' 리뷰 수집 완료! (5개)
# 📖 5558/5572 - '천년의 비밀' 리뷰 수집 완료! (5개)
# 📖 5559/5572 - '녹색 섬광' 리뷰 수집 완료! (5개)
# 📖 5560/5572 - '삐뚤어진 나라의 미스터리' 리뷰 수집 완료! (5개)
# 📖 5561/5572 - 'B파일' 리뷰 수집 완료! (5개)
# 📖 5562/5572 - '괴물딴지 미스터리 사전' 리뷰 수집 완료! (5개)
# 📖 5563/5572 - 'O' 리뷰 수집 완료! (5개)
# 📖 5564/5572 - '히스테리 미스터리' 리뷰 수집 완료! (5개)
# 📖 5565/5572 - '교동회관 밀실 살인사건' 리뷰 수집 완료! (5개)
# 📖 5566/5572 - '악마는 꿈꾸지 않는다' 리뷰 수집 완료! (5개)
# 📖 5567/5572 - '춤추는 집 1' 리뷰 수집 완료! (5개)
# 📖 5568/5572 - '염마 - 한국 최초 추리소설' 리뷰 수집 완료! (5개)
# 📖 5569/5572 - '한국추리소설 걸작선 1' 리뷰 수집 완료! (5개)
# 📖 5570/5572 - '계간 미스터리  : 봄여름 특별호' 리뷰 수집 완료! (5개)
# 📖 5571/5572 - '한국 교과서 전쟁사' 리뷰 수집 완료! (5개)
# 📖 5572/5572 - '625 미스터리' 리뷰 수집 완료! (5개)
# ✅ 총 4923권의 블로그 리뷰 저장 완료!

# %%
import requests
import json
import os
import time
import re

# ✅ 네이버 API 환경변수 사용
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# ✅ 정제된 책 데이터 로드
with open("clean_mystery_books.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 블로그 리뷰 필터링 함수 (소설 관련 단어 포함된 경우만 저장)
def filter_valid_reviews(reviews):
    valid_reviews = []
    allowed_keywords = ["책", "소설", "리뷰", "작품", "추천", "줄거리", "미스터리", "추리", "범죄", "작가", "스토리"]
    
    for review in reviews:
        title = review["title"]
        summary = review["summary"]

        if any(keyword in title for keyword in allowed_keywords) or any(keyword in summary for keyword in allowed_keywords):
            valid_reviews.append(review)

    return valid_reviews

# ✅ 불필요한 출판 정보 제거 함수
def clean_description(description):
    description = re.sub(r"(출판[:\s]?\S+|저자[:\s]?\S+|발매[:\s]?\d{4}.\d{2}.\d{2})", "", description)
    description = re.sub(r"<.*?>", "", description)  # HTML 태그 제거
    return description.strip()

# ✅ 소설 관련 키워드 등장 횟수 체크
def is_relevant_review(summary):
    keywords = ["책", "소설", "추리", "미스터리", "스토리", "범죄", "작가", "줄거리"]
    score = sum(summary.count(keyword) for keyword in keywords)
    return score >= 2

# ✅ 블로그 크롤링 실행
book_reviews = {}

for index, book in enumerate(books_data, 1):
    title = book.get("title", "제목 없음")

    # ✅ 네이버 블로그 검색 API 호출
    reviews = search_blog_reviews(title)

    # ✅ 리뷰 필터링 적용
    cleaned_reviews = []
    for review in reviews:
        clean_summary = clean_description(review["summary"])
        if is_relevant_review(clean_summary):
            cleaned_reviews.append({"title": review["title"], "summary": clean_summary, "link": review["link"]})

    # ✅ 필터링된 데이터 저장
    if cleaned_reviews:
        book_reviews[title] = cleaned_reviews

    print(f"📖 {index}/{len(books_data)} - '{title}' 리뷰 수집 완료! ({len(cleaned_reviews)}개)")
    
    time.sleep(1.5)  # ✅ API 요청 간격 조정

# ✅ 크롤링된 블로그 리뷰를 JSON 파일로 저장
with open("filtered_blog_reviews.json", "w", encoding="utf-8") as f:
    json.dump(book_reviews, f, ensure_ascii=False, indent=4)

print(f"✅ 총 {len(book_reviews)}권의 블로그 리뷰 저장 완료!")

# %%
import requests
import json
import os
import time
import re

# ✅ 네이버 API 환경변수 사용
CLIENT_ID = os.getenv('X_NAVER_CLIENT_ID')
CLIENT_SECRET = os.getenv('X_NAVER_CLIENT_SECRET')

# ✅ 정제된 책 데이터 로드
with open("clean_mystery_books.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 네이버 블로그 검색 API 요청 함수 (429 오류 방지 + 응답이 없을 경우 빈 리스트 반환)
def search_blog_reviews(query, display=5, retries=3):
    url = "https://openapi.naver.com/v1/search/blog.json"
    headers = {
        "X-Naver-Client-Id": CLIENT_ID,
        "X-Naver-Client-Secret": CLIENT_SECRET
    }
    params = {
        "query": query,
        "display": display,
        "sort": "sim"
    }

    for attempt in range(retries):  # ✅ 최대 3번 재시도
        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 200:
            data = response.json()
            if "items" in data:
                return data["items"]  # ✅ API 응답이 있을 경우 리스트 반환
            else:
                print(f"⚠️ '{query}' 검색 결과 없음")
                return []  # ✅ 응답에 'items'가 없을 경우 빈 리스트 반환

        elif response.status_code == 429:
            wait_time = (attempt + 1) * 5  # ✅ 5초, 10초, 15초 대기
            print(f"🚨 429 오류: 요청 속도 제한 초과! ({query}) - {attempt + 1}번째 재시도 후 {wait_time}초 대기...")
            time.sleep(wait_time)

        else:
            print(f"❌ API 요청 실패: {response.status_code}, 검색어: {query}")
            return []  # ✅ API 요청 실패 시 빈 리스트 반환

    return []  # ✅ 3번 재시도 후에도 실패하면 빈 리스트 반환

# ✅ 블로그 리뷰 필터링 함수 (소설 관련 단어 포함된 경우만 저장)
def filter_valid_reviews(reviews):
    valid_reviews = []
    allowed_keywords = ["책", "소설", "리뷰", "작품", "추천", "줄거리", "미스터리", "추리", "범죄", "작가", "스토리"]
    
    for review in reviews:
        title = review["title"]
        summary = review["summary"]

        if any(keyword in title for keyword in allowed_keywords) or any(keyword in summary for keyword in allowed_keywords):
            valid_reviews.append(review)

    return valid_reviews

# ✅ 불필요한 출판 정보 제거 함수
def clean_description(description):
    description = re.sub(r"(출판[:\s]?\S+|저자[:\s]?\S+|발매[:\s]?\d{4}.\d{2}.\d{2})", "", description)
    description = re.sub(r"<.*?>", "", description)  # HTML 태그 제거
    return description.strip()

# ✅ 소설 관련 키워드 등장 횟수 체크
def is_relevant_review(summary):
    keywords = ["책", "소설", "추리", "미스터리", "스토리", "범죄", "작가", "줄거리"]
    score = sum(summary.count(keyword) for keyword in keywords)
    return score >= 2

# ✅ 블로그 크롤링 실행 (처음 20개 책만 크롤링)
book_reviews = {}

for index, book in enumerate(books_data[:20], 1):  # 🔥 20개만 크롤링
    title = book.get("title", "제목 없음")

    # ✅ 네이버 블로그 검색 API 호출
    reviews = search_blog_reviews(title)  # ✅ 이제 빈 리스트([])라도 항상 반환됨

    # ✅ 리뷰 필터링 적용
    cleaned_reviews = []
    for review in reviews:
        clean_summary = clean_description(review["description"])  # ✅ "summary" → "description" 수정
        if is_relevant_review(clean_summary):
            cleaned_reviews.append({"title": review["title"], "summary": clean_summary, "link": review["link"]})

    # ✅ 필터링된 데이터 저장
    if cleaned_reviews:
        book_reviews[title] = cleaned_reviews

    print(f"📖 {index}/20 - '{title}' 리뷰 수집 완료! ({len(cleaned_reviews)}개)")
    
    time.sleep(1.5)  # ✅ API 요청 간격 조정

# ✅ 크롤링된 블로그 리뷰를 JSON 파일로 저장
with open("filtered_blog_reviews_20.json", "w", encoding="utf-8") as f:
    json.dump(book_reviews, f, ensure_ascii=False, indent=4)

print(f"✅ 총 {len(book_reviews)}권의 블로그 리뷰 저장 완료! (20개 중)")
# Out:
# 📖 1/20 - '당신이 누군가를 죽였다' 리뷰 수집 완료! (1개)
# 📖 2/20 - '용의자 X의 헌신' 리뷰 수집 완료! (3개)
# 📖 3/20 - '악의' 리뷰 수집 완료! (0개)
# 📖 4/20 - '비정근' 리뷰 수집 완료! (2개)
# 📖 5/20 - '셜록 홈스의 모험' 리뷰 수집 완료! (1개)
# 📖 6/20 - '리버 2' 리뷰 수집 완료! (0개)
# 📖 7/20 - '리버 1' 리뷰 수집 완료! (1개)
# 📖 8/20 - '미로장의 참극' 리뷰 수집 완료! (2개)
# 📖 9/20 - '얼음 속의 여인' 리뷰 수집 완료! (2개)
# 📖 10/20 - '성소의 참새' 리뷰 수집 완료! (1개)
# 📖 11/20 - '귀신 들린 아이' 리뷰 수집 완료! (1개)
# 📖 12/20 - '죽은 자의 몸값' 리뷰 수집 완료! (0개)
# 📖 13/20 - '아이 윌 파인드 유' 리뷰 수집 완료! (0개)
# 📖 14/20 - '고행의 순례자' 리뷰 수집 완료! (2개)
# 📖 15/20 - '캐드펠 수사 시리즈' 리뷰 수집 완료! (3개)
# 📖 16/20 - '청과 부동명왕' 리뷰 수집 완료! (0개)
# 📖 17/20 - '아서 코난 도일, 선상 미스터리 단편 컬렉션' 리뷰 수집 완료! (5개)
# 📖 18/20 - '아름답고 위험한 이름, 비너스' 리뷰 수집 완료! (0개)
# 📖 19/20 - '시체 한 구가 더 있다' 리뷰 수집 완료! (1개)
# 📖 20/20 - '수도사의 두건' 리뷰 수집 완료! (1개)
# ✅ 총 14권의 블로그 리뷰 저장 완료! (20개 중)

# %%
import requests
import os
import json

# ✅ 알라딘 API 키 (환경변수에서 가져오기)
TTBKey = os.getenv('TTBKey')
# ✅ ISBN을 통한 도서 정보 조회 함수
def get_book_info_by_isbn(isbn):
    url = "http://www.aladin.co.kr/ttb/api/ItemLookUp.aspx"
    params = {
        "TTBKey": TTBKey,  # ✅ 알라딘 API 키
        "ItemId": isbn,  # ✅ ISBN을 ItemId로 전달 (isbn13 → isbn 수정)
        "ItemIdType": "ISBN13",  # ✅ ISBN13 사용
        "Cover": "Big",  # ✅ 커버 이미지 크기
        "Output": "js",  # ✅ JSON 형식 응답
        "Version": "20131101",  # ✅ API 버전
        "OptResult":["Story","fulldescription2"]
    }

    response = requests.get(url, params=params)
    if response.status_code == 200:
        try:
            data = response.json()
            if "item" in data:
                return data["item"]
            else:
                print(f"⚠️ '{isbn}'에 대한 검색 결과가 없습니다.")
                return None
        except json.JSONDecodeError:
            print(f"❌ JSON 디코딩 오류: {response.text}")
            return None
    else:
        print(f"❌ API 요청 실패: {response.status_code}, ISBN: {isbn}")
        return None

# ✅ 예제 실행 (올바른 변수 사용)
isbn = "9791170611561"  # ✅ 검색할 도서 ISBN13
book_info = get_book_info_by_isbn(isbn)

if book_info:
    for book in book_info:
        print(f"📖 제목: {book.get('title', '제목 없음')}")
        print(f"📜 줄거리: {book.get('description', '줄거리 없음')}")
        print(f"✍️ 저자: {book.get('author', '저자 정보 없음')}")
        print(f"🏢 출판사: {book.get('publisher', '출판사 정보 없음')}")
        print(f"📅 출간일: {book.get('pubDate', '출간일 없음')}")
        print(f"📘 표지 이미지: {book.get('cover', '이미지 없음')}")
        print(f"🔗 링크: {book.get('link', '링크 없음')}\n")
else:
    print("⚠️ 도서 정보를 가져올 수 없습니다.")
# Out:
# 📖 제목: 당신이 누군가를 죽였다
# 📜 줄거리: 일본 최고의 베스트셀러 작가 히가시노 게이고의 장편소설『당신이 누군가를 죽였다』가 출간되었다. 작품은 장르문학계의 거장인 작가가 101번째 작품을 맞아 추리소설의 원점으로 돌아가 ‘황금시대 미스터리’의 매력을 유감없이 발휘한 걸작으로 평단과 독자의 호평을 받고 있다.
# ✍️ 저자: 히가시노 게이고 (지은이), 최고은 (옮긴이)
# 🏢 출판사: 북다
# 📅 출간일: 2024-07-23
# 📘 표지 이미지: https://image.aladin.co.kr/product/34292/25/cover200/k692932177_1.jpg
# 🔗 링크: http://www.aladin.co.kr/shop/wproduct.aspx?ItemId=342922559&amp;partner=openAPI&amp;start=api

# %%
import json
import re

# ✅ 중국어 & 일본어 감지하는 정규표현식 (Unicode 범위)
chinese_japanese_pattern = re.compile(r"[\u3040-\u30FF\u4E00-\u9FFF]")  # 히라가나, 가타카나, 한자

# ✅ JSON 파일 로드
with open("clean_mystery_books.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 필터링 함수 (제목과 설명에서 중국어나 일본어 포함 시 제거)
def contains_chinese_or_japanese(text):
    return bool(chinese_japanese_pattern.search(text))

# ✅ 필터링된 도서 리스트 생성
filtered_books = [
    book for book in books_data
    if not contains_chinese_or_japanese(book.get("title", "")) and not contains_chinese_or_japanese(book.get("description", ""))
]

# ✅ 필터링 결과 저장
with open("filtered_mystery_books.json", "w", encoding="utf-8") as f:
    json.dump(filtered_books, f, ensure_ascii=False, indent=4)

print(f"✅ 필터링 완료! 총 {len(filtered_books)}권의 도서가 저장되었습니다.")
# Out:
# ✅ 필터링 완료! 총 5328권의 도서가 저장되었습니다.

# %%
import json
import re

# ✅ 필터링할 키워드 리스트
exclude_keywords = ["실무론","학술정보","범죄론",
    "직무적성검사", "하브루타", "추리퀴즈", "약사의 혼잣말", "학습", "밥스 패밀리", "신비아파트", "수학 탐정스", "어린이", 
    "미스터리 수학", "범죄심리학", "이론 총서", "인적성검사", "추리논증", "LEET", "법학적성시험", "범죄학", "형사법", "형법", 
    "수사학", "법학", "법조", "검찰", "경찰", "귀신 보는 추리 탐정", "고양이 탐정 윈스턴", "전공", "수험서", "시험", "문제집", 
    "논문", "형사정책", "카카오", "직소퍼즐", "엉덩이탐정", "엉덩이 탐정", "스티커 탐정", "초등탐정", "수상한 전학생", "맥거크 탐정단"
]

# ✅ JSON 파일 로드
with open("clean_mystery_books.json", "r", encoding="utf-8") as f:
    books_data = json.load(f)

# ✅ 필터링 함수 (제목, 설명, 저자, 출판사에서 특정 키워드 포함 시 제거)
def is_irrelevant_book(book):
    title = book.get("title", "").lower()
    description = book.get("description", "").lower()
    author = book.get("author", "").lower()  # 🔹 저자 추가
    publisher = book.get("publisher", "").lower()  # 🔹 출판사 추가

    # ✅ 키워드 포함 여부 확인 (정규표현식 제거, 부분 포함 검사로 변경)
    for keyword in exclude_keywords:
        if keyword in title or keyword in description or keyword in author or keyword in publisher:
            return True  # 🚨 해당 키워드가 포함된 책은 제거
    return False

# ✅ 필터링된 도서 리스트 생성
filtered_books = [book for book in books_data if not is_irrelevant_book(book)]

# ✅ 필터링 결과 저장
with open("filtered_mystery_books.json", "w", encoding="utf-8") as f:
    json.dump(filtered_books, f, ensure_ascii=False, indent=4)

print(f"✅ 필터링 완료! 총 {len(filtered_books)}권의 도서가 저장되었습니다.")
# Out:
# ✅ 필터링 완료! 총 3980권의 도서가 저장되었습니다.
